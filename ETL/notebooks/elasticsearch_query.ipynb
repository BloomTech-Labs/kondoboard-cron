# %%
import json
import requests

# %%
query = json.dumps({
    "query": {
        "match_all": {}
    }
})
uri = f"https://{user}:{password}@{endpoint}"
headers ={"Content-Type": "application/json"}

response = requests.get(uri, headers=headers, data=query)

# %%
response = response.json()

# %%
response
# Out:
# {'took': 0,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 19, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1549335342',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1549335342?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=B4EFA78CF416B570A4453DBD2C44A87C643CF0A4',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': '...  for good. <strong>Data</strong> <strong>Engineer</strong> Do you want to work for a tech company that writes its own code, develops its own software, and builds its own products? We experiment and innovate leveraging ...',
#      'publication_date': '2020-05-19',
#      'location_raw': ['US',
#       'Illinois',
#       'Cook County',
#       'Chicago',
#       'Illinois Medical District'],
#      'location_point': '41.868494,-87.673975'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1537091904',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1537091904?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=6DE6CDD2E6B8EE4FAC9D4791B848D688AEB537B5',
#      'title': 'Data Engineer / Lead Data Engineer',
#      'title_keyword': 'Data Engineer / Lead Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Menlo Park, CA <strong>Data</strong> <strong>Engineer</strong> 6 Positon Rate Open for RIGHT Candidate 10 years of experience Experience in Advance SQL, Python, Tableau or any BI tool Should be well versed ...',
#      'publication_date': '2020-05-05',
#      'location_raw': ['US', 'California', 'San Mateo County', 'Menlo Park'],
#      'location_point': '37.448491,-122.180281'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1533100037',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1533100037?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=23628A09689E2BD1265C0B330E8889D356BA7DEE',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Role <strong>Data</strong> <strong>Engineer</strong> Location Wilmington, DE Skillset Language PythonScalaJava Python is required Pyspark is a big one to have Spark or Scala required Analytics of data Analysing ...  for a savvy <strong>Data</strong> <strong>Engineer</strong> to join our growing team to build a modernized Data Ecosystem. The hire will be responsible for expanding and optimizing our data and data pipeline architecture ...',
#      'publication_date': '2020-04-30',
#      'location_raw': ['US', 'Delaware', 'New Castle County', 'Wilmington'],
#      'location_point': '39.73126,-75.545138'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1540746038',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1540746038?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=513FE7192E600E19150585147811F011D512BF27',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': "<strong>Data</strong> <strong>Engineer</strong> Seattle WA 6 Months <strong>Data</strong> <strong>Engineer</strong>  Development of ETL <strong>data</strong> pipelines, from ingestion of data to consumption by business intelligence and advanced analytics teams ...  technical backlog to answer those needs in a timely manner.  Work with team to identify and resolve technical debt to improve the team's throughput. Skills:  2 - 6 years software and <strong>data</strong> ...",
#      'publication_date': '2020-05-09',
#      'location_raw': ['US', 'Washington', 'King County', 'Seattle'],
#      'location_point': '47.608492,-122.336407'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1550148404',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1550148404?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=05F093B5BBA24085766EBE01B8AC066DE1B4EA29',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Role FullStack <strong>Data</strong> <strong>Engineer</strong> Location NYC, NY Boston, MA Duration Fulltime Positions 5 Salary 130KYear (Mid-Level)  Benefits 180KYear (Senior)  Benefits Key Responsibilities ...  Be the technical lead engineer on a team of <strong>data</strong> <strong>engineers</strong> responsible for <strong>data</strong> aggregation, transformation, modeling and delivery for both client usage and internal data science teams Full-stack ...',
#      'publication_date': '2020-05-20',
#      'location_raw': ['US', 'New York'],
#      'location_point': '42.522869,-75.574677'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1544935967',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1544935967?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=F2F438E331EE5F2029A7B9B331D0149B6F8EB077',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Important <strong>Data</strong> <strong>Engineer</strong> with Scala background as well as Kafka. JOB DESCRIPTION As a software engineer on the Lineage team you will help deliver key features through our agile ...  scales. Technologies used include Scala, Akka, AWS (Lambda, Neptune, DynamoDB), Kafka, Jenkins, Terraform Role <strong>Data</strong> <strong>Engineer</strong>- 2 openings Duration 8 months  extension Location San ...',
#      'publication_date': '2020-05-14',
#      'location_raw': ['US', 'California', 'San Francisco'],
#      'location_point': '37.798085,-122.466538'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1550124138',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1550124138?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=F9032DFA855E78FC254649635160B39FEC3E207E',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Hi, Please find the below requirements. You can respond back with an updated resume to praveenrajpvkc.com Title <strong>Data</strong> <strong>Engineer</strong> (Azure <strong>Data</strong> <strong>Engineer</strong> )Location Redmond, WAClient ...  Microsoft Note We are looking for a <strong>Data</strong> <strong>Engineer</strong> with Azure functions, azure pipelines design, ADF, ADLS and problem solving using C or python Responsibilities bull Build and maintain ETL ...',
#      'publication_date': '2020-05-20',
#      'location_raw': ['US', 'Washington', 'King County', 'Redmond'],
#      'location_point': '47.670119,-122.118237'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1521288337',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1521288337?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=3850D5181972D3577432AB845ACE7A684586D6DB',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Description We are seeking a highly talented <strong>Data</strong> <strong>Engineer</strong> (DE) within the <strong>Data</strong> <strong>Engineering</strong> group. We need your help to build systems to enable data-driven decision-making. Our ...  <strong>Data</strong> <strong>Engineering</strong> team owns and develops the technology platform that offers decision makers both performance metrics and analysis as well as the self-service capability to perform ...',
#      'publication_date': '2020-04-14',
#      'location_raw': ['US', 'New Jersey', 'Essex County', 'Newark'],
#      'location_point': '40.735075,-74.173906'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1551130791',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1551130791?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=979581E2002B04CAA97AE0C211527E4893562357',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Job Title <strong>Data</strong> <strong>Engineer</strong> Location Portland, OR Duration 6-12 Months Primary Skill MS SQL Other Mandatory Skills SQL Server, No-SQL databases, SQL Python Project Description ...  of outputs Good knowledge of <strong>Data</strong> <strong>Engineering</strong>, Big <strong>Data</strong> Analytics, Excellent analytical and problem-solving skills A knack for independent and group work Scrupulous approach to duties ...',
#      'publication_date': '2020-05-21',
#      'location_raw': ['US', 'Oregon', 'Multnomah County', 'Portland'],
#      'location_point': '45.505603,-122.688215'}},
#    {'_index': 'jobs',
#     '_type': '_doc',
#     '_id': 'A1544828627',
#     '_score': 1.0,
#     '_source': {'post_url': 'https://www.adzuna.com/land/ad/1544828627?se=QgsIwxGe6hGOLYr73xsA5Q&utm_medium=api&utm_source=da871bdc&v=07DF6CE34E594CB33A8C8562F713CCF3E8724ED0',
#      'title': 'Data Engineer',
#      'title_keyword': 'Data Engineer',
#      'tags': 'it-jobs',
#      'description': 'Job Title <strong>Data</strong> <strong>Engineer</strong> Location Portland, OR Duration 6-12 Months Primary Skill MS SQL Other Mandatory Skills SQL Server, No-SQL databases, SQL Python Project Description ...  of outputs Good knowledge of <strong>Data</strong> <strong>Engineering</strong>, Big <strong>Data</strong> Analytics, Excellent analytical and problem-solving skills A knack for independent and group work Scrupulous approach to duties ...',
#      'publication_date': '2020-05-14',
#      'location_raw': ['US', 'Oregon', 'Multnomah County', 'Portland'],
#      'location_point': '45.505603,-122.688215'}}]}}
