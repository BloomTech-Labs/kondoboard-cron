# %%
import requests
import pandas as pd
import collections

# %%
# ADZUNA API INFO

# %%
request = requests.get(f"https://api.adzuna.com/v1/api/jobs/us/search/1?app_id={app_id}&app_key={api_key}&results_per_page=20&what=data%20engineer&content-type=application/json").json()

# %%
from pprint import pprint
pprint(request["results"])
# Out:
# [{'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU0OTMzNTM0MiIsInMiOiJ6Z0swa0FxZTZoRzlrTkdMZHM3cVd3In0.-KMohUMdmvHVtHhMpmYvAOEDUPvC8NI8rgYt7d_Yn38',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#                'label': 'IT Jobs',
#                'tag': 'it-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#               'display_name': 'Capital One'},
#   'created': '2020-05-19T22:16:25Z',
#   'description': '...  for good. <strong>Data</strong> '
#                  '<strong>Engineer</strong> Do you want to work for a tech '
#                  'company that writes its own code, develops its own software, '
#                  'and builds its own products? We experiment and innovate '
#                  'leveraging ...',
#   'id': '1549335342',
#   'latitude': 41.868494,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#                'area': ['US',
# ...

# %%
request['results']
# Out:
# [{'location': {'display_name': 'Illinois Medical District, Chicago',
#    'area': ['US',
#     'Illinois',
#     'Cook County',
#     'Chicago',
#     'Illinois Medical District'],
#    '__CLASS__': 'Adzuna::API::Response::Location'},
#   'id': '1549335342',
#   'longitude': -87.673975,
#   'latitude': 41.868494,
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiVEFUcmxqQ2Q2aEdIVkVTejN4c0E1USIsImkiOiIxNTQ5MzM1MzQyIn0.DcoRU9BTjek9iOFs6Ap4Y2fW-KdrM3CxlxmFZHX5WYM',
#   'title': '<strong>Data</strong> <strong>Engineer</strong>',
#   'description': '...  for good. <strong>Data</strong> <strong>Engineer</strong> Do you want to work for a tech company that writes its own code, develops its own software, and builds its own products? We experiment and innovate leveraging ...',
#   'salary_is_predicted': '0',
#   'redirect_url': 'https://www.adzuna.com/land/ad/1549335342?se=TATrljCd6hGHVESz3xsA5Q&utm_medium=api&utm_source=da871bdc&v=B4EFA78CF416B570A4453DBD2C44A87C643CF0A4',
# ...

# %%
from flatten_dict import flatten

flattened_results =[
    flatten(result, reducer="underscore")
    for result in 
    request['results']
]

# %%
df = pd.DataFrame.from_dict(flattened_results)

# %%
df.head()
# Out:
#                 location_display_name  \
# 0  Illinois Medical District, Chicago
# 1        Menlo Park, San Mateo County
# 2                Seattle, King County
# 3       Wilmington, New Castle County
# 4                        New York, US
#
#                                        location_area  \
# 0  [US, Illinois, Cook County, Chicago, Illinois ...
# 1     [US, California, San Mateo County, Menlo Park]
# 2             [US, Washington, King County, Seattle]
# 3      [US, Delaware, New Castle County, Wilmington]
# 4                                     [US, New York]
#
#                 location___CLASS__          id   longitude   latitude  \
# 0  Adzuna::API::Response::Location  1549335342  -87.673975  41.868494
# 1  Adzuna::API::Response::Location  1537091904 -122.180281  37.448491
# 2  Adzuna::API::Response::Location  1540746038 -122.336407  47.608492
# 3  Adzuna::API::Response::Location  1533100037  -75.545138  39.731260
# ...

# %%
df = df[['id', 'redirect_url', 'title', 'title', 'category_tag', 'description', 'created', 'location_area', 'latitude', 'longitude']]

# %%
df.columns = ['id', 'post_url', 'title', 'title_keyword', 'tags', 'description', 'publication_date', 'location', 'latitude', 'longitude']

# %%
df.head()
# Out:
#            id                                           post_url  \
# 0  1549335342  https://www.adzuna.com/land/ad/1549335342?se=T...
# 1  1537091904  https://www.adzuna.com/land/ad/1537091904?se=T...
# 2  1540746038  https://www.adzuna.com/land/ad/1540746038?se=T...
# 3  1533100037  https://www.adzuna.com/land/ad/1533100037?se=T...
# 4  1550148404  https://www.adzuna.com/land/ad/1550148404?se=T...
#
#                                                title  \
# 0    <strong>Data</strong> <strong>Engineer</strong>
# 1  <strong>Data</strong> <strong>Engineer</strong...
# 2    <strong>Data</strong> <strong>Engineer</strong>
# 3    <strong>Data</strong> <strong>Engineer</strong>
# 4    <strong>Data</strong> <strong>Engineer</strong>
#
#                                        title_keyword     tags  \
# 0    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 1  <strong>Data</strong> <strong>Engineer</strong...  it-jobs
# ...

# %%
df.to_csv('./data/adzuna_extract.csv', index=None)

# %%
# LOOPING OVER DIFFERENT TITLES

# %%
import requests
from flatten_dict import flatten
import pandas as pd
from pprint import pprint

# %%
main_titles = ["data engineer", "data scientist"]

# %%
adzuna_titles = [item.strip().replace(' ', '%20') for item in main_titles]
appended_results = list()

for title in adzuna_titles:
    
    # make the requests to Adzuna API
    request = requests.get(f"https://api.adzuna.com/v1/api/jobs/us/search/1?app_id={app_id}&app_key={api_key}&results_per_page=20&what={title}&content-type=application/json")
    result = request.json()
    
    # flatten nested objects returned by API by looping over each job
    flattened_results = [
        flatten(job, reducer="underscore")
        for job in 
        result['results']
    ]
    
    # append those flattened results to make a list of flattened results 
    # with each index being a different API
    appended_results.append(flattened_results)
    
    # turn 2D list with different API calls into a 1D list to be put into df
    final = [job for api in appended_results for job in api]

df = pd.DataFrame.from_dict(final)

# rename columns
df = df[['id', 'redirect_url', 'title', 'title', 'category_tag', 'description', 'company_display_name', 'created', 'location_area', 'latitude', 'longitude']]
df.columns = ['id', 'post_url', 'title', 'title_keyword', 'tags', 'description', 'company', 'publication_date', 'location', 'latitude', 'longitude']

# separate city and state
df['city'] = df['location_area'].apply(lambda x: x[-1].replace(' County', '') if len(x) > 1 else "unknown")
df['state'] = df['location_area'].apply(lambda x: x[1] if len(x) > 1 else "uknown")
