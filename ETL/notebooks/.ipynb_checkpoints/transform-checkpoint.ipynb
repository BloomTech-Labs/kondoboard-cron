# %%
import pandas as pd
from bs4 import BeautifulSoup
import arrow

# %%
df = pd.read_csv('./data/adzuna_extract.csv')

# %%
df.head()
# Out:
#            id                                            PostURL  \
# 0  1549335342  https://www.adzuna.com/land/ad/1549335342?se=Y...
# 1  1540746038  https://www.adzuna.com/land/ad/1540746038?se=Y...
# 2  1537091904  https://www.adzuna.com/land/ad/1537091904?se=Y...
# 3  1533100037  https://www.adzuna.com/land/ad/1533100037?se=Y...
# 4  1550148404  https://www.adzuna.com/land/ad/1550148404?se=Y...
#
#                                                Title  \
# 0    <strong>Data</strong> <strong>Engineer</strong>
# 1    <strong>Data</strong> <strong>Engineer</strong>
# 2  <strong>Data</strong> <strong>Engineer</strong...
# 3    <strong>Data</strong> <strong>Engineer</strong>
# 4    <strong>Data</strong> <strong>Engineer</strong>
#
#                                         TitleKeyword     Tags  \
# 0    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 1    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 2  <strong>Data</strong> <strong>Engineer</strong...  it-jobs
# 3    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 4    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
#
#                                          Description       PublicationDate  \
# 0  ...  for good. <strong>Data</strong> <strong>E...  2020-05-19T22:16:25Z
# 1  <strong>Data</strong> <strong>Engineer</strong...  2020-05-09T09:44:30Z
# 2  Menlo Park, CA <strong>Data</strong> <strong>E...  2020-05-05T14:31:29Z
# 3  Role <strong>Data</strong> <strong>Engineer</s...  2020-04-30T17:27:52Z
# 4  Role FullStack <strong>Data</strong> <strong>E...  2020-05-20T15:30:36Z
#
#                                             Location   Latitude   Longitude
# 0  ['US', 'Illinois', 'Cook County', 'Chicago', '...  41.868494  -87.673975
# 1     ['US', 'Washington', 'King County', 'Seattle']  47.608492 -122.336407
# 2  ['US', 'California', 'San Mateo County', 'Menl...  37.448491 -122.180281
# 3  ['US', 'Delaware', 'New Castle County', 'Wilmi...  39.731260  -75.545138
# 4                                 ['US', 'New York']  42.522869  -75.574677

# %%
def keyword(text):
    """
    Formats keywords by 
    -lowercasing all letters 
    -replacing ' ' with '_'
    -replacing '-' with '_'
    """
    text = text.lower()
    text = text.replace(' ', '_')
    text = text.replace('-', '_')
    return text

# %%
def remove_html(text):
    """
    Removes HTML
    """
    return BeautifulSoup(text).get_text()

# %%
def format_date(text):
    """
    Formats Date to 'YYYY-MM-DD'
    """
    time = arrow.get(text)
    time = time.format('YYYY-MM-DD')
    return time

# %%
def adzuna_id(text):
    """
    Formats ADZUNA API IDs to A + original ID
    """
    return "A" + str(text)

# %%
df.head()
# Out:
#             id                                            PostURL  \
# 0  A1549335342  https://www.adzuna.com/land/ad/1549335342?se=Y...
# 1  A1540746038  https://www.adzuna.com/land/ad/1540746038?se=Y...
# 2  A1537091904  https://www.adzuna.com/land/ad/1537091904?se=Y...
# 3  A1533100037  https://www.adzuna.com/land/ad/1533100037?se=Y...
# 4  A1550148404  https://www.adzuna.com/land/ad/1550148404?se=Y...
#
#                                                Title  \
# 0    <strong>Data</strong> <strong>Engineer</strong>
# 1    <strong>Data</strong> <strong>Engineer</strong>
# 2  <strong>Data</strong> <strong>Engineer</strong...
# 3    <strong>Data</strong> <strong>Engineer</strong>
# 4    <strong>Data</strong> <strong>Engineer</strong>
#
#                                         TitleKeyword     Tags  \
# 0    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 1    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 2  <strong>Data</strong> <strong>Engineer</strong...  it-jobs
# 3    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
# 4    <strong>Data</strong> <strong>Engineer</strong>  it-jobs
#
#                                          Description       PublicationDate  \
# 0  ...  for good. <strong>Data</strong> <strong>E...  2020-05-19T22:16:25Z
# 1  <strong>Data</strong> <strong>Engineer</strong...  2020-05-09T09:44:30Z
# 2  Menlo Park, CA <strong>Data</strong> <strong>E...  2020-05-05T14:31:29Z
# 3  Role <strong>Data</strong> <strong>Engineer</s...  2020-04-30T17:27:52Z
# 4  Role FullStack <strong>Data</strong> <strong>E...  2020-05-20T15:30:36Z
#
#                                             Location   Latitude   Longitude
# 0  ['US', 'Illinois', 'Cook County', 'Chicago', '...  41.868494  -87.673975
# 1     ['US', 'Washington', 'King County', 'Seattle']  47.608492 -122.336407
# 2  ['US', 'California', 'San Mateo County', 'Menl...  37.448491 -122.180281
# 3  ['US', 'Delaware', 'New Castle County', 'Wilmi...  39.731260  -75.545138
# 4                                 ['US', 'New York']  42.522869  -75.574677

# %%
def apply(column, function):
    """
    Applies function to column
    """
    df[column] = df[column].apply(function)

# %%
# InsertedDate 

df['InsertedDate'] = arrow.utcnow().format("YYYY-MM-DD")

# %%
# APPLY ADZUNA ID

apply('id', adzuna_id)

# %%
# APPLY REMOVE_HTML FUNCTION

apply('Title', remove_html)
apply('TitleKeyword', remove_html)

# %%
# APPLY KEYWORD FUNCTION

apply('TitleKeyword', keyword)
apply('Tags', keyword)

# %%
# APPLY DATE FUNCTION

apply('PublicationDate', format_date)

# %%
df.head()
# Out:
#              id                                            PostURL  \
# 0  AA1549335342  https://www.adzuna.com/land/ad/1549335342?se=Y...
# 1  AA1540746038  https://www.adzuna.com/land/ad/1540746038?se=Y...
# 2  AA1537091904  https://www.adzuna.com/land/ad/1537091904?se=Y...
# 3  AA1533100037  https://www.adzuna.com/land/ad/1533100037?se=Y...
# 4  AA1550148404  https://www.adzuna.com/land/ad/1550148404?se=Y...
#
#                                 Title                        TitleKeyword  \
# 0                       Data Engineer                       data_engineer
# 1                       Data Engineer                       data_engineer
# 2  Data Engineer / Lead Data Engineer  data_engineer_/_lead_data_engineer
# 3                       Data Engineer                       data_engineer
# 4                       Data Engineer                       data_engineer
#
#       Tags                                        Description PublicationDate  \
# 0  it_jobs  ...  for good. <strong>Data</strong> <strong>E...      2020-05-19
# 1  it_jobs  <strong>Data</strong> <strong>Engineer</strong...      2020-05-09
# 2  it_jobs  Menlo Park, CA <strong>Data</strong> <strong>E...      2020-05-05
# 3  it_jobs  Role <strong>Data</strong> <strong>Engineer</s...      2020-04-30
# 4  it_jobs  Role FullStack <strong>Data</strong> <strong>E...      2020-05-20
#
#                                             Location   Latitude   Longitude  \
# 0  ['US', 'Illinois', 'Cook County', 'Chicago', '...  41.868494  -87.673975
# 1     ['US', 'Washington', 'King County', 'Seattle']  47.608492 -122.336407
# 2  ['US', 'California', 'San Mateo County', 'Menl...  37.448491 -122.180281
# 3  ['US', 'Delaware', 'New Castle County', 'Wilmi...  39.731260  -75.545138
# 4                                 ['US', 'New York']  42.522869  -75.574677
#
#   InsertedDate
# 0   2020-05-23
# 1   2020-05-23
# 2   2020-05-23
# 3   2020-05-23
# 4   2020-05-23

# %%
df.to_csv('./data/adzuna_transform.csv', index=None)
