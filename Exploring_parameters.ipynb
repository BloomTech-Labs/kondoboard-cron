# %%
import requests
request = requests.get('https://api.jobsearcher.com/v1/jobs?q%5Bmust%5D%5B0%5D=Python&status=active&limit=100')

request = request.json()

listings = request['data']

first_listing = listings[0]

first_listing.keys()

reduced_listing = dict((k, first_listing[k]) for k in ['id', 'url','company', 'title','location', 'postedDate', 'updatedDate', 'bullets', 'keywords'] 
                                        if k in first_listing)

# %%
reduced_listing
# Out:
# {'id': '451c129852855c7fc5386e026d3fada198667042bd172fd2129274d0a9d6a560',
#  'url': 'https://neuvoo.com/job.php?id=85ca87d0296d&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83debgadd3aeffdd83de93aec3degbdaedd974daafaacaea33de83ee3fbdbgbdd8cdcaed3dddfcddbgdd7',
#  'company': 'DiverseLynx',
#  'title': 'Entry Level Python Developer',
#  'location': {'city': 'Houston',
#   'state': 'Texas',
#   'latitude': 29.674496,
#   'longitude': -95.247573},
#  'postedDate': '2020-05-25T20:58:22.469Z',
#  'updatedDate': '2020-05-25T20:58:22.469Z',
#  'bullets': ['for Entry Level Python Developer',
#   'Fresh Graduate or Work experience in Test Automation using Python',
#   'Knowledge of Python and Robot framework',
#   'Knowledge of Python Library - OpenCV, Pygui',
#   'Develop Test Automation scripts using Python'],
#  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#   {'value': 'python developer', 'uniquenessScore': 0.231},
#   {'value': 'test automation', 'uniquenessScore': 0.122},
#   {'value': 'robot', 'uniquenessScore': 0.104},
#   {'value': 'library', 'uniquenessScore': 0.031},
#   {'value': 'entry level', 'uniquenessScore': 0.017},
#   {'value': 'graduate', 'uniquenessScore': 0.013},
#   {'value': 'experience', 'uniquenessScore': 0.001}]}

# %%
pip install flatten_dict
# Out:
# Requirement already satisfied: flatten_dict in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (0.3.0)
# Requirement already satisfied: six<2.0,>=1.12 in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (from flatten_dict) (1.12.0)
# Requirement already satisfied: pathlib2<3.0,>=2.3 in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (from flatten_dict) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from flatten_dict import flatten

# from dotenv import load_dotenv
# import os

# load_dotenv()

# app_id = os.getenv("APP_ID")
# api_key = os.getenv("API_KEY")

# TODO:
# Change the request to cover many different types of jobs... not just data engineer

def request_to_df():
    # make API call
    # TODO:
    #add multiple job types
        #-Option 1. multiple request_to_df with different keywords
        #-Option 2. have many request = requests.get(many different parameters)
    request = requests.get(f"https://api.jobsearcher.com/v1/jobs?q%5Bmust%5D%5B0%5D=Python&status=active&limit=100")
    # convert result into json
    result = request.json()
    # flatten nested objects
    flattened_results =[
        flatten(job, reducer="underscore")
        for job in 
        result['data']
    ]
    for item in flattened_results:
        item.update(tags = [n['value'] for n in item['keywords']])
    # turn into dataframe
#     df = pd.DataFrame.from_dict(flattened_results)

    # rename columns
#     df = df[['id', 'url', 'company', 'title', 'location_city', 'location_state', 'postedDate', 'bullets', 'location_latitude', 'location_longitude']]
            
#     df.columns = ['id', 'post_url', 'company', 'title', 'city', 'state', 'publication_date', 'description', 'latitude', 'longitude']
    # 'title_keyword' and 'tags' are in Adzuna but NOT in Jobsearcher
    # Changed 'location' to two seperate columns 'city', 'state'
    return flattened_results

# %%
for item in thing:
    item.update(tags = [n['value'] for n in item['keywords']])

# flattened_results =[
#         flatten(job, reducer="underscore")
#         for job in 
#         result['keywords']

# %%
flat = request_to_df()

# %%
type(flat)
# Out:
# list

# %%
for item in flat:
    item.update(tags = [n['value'] for n in item['keywords']])

# %%
flat
# Out:
# [{'id': '27970c6ac8d7eb957aa9bfc9aaabd2774670c5106b8fb6faccf9aca18aa58562',
#   'type': 'sponsoredToOrganic',
#   'title': 'Test Automation with Python',
#   'url': 'https://neuvoo.com/job.php?id=bb290c5c640b&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aeegdde3de7fddg3aed3deb3aedbdaadd9c4dagfaaeaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3520153846153846,
#   'postedDate': '2020-05-30T01:08:28.107Z',
#   'updatedDate': '2020-05-30T01:08:28.107Z',
#   'provider': 'neuvoo',
#   'bullet': '4 years of experience in Test Automation using Python',
#   'bullets': ['4 years of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:28.107Z',
#   'status': 'active',
#   'shortId': 'gvq1VE',
#   'companyShortId': 'zGxooN',
#   'tags': ['opencv',
#    'test automation',
#    'robot',
#    'python',
#    'hands on',
#    'library',
#    'coding',
#    'experience']},
#  {'id': '451c129852855c7fc5386e026d3fada198667042bd172fd2129274d0a9d6a560',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=844eb003d441&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83decgddc3aebfade3deg3deg3dedbaacdd9c4dacfdafaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3230307692307693,
#   'postedDate': '2020-05-30T00:57:19.331Z',
#   'updatedDate': '2020-05-30T00:57:19.331Z',
#   'provider': 'neuvoo',
#   'bullet': 'for Entry Level Python Developer',
#   'bullets': ['for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge of Python and Robot framework',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:57:19.331Z',
#   'status': 'active',
#   'shortId': 'v2Yd7a',
#   'companyShortId': 'zGxooN',
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'robot',
#    'library',
#    'entry level',
#    'graduate',
#    'experience']},
#  {'id': '9486dd4822788545ef9176ba609b7fd22693d2320321745e9c3228cdfe6b00d8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Lead Full Stack Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=3a21bce968ad&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddd3aefgdde3deffade3aed3aeb3de7bdaadd984aaffaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'PeopleNTech LLC',
#   'location_city': 'Chandler',
#   'location_state': 'Arizona',
#   'location_latitude': 33.306009,
#   'location_longitude': -111.91928,
#   'score': 0.38537606837606836,
#   'postedDate': '2020-05-30T00:42:16.175Z',
#   'updatedDate': '2020-05-30T00:42:16.175Z',
#   'provider': 'neuvoo',
#   'bullet': 'Position- Lead Full Stack Python Developer',
#   'bullets': ['Position- Lead Full Stack Python Developer',
#    'Need someone with Python Full Stack web application background to be the lead.',
#    'Lead Full Stack Python Developer with Python based API WebServices building skills + Javascript Framework knowledge'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'lead', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'background', 'uniquenessScore': 0.003},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:42:16.175Z',
#   'status': 'active',
#   'shortId': '0VJlgp',
#   'companyShortId': 'N0XEWN',
#   'tags': ['python developer',
#    'full stack',
#    'api',
#    'javascript',
#    'web',
#    'lead',
#    'building',
#    'background',
#    'skills',
#    'application']},
#  {'id': 'ed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e68ab2617751522b7954d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Automation Tester with Python',
#   'url': 'https://neuvoo.com/job.php?id=edc1e79db0b6&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadb3aecgadd3deffadb3de93de73aecbaaedd9g4aaefdaaaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.35140000000000005,
#   'postedDate': '2020-05-30T01:18:29.056Z',
#   'updatedDate': '2020-05-30T01:18:29.056Z',
#   'provider': 'neuvoo',
#   'bullet': '4 yrs of experience in Test Automation using Python',
#   'bullets': ['4 yrs of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'automation tester', 'uniquenessScore': 0.269},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:18:29.056Z',
#   'status': 'active',
#   'shortId': 'xPE9xJ',
#   'companyShortId': 'zGxooN',
#   'tags': ['opencv',
#    'automation tester',
#    'test automation',
#    'robot',
#    'python',
#    'hands on',
#    'library',
#    'coding',
#    'experience']},
#  {'id': 'af1ef1679f9469dc306867e22eba9bbb0b99c18b70815d8947db1720e417209d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Data analyst with Python',
#   'url': 'https://www.ziprecruiter.com/k/t/AALecNKlE-bkJx-U3zt9HmfAi3UEnlQJLyQCWSN6zLNrcxPVPm12-TS2CJ8U7qLK94v8tucj7VnWUnGM_ky-6NLZvkAqYqU2M_06zWq2ya85j-Jw4L52DqRvcCwfsnJTqj-qcTm_i--AYhS1Btlas2vLzDRNlMph8Dvw0A9RJ5eVy4qSwX6LgiB5NbEh3eSQVsXTjWNYU2B75ZElxrS4ubNTBHyNuovGH-SHqFq1L80YQHQFxXyaSe_9ErhSubUHaeNM6rEKIsikPBTPZm8e8zRN0RDhA3XKorD9mDPUXQWwBponytPXw_WVQpUYshhiEWB29nhzE9io9PBj9Jnn2lPtC6VgZoGiVIfcUjXqzwrgPQ',
#   'company': 'Two95 International Inc.',
#   'location_city': 'New York',
#   'location_state': 'NY',
#   'location_latitude': 40.74179,
#   'location_longitude': -73.999332,
#   'score': 0.3521787545787546,
#   'postedDate': '2020-05-28T22:46:34.000Z',
#   'updatedDate': '2020-05-30T18:04:39.697Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Data analyst with Python',
#   'bullets': ['Title: Data analyst with Python',
#    'Experience with SQL (Teradata, Oracle)',
#    'Familiarity with Python frameworks such as Django, Flask, Pyramid.',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Familiarity with event-driven programming in Python'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'teradata', 'uniquenessScore': 0.162},
#    {'value': 'pyramid', 'uniquenessScore': 0.14},
#    {'value': 'data analyst', 'uniquenessScore': 0.078},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'oracle', 'uniquenessScore': 0.026},
#    {'value': 'sql', 'uniquenessScore': 0.023},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'event', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:39.697Z',
#   'status': 'active',
#   'shortId': 'gQQ71l',
#   'companyShortId': 'yoPqYw',
#   'tags': ['flask',
#    'django',
#    'threading',
#    'teradata',
#    'pyramid',
#    'data analyst',
#    'python',
#    'oracle',
#    'sql',
#    'architecture',
#    'programming',
#    'event',
#    'process',
#    'title',
#    'experience']},
#  {'id': '48189aac0b1b8f7d416fc571a454a3983fcc7101d94c6ecec6ebacb29318de95',
#   'type': 'sponsoredToOrganic',
#   'title': 'Pyton Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJBMn7YDdELza40wo8nSs2nJtef1U-Gj8CO1lfzY0ghYp3U_r30TdhTflRRDqFIYFk9Pc2G6OAtu3DugtYS6fThzSh30IF9i_S647paAf3vUu8gGH9_Y3cdtkah0-dKnfHLlBuy3IvY0Dsb0pNjpyUMXkDwY7jTZ-cRTTkbZ16-lOFGnITP3sjKJ5uB-w8JSSP2sviBHLJWK1AnKLVgzLneS2H3VhrUgILzB1nC94uM5xu8WwpWQ5p8gyPnjlBU3xJrTTTbrGTT2dmVCnwk4x3ENmWxyKDMYlUpUkUScCyn9eG0leVb0AER8seBKQN3AWOJc6OveBIj-cJhc01fViPdjLU',
#   'company': 'Conflux Systems Inc.',
#   'location_city': 'Sanger',
#   'location_state': 'CA',
#   'location_latitude': 36.78402,
#   'location_longitude': -119.4687,
#   'score': 0.24978461538461535,
#   'postedDate': '2020-05-21T05:16:49.000Z',
#   'updatedDate': '2020-05-30T18:08:49.533Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Python Developer',
#   'bullets': ['Title: Python Developer',
#    'Python developer with excellent skills in for data processing and data mining.',
#    'Should have excellent knowledge in Python scripting',
#    'Must have handled large data file / database using Python objects',
#    'Experience in BFSI domain'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'data mining', 'uniquenessScore': 0.112},
#    {'value': 'data processing', 'uniquenessScore': 0.084},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'file', 'uniquenessScore': 0.01},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:49.533Z',
#   'status': 'active',
#   'shortId': 'E46REx',
#   'companyShortId': 'ye3mXV',
#   'tags': ['python developer',
#    'data mining',
#    'data processing',
#    'domain',
#    'database',
#    'file',
#    'skills',
#    'title',
#    'experience']},
#  {'id': '19c729f4839f259829d1ccb69a00bb57bd2a5ec53b9d9d0d8e739d5cee527f17',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJFkPXyGCKR1H0P0P4lbHa_qSVR2RdN3Jf2qTux5466Ex4MJWnJYuXMwPnbLqbKJIj7or5pLbBdHe_LNPUpvmfPks8aEIe0BrVHYgkMWrL9KQ0zCVlXacT33ugWaumYRedU-8MV03hKhobPppLlDsX12FkcDG-v7RwZ5cHlCxRgJHSUd3Epj7XBpFZHtMNZ56OkKmXvXC4Js0k17qtIkrRYUu3SNpOu54OTSEfOr8v1FNwT68-lOQckhW-L9179m-VQ3IS7OwmguLG2GxfBCY70B2JSgD-C2MWApMF9I9z5IFbzJqeXKu8wd6Joxc7NqLWQHucqHxRnKtRFuImvEfUi_mi6EDV7',
#   'company': 'IntelliPro Group Inc.',
#   'location_city': 'Mountain View',
#   'location_state': 'CA',
#   'location_latitude': 37.412894,
#   'location_longitude': -122.04989,
#   'score': 0.2490761904761905,
#   'postedDate': '2020-05-15T10:45:17.000Z',
#   'updatedDate': '2020-05-30T18:04:01.181Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#   'bullets': ['Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#    'The project is to migrate critical internal systems to Python 3 or Java by the end of 2019, such that there is no service interruption to the pipeline and systems on 01/01/2020.',
#    'The work is expected to continue into 2020, and it should also complete the migration of non-critical systems written in Python 2.7 to Python 3 or Java by end of Q2 2020.',
#    'Refactor existing Python 2.7 code to continue to function into 2020 and beyond by upgrading to Python 3, or re-write in Java.',
#    'Investigate the code and identify Python 2.7 libraries, and update the code to use Google approved Python 3 libraries.'],
#   'keywords': [{'value': 'q2', 'uniquenessScore': 0.186},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'migration', 'uniquenessScore': 0.073},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'apps', 'uniquenessScore': 0.041},
#    {'value': 'pipeline', 'uniquenessScore': 0.037},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'investigate', 'uniquenessScore': 0.034},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'write', 'uniquenessScore': 0.01},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'google', 'uniquenessScore': 0.006},
#    {'value': 'project', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'service', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:01.181Z',
#   'status': 'active',
#   'shortId': 'j3KPab',
#   'companyShortId': 'NqnZ0y',
#   'tags': ['q2',
#    'backend',
#    'migration',
#    'python',
#    'apps',
#    'pipeline',
#    'software engineer',
#    'investigate',
#    'java',
#    'parts',
#    'write',
#    'web',
#    'google',
#    'project',
#    'systems',
#    'code',
#    'service']},
#  {'id': 'fabdb7b4c116874f947468bee8018aee771fb3e4677a10bede179f0674ed970a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=244ab4aa01ac&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdde3decgddc3aeffade3dec3aef3aefbdagdd9f4aaffaadaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Diverse Lynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3610153846153846,
#   'postedDate': '2020-05-30T00:37:56.160Z',
#   'updatedDate': '2020-05-30T00:37:56.160Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Entry Level Python Developer',
#   'bullets': ['Role: Entry Level Python Developer',
#    'Job Description for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:37:56.160Z',
#   'status': 'active',
#   'shortId': '4ZAxA3',
#   'companyShortId': 'wYKRpN',
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'library',
#    'entry level',
#    'graduate',
#    'job',
#    'experience']},
#  {'id': '79792ee6ac23bac56caea374b45e6572930e37e8037b9115f4d38d48d7e0abc8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer (VBA / Python Developer)',
#   'url': 'https://neuvoo.com/job.php?id=732c9a24afcd&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd93dedgdde3aedfdd73aef3dee3decbaafda9a4aadfaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'idexcel Technologies',
#   'location_city': 'Boston',
#   'location_state': 'Massachusetts',
#   'location_latitude': 42.345258,
#   'location_longitude': -71.078871,
#   'score': 0.46863736263736266,
#   'postedDate': '2020-05-30T00:53:55.240Z',
#   'updatedDate': '2020-05-30T00:53:55.240Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Software Engineer (VBA / Python Developer)',
#   'bullets': ['Role: Software Engineer (VBA / Python Developer)',
#    'We are looking for a Software Engineer (VBA / Python) for our client, Fidelity Investments.',
#    'Programmer who is able to program in both VBA as well as Python for MS Excel',
#    'MS Excel programming experience in creating macros, plugins and modules with both VBA and Python',
#    'They are looking for a developer who can program in VBA and Python.'],
#   'keywords': [{'value': 'fidelity investments', 'uniquenessScore': 0.239},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'vba', 'uniquenessScore': 0.152},
#    {'value': 'programmer', 'uniquenessScore': 0.063},
#    {'value': 'ms excel', 'uniquenessScore': 0.063},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:53:55.240Z',
#   'status': 'active',
#   'shortId': '4pmQQ6',
#   'companyShortId': 'z3jDpw',
#   'tags': ['fidelity investments',
#    'python developer',
#    'vba',
#    'programmer',
#    'ms excel',
#    'software engineer',
#    'programming',
#    'client',
#    'experience']},
#  {'id': 'f6846d2400b38e2f726fdb132b601a144329f6dbaf68e6f90ac01a8ee810c614',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=061d99d0d3c4&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8ddgfdda3def8adcfdd73de7gadc3deg3aec3dedbaaddd9c4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'Georgia',
#   'location_latitude': 33.775206,
#   'location_longitude': -84.389428,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-29T22:09:20.937Z',
#   'updatedDate': '2020-05-29T22:09:20.937Z',
#   'provider': 'neuvoopremium',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:09:20.937Z',
#   'status': 'active',
#   'shortId': 'rRQPoQ',
#   'companyShortId': 'zjGa44',
#   'tags': ['florida blue',
#    'python developer',
#    'backend',
#    'batch',
#    'coding',
#    'programming',
#    'api',
#    'information technology',
#    'processing',
#    'solutions',
#    'development',
#    'enable',
#    'experience']},
#  {'id': '5612ce01752a95238ee86a0da2af54918f16ee3592c580d43dd09e375308744b',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=8499018c4c73&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8dd8fddc3de78dd7fddg3defgdd83aed3dec3aedbda9dd9d4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'New Jersey',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-29T22:18:10.579Z',
#   'updatedDate': '2020-05-29T22:18:10.579Z',
#   'provider': 'neuvoopremium',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:18:10.579Z',
#   'status': 'active',
#   'shortId': '7Dmx1W',
#   'companyShortId': 'N5gYBw',
#   'tags': ['flask',
#    'python developer',
#    'django',
#    'spring boot',
#    'threading',
#    'microservices',
#    'fabric',
#    'next generation',
#    'architecture',
#    'analytics',
#    'regulatory',
#    'web',
#    'growing',
#    'building',
#    'data',
#    'process',
#    'team',
#    'title',
#    'experience',
#    'search',
#    'business']},
#  {'id': '18f6dcc864fc65276b125ba4cd4eee4bf87b01264d92ce2ae1abc82e897111ef',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44whgff?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'NJ',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:05:15.998Z',
#   'provider': 'jobnet',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:05:15.998Z',
#   'status': 'active',
#   'shortId': 'dLoXDd',
#   'companyShortId': 'N5gYBw',
#   'tags': ['flask',
#    'python developer',
#    'django',
#    'spring boot',
#    'threading',
#    'microservices',
#    'fabric',
#    'next generation',
#    'architecture',
#    'analytics',
#    'regulatory',
#    'web',
#    'growing',
#    'building',
#    'data',
#    'process',
#    'team',
#    'title',
#    'experience',
#    'search',
#    'business']},
#  {'id': 'fb8f578ce30e7068ee1e24af6c2a7dba83048000f99397bc08f4aab9ad6c5c5c',
#   'type': 'sponsoredToOrganic',
#   'title': 'Sr. Python Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALrZfq-fF-ViSW8mpZinXH4QANiyFn2QwMnWhpDpFxrq6ittTNXmhsyfQZ9UhAlXjJ-Ymd4w9VXSbWpTdIMz0qsCcvruA3CIbkPwuq1kl1YFCLkGCgWSWVmwKHLJg_Ohiuq6uzZgxGn46U6jWR-LZ5qtg1NevPzzBvpNXYG5IWKsOqeV-BgPenDwAfkdFW9rEqjsg2SSnUxyw52ntRj4o906WVtJ7aljBTR3njrU5_Rlo2MvGERgnnSG1lN0iHrhOFA5NbjDFCZpcS3QcBe0qG1tRdXsQdbrBm_iLyq4kZgcbG7qo8BivA9jA8TuSf8L2nmIWoKQ8wNnVPWY6WY',
#   'company': 'HCL Global',
#   'location_city': 'Jacksonville',
#   'location_state': 'FL',
#   'location_latitude': 30.466832,
#   'location_longitude': -81.547848,
#   'score': 0.32817728937728935,
#   'postedDate': '2020-05-21T16:07:24.000Z',
#   'updatedDate': '2020-05-30T18:08:55.508Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#   'bullets': ['Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#    'Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    'Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    'Must have demonstrated experience processing batch files using Python',
#    'To implement Enterprise Business API using Python-based on RESTful Service architectural style.'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'architectural', 'uniquenessScore': 0.051},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'style', 'uniquenessScore': 0.013},
#    {'value': 'enterprise', 'uniquenessScore': 0.012},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'needed', 'uniquenessScore': 0.003},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'service', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:55.508Z',
#   'status': 'active',
#   'shortId': 'V3Jn8n',
#   'companyShortId': 'NmO7vv',
#   'tags': ['florida blue',
#    'python developer',
#    'backend',
#    'batch',
#    'architectural',
#    'coding',
#    'api',
#    'programming',
#    'information technology',
#    'style',
#    'enterprise',
#    'processing',
#    'needed',
#    'solutions',
#    'development',
#    'enable',
#    'service',
#    'experience',
#    'business']},
#  {'id': '6bedddc9528fd855dae03c97d37e4166b490eef7bead768837c88f5f690d7fca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44suek3?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'GA',
#   'location_latitude': 33.855904,
#   'location_longitude': -84.395303,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:03:57.464Z',
#   'provider': 'jobnet',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:03:57.464Z',
#   'status': 'active',
#   'shortId': 'qae3BM',
#   'companyShortId': 'zjGa44',
#   'tags': ['florida blue',
#    'python developer',
#    'backend',
#    'batch',
#    'coding',
#    'programming',
#    'api',
#    'information technology',
#    'processing',
#    'solutions',
#    'development',
#    'enable',
#    'experience']},
#  {'id': 'a5d56fd67e2b60b3163613a45055c0f91809066134ab9d2bb92f53399ea78eca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Developer / Analyst - Job ID TXho_6060',
#   'url': 'https://www.ziprecruiter.com/k/t/AAI2Gvqr0BOL5q7PlkPh1-diyQYTkyHnqmCQ28rZyt0Lek39SOPkEwToDvFgibsGCOnt8_sYhmIyf_XOL83xQUZ4UUtDP5I4ZJ8H0_ZBczmIkaqagLMLpxFz1nzaqzbVkH_OQCmNegUvyiSMCtrAIJrSHmAlEcMs7qm3RxtO2y7irwHlO6J_yZXWHSioeL0wSvvBce0iaw__OucN4pbAtPBX_amdk6qRq3enItqClVR8zOTekA1BJhjlSGaaZQ6b5JAgmMJBhjymQNWeCdTRciOMTmm8BXepvalEoEv70Nb4biqvASiK4y59bDWo--eZbozbOqXqXPfFiMWl-m8KhwmE51-5mqfR1ixSCN9MGpVvRZpk7PeSv1wMrfpKXkodehGVQDKi2g',
#   'company': 'Talbridge Corporation',
#   'location_city': 'Houston',
#   'location_state': 'TX',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.5984886446886447,
#   'postedDate': '2020-05-02T13:18:04.000Z',
#   'updatedDate': '2020-05-30T04:04:48.588Z',
#   'provider': 'ziprecruiterpriority',
#   'bullet': 'Senior Python Developer / Analyst',
#   'bullets': ['Senior Python Developer / Analyst',
#    'Experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for Mid Continental Business Unit.',
#    '· Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '· Data Science domain exposure – very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T04:04:48.588Z',
#   'status': 'active',
#   'shortId': 'apWGmB',
#   'companyShortId': 'Nm1DVN',
#   'tags': ['databricks',
#    'tensorflow',
#    'python developer',
#    'upstream',
#    'continental',
#    'data science',
#    'azure',
#    'nice',
#    'domain',
#    'houston tx',
#    'test',
#    'global',
#    'analyst',
#    'code',
#    'technology',
#    'development',
#    'team',
#    'application',
#    'support',
#    'job',
#    'business']},
#  {'id': '76c5baaca2e404b080ace05f1673c51385e84a9abd392a3c72eac3779988d260',
#   'type': 'sponsoredToOrganic',
#   'title': 'Contract: Senior Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=bee9098ec9c4&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aebgadb3de7fddg3de73de83aebbaaddd974aadfdacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'EXPATS DIRECT LIMITED',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.6350043956043956,
#   'postedDate': '2020-05-30T01:08:56.906Z',
#   'updatedDate': '2020-05-30T01:08:56.906Z',
#   'provider': 'neuvoo',
#   'bullet': 'The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#   'bullets': ['The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for MCBU, AES NOJV.',
#    '-Our Client is seeking an experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    '-Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '-Data Science domain exposure - very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'aes', 'uniquenessScore': 0.225},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'contract', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'business', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:56.906Z',
#   'status': 'active',
#   'shortId': 'PbXQmV',
#   'companyShortId': 'N51apb',
#   'tags': ['databricks',
#    'tensorflow',
#    'python developer',
#    'aes',
#    'upstream',
#    'continental',
#    'data science',
#    'azure',
#    'domain',
#    'houston tx',
#    'nice',
#    'global',
#    'analyst',
#    'test',
#    'contract',
#    'client',
#    'technology',
#    'code',
#    'development',
#    'business',
#    'application',
#    'team',
#    'support']},
#  {'id': 'ecd49eb280663b6dc45cf1af4eac791531774beaf045c87393904b4571e23e98',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAIQxM_YapLU_T7yJ5L5XtRXEod5el4E8JKR96Ra9VSAO7Va1hcJVrGHjGPRjA4HimawnJhLiOpVJGuLrlOZh7typ0WzBA7-nwL-660ZKzFledZNJ_-8RE4Kf4JutCI6XRI-wiCJ-GCiN_sdl6SSqxNlJtdIrAeHVqYdZglMC6hn81Jul5_jhoQlMeDhT5yYq6oX2bIfvOdeVNVEPcLSvVNfpzTzK5PHfgvXz-nH_tPnvQzAib8DPv57b9e6o6CssfvNCkN5e5oWZWZKQ5WDOXzRhFFzxHbHFVDg32vSPwQS9AxVGn8LczTqHpJRTHLD9C5DqFfp4N50Bq7LLA7uC1XoYQWPa6NWfQ',
#   'company': 'IdeasJam',
#   'location_city': 'Remote',
#   'location_state': 'OR',
#   'location_latitude': 43.1148,
#   'location_longitude': -124.1568,
#   'score': 0.552541391941392,
#   'postedDate': '2020-05-16T09:36:59.000Z',
#   'updatedDate': '2020-05-29T18:06:24.038Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#   'bullets': ['This is a full stack developer role working in a fast paced environment.',
#    'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#    'Engineer should have a strong understanding of the back-end technologies (Python/Django), front-end technologies (any main JavaScript framework), and strong understandings of DevOps (preferably Docker).',
#    'Maintaining and improving Django / python-based DevOps using Docker.',
#    'Understanding of the threading limitations of Python, and multi-process architecture'],
#   'keywords': [{'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'full stack developer', 'uniquenessScore': 0.14},
#    {'value': 'docker', 'uniquenessScore': 0.12},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'fast paced', 'uniquenessScore': 0.015},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002}],
#   'validThrough': '2020-05-31T18:06:24.038Z',
#   'status': 'active',
#   'shortId': '5D9QQV',
#   'companyShortId': 'Kp21DK',
#   'tags': ['python django',
#    'python developer',
#    'threading',
#    'full stack developer',
#    'docker',
#    'devops',
#    'front end',
#    'software engineer',
#    'architecture',
#    'fast paced',
#    'javascript',
#    'process']},
#  {'id': 'ea38cd2cfbbc0d2429681e167da8ce7b042f878cfad9200502387a44bc70a4ee',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAKFf09aUc1d6Z_YUgdjw3Ps_jrL-vzXkVQk0wC6Ko2KS72Z9IjwqRISBbmej0x2-_qlRLXQ6O-wdmbtkQMquXswZSF58pIivQfgpmSohBI2ZctVAmKBAIk9iR0Hj-EAIWOlg8Pu6_QEKgSQ25laFL3FCXRCSe6voViciQRNsk4h5kZZILc5XmZzbHisrTbJ-cMTvNruM3FqsqV6YCAhDEMa0snaJ7NNIg2sqjO9yu2r9kliM3ENULbpkJp4hOtIn1meZyhSDMgYa8qcAQbavJgDRUlIapULPNJ9IrFRJ16LiTpnU3OHOwGDx2yQfjoxczvkkYjt_1-ty5Yxvw',
#   'company': 'Resolvit, LLC',
#   'location_city': 'Cincinnati',
#   'location_state': 'OH',
#   'location_latitude': 39.103702,
#   'location_longitude': -84.532826,
#   'score': 0.4737619047619048,
#   'postedDate': '2020-05-06T16:45:51.000Z',
#   'updatedDate': '2020-05-30T04:05:22.872Z',
#   'provider': 'ziprecruiterpriority',
#   'bullet': 'Join Resolvit as a Python Developer and be part of a creative, forward-thinking team.',
#   'bullets': ['Join Resolvit as a Python Developer and be part of a creative, forward-thinking team.',
#    'As the Python Developer , you will be part of the team building our core platform.',
#    'Expertise in Python and knowledge of at least one Python web framework such as Django or Flask',
#    'Understanding of the threading limitations of Python and multi-process architecture',
#    'Resolvit is an international technology consulting firm with industry-leading customers in the financial services, high tech, manufacturing, retail, life sciences, and government sectors.'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'high tech', 'uniquenessScore': 0.134},
#    {'value': 'consulting firm', 'uniquenessScore': 0.079},
#    {'value': 'team building', 'uniquenessScore': 0.055},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'financial services', 'uniquenessScore': 0.021},
#    {'value': 'creative', 'uniquenessScore': 0.012},
#    {'value': 'manufacturing', 'uniquenessScore': 0.011},
#    {'value': 'international', 'uniquenessScore': 0.01},
#    {'value': 'government', 'uniquenessScore': 0.01},
#    {'value': 'core', 'uniquenessScore': 0.009},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'retail', 'uniquenessScore': 0.004},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'industry', 'uniquenessScore': 0.002}],
#   'validThrough': '2020-06-01T04:05:22.872Z',
#   'status': 'active',
#   'shortId': 'ZDlxQO',
#   'companyShortId': 'wLQLrz',
#   'tags': ['flask',
#    'python developer',
#    'django',
#    'threading',
#    'high tech',
#    'consulting firm',
#    'team building',
#    'architecture',
#    'financial services',
#    'creative',
#    'manufacturing',
#    'international',
#    'government',
#    'core',
#    'web',
#    'retail',
#    'process',
#    'industry']},
#  {'id': 'e88d9874e7ae1b7826b1844d5bcdf00d4ed10de59b7e47c0ac30d3d2cb9b004c',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALvvfuV-n_bPA_lf1ErpjVy6eLrQatLlNt9bDPv1nmQv0vD3rVI70-0jWOAHmLhbOd8dhFSYczMydF6YnlK_PLkZVMTffDyf1mf4xtOPQgiI7T30ZehbpSUERkdWUXGcx5eMWWhT6UxGjE4qsPCE-lc1j3RSj3-RAFpZIPAEFc1EBlla0CBHU55lOHKHMyibJuMMl6th1pwsjKTLbgK6F5s44vCYwYX0iOJKnUATVip0pshldwxRXqeYBaOTq6Dk7nOlzkG0fDuXw-9acWRTp6TItklSRDHVU0XtbXpKhkV2cJ5x6n73oK8bSIf1duE217giRVQRDisIOqS',
#   'company': 'ConsultAdd',
#   'location_city': 'Jackson Township',
#   'location_state': 'NJ',
#   'location_latitude': 40.10682,
#   'location_longitude': -74.34102,
#   'score': 0.5083289377289377,
#   'postedDate': '2020-05-21T17:32:56.000Z',
#   'updatedDate': '2020-05-30T18:09:02.176Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'You will be developing software using Python, PostgreSQL, and Flask to improve the performance of enterprise websites with millions of pages.',
#   'bullets': ['You will be developing software using Python, PostgreSQL, and Flask to improve the performance of enterprise websites with millions of pages.',
#    'Knowledge of frameworks like Django and flask.',
#    'RESPONSIBILITIES: Develop, test, debug, and document Python applications that utilize Python and Flask.',
#    'Develop microservices using Python that will serve data to other products within the company',
#    'Ability to refactor portions of an existing product currently implemented in Python, Perl, and PostgreSQL.'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'postgresql', 'uniquenessScore': 0.173},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'perl', 'uniquenessScore': 0.084},
#    {'value': 'enterprise', 'uniquenessScore': 0.012},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'document', 'uniquenessScore': 0.006},
#    {'value': 'software', 'uniquenessScore': 0.005},
#    {'value': 'performance', 'uniquenessScore': 0.003},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'company', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:09:02.176Z',
#   'status': 'active',
#   'shortId': 'ORxEg7',
#   'companyShortId': 'y8m9YK',
#   'tags': ['flask',
#    'python developer',
#    'django',
#    'postgresql',
#    'microservices',
#    'perl',
#    'enterprise',
#    'test',
#    'document',
#    'software',
#    'performance',
#    'data',
#    'company']},
#  {'id': 'b0dddf2a8b18886af78dbd386388e7745e1f2cc45f4c761e695f0620a29b1e2a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://neuvoo.com/job.php?id=0299d23767dd&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddg3deegdd73de7fadc3dee3ded3de9bdaadd994aacfaacaea33de83ee3fbdbgbddecdcded38ddf8ddbgdd7',
#   'company': 'Enflux',
#   'location_city': 'San Antonio',
#   'location_state': 'Texas',
#   'location_latitude': 29.561734,
#   'location_longitude': -98.355891,
#   'score': 0.27550549450549455,
#   'postedDate': '2020-05-31T00:31:38.033Z',
#   'updatedDate': '2020-05-31T00:31:38.033Z',
#   'provider': 'neuvoo',
#   'bullet': "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#   'bullets': ['Enflux is seeking a Software Engineer to be a core part of our development team.',
#    "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#    "There are parts of Python you love, parts of Python you'd change, but you appreciate the undeniable power of Python to help you get things done.",
#    'Experience with Elasticsearch',
#    'No visa sponsorship is available for this position'],
#   'keywords': [{'value': 'elasticsearch', 'uniquenessScore': 0.223},
#    {'value': 'no visa', 'uniquenessScore': 0.156},
#    {'value': 'mid level', 'uniquenessScore': 0.127},
#    {'value': 'visa sponsorship', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'saas', 'uniquenessScore': 0.062},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'core', 'uniquenessScore': 0.009},
# ...
#    'If you are a Senior Software Engineer (Full-Stack focused on Back-end) with Python (Django) and some Front-end JavaScript (TypeScript / Angular / React / Vue) experience, then please read on.',
#    '- Python (Django) with some front-end (JavaScript)',
#    '- REST API design and implementation with Django',
#    '- Docker / Kubernetes'],
#   'keywords': [{'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'vue', 'uniquenessScore': 0.267},
#    {'value': 'typescript', 'uniquenessScore': 0.255},
#    {'value': 'kubernetes', 'uniquenessScore': 0.183},
#    {'value': 'docker', 'uniquenessScore': 0.12},
#    {'value': 'senior software engineer', 'uniquenessScore': 0.089},
#    {'value': 'angular', 'uniquenessScore': 0.081},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'react', 'uniquenessScore': 0.05},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'implementation', 'uniquenessScore': 0.01},
#    {'value': 'design', 'uniquenessScore': 0.006},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:11:14.472Z',
#   'status': 'active',
#   'shortId': 'e5Yd5M',
#   'companyShortId': 'NZR30e',
#   'tags': ['python django',
#    'vue',
#    'typescript',
#    'kubernetes',
#    'docker',
#    'senior software engineer',
#    'angular',
#    'backend',
#    'full stack',
#    'react',
#    'front end',
#    'api',
#    'javascript',
#    'implementation',
#    'design',
#    'experience']},
#  {'id': '09bc4b705c429556aaaabee1fb87718d244ddf6353f10244ec51c7efbed0f8ff',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer (python, aws, rest)',
#   'url': 'https://neuvoo.com/job.php?id=4d5f505a0035&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddc3aecgddb3aeafddb3deg3deb3aefbdagdd9g4dadfdabaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Concepts IT Inc',
#   'location_city': 'San Diego',
#   'location_state': 'California',
#   'location_latitude': 32.676375,
#   'location_longitude': -117.06526,
#   'score': 0.5511142857142858,
#   'postedDate': '2020-05-30T00:46:06.989Z',
#   'updatedDate': '2020-05-30T00:46:06.989Z',
#   'provider': 'neuvoo',
#   'bullet': 'Python Developer (python, aws, rest)',
#   'bullets': ['Python Developer (python, aws, rest)',
#    'Job title: Python Developer with AWS - Contract position (Upto 5 yrs preferred looking for junior professionals only)',
#    'Experience with cloud services like AWS or Microsoft Azure.',
#    'Experience with Docker container related technologies like Kubernetes, Mesos, etc.',
#    'Experience with automated deployments and source code / configuration management tools - GitHub, AWS CloudFormation, Jenkins, Chef, Ansible, Puppet, Vagrant, Terraform, etc.'],
#   'keywords': [{'value': 'terraform', 'uniquenessScore': 0.263},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'microsoft azure', 'uniquenessScore': 0.195},
#    {'value': 'kubernetes', 'uniquenessScore': 0.183},
#    {'value': 'ansible', 'uniquenessScore': 0.151},
#    {'value': 'puppet', 'uniquenessScore': 0.134},
#    {'value': 'docker', 'uniquenessScore': 0.12},
#    {'value': 'contract position', 'uniquenessScore': 0.1},
#    {'value': 'jenkins', 'uniquenessScore': 0.097},
#    {'value': 'configuration management', 'uniquenessScore': 0.079},
#    {'value': 'aws', 'uniquenessScore': 0.055},
#    {'value': 'chef', 'uniquenessScore': 0.046},
#    {'value': 'container', 'uniquenessScore': 0.043},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'cloud', 'uniquenessScore': 0.021},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'job', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:46:06.989Z',
#   'status': 'active',
#   'shortId': 'b4PVYa',
#   'companyShortId': 'z1dKoe',
#   'tags': ['terraform',
#    'python developer',
#    'microsoft azure',
#    'kubernetes',
#    'ansible',
#    'puppet',
#    'docker',
#    'contract position',
#    'jenkins',
#    'configuration management',
#    'aws',
#    'chef',
#    'container',
#    'junior',
#    'cloud',
#    'code',
#    'title',
#    'experience',
#    'job']},
#  {'id': '77703e2744f36a84bdb7b060e597ddf9ee14b74dd14a25b315a2b46d99833af5',
#   'type': 'sponsoredToOrganic',
#   'title': 'Backend Developer - Python',
#   'url': 'https://neuvoo.com/job.php?id=42235ec4636e&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddc3deegdde3dedfddb3aeb3aed3decbdaadd9d4daafaabaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Open Systems Technologies',
#   'location_city': 'Bloomfield',
#   'location_state': 'Connecticut',
#   'location_latitude': 41.839367,
#   'location_longitude': -72.741195,
#   'score': 0.3473355311355312,
#   'postedDate': '2020-05-30T00:44:02.880Z',
#   'updatedDate': '2020-05-30T00:44:02.880Z',
#   'provider': 'neuvoo',
#   'bullet': 'Our client is seeking a Backend Developer - Python to join their team in Bloomfield, CT, New York City, or Charlotte, NC.',
#   'bullets': ['Our client is seeking a Backend Developer - Python to join their team in Bloomfield, CT, New York City, or Charlotte, NC.',
#    'Advanced Python programming skills for Application development; 7+ years with OO Language (Python, Go, Scala, Java)',
#    'Experience with developing RESTful web services or a web framework (Spring, Django, Rails)',
#    'CI/CD experience (Jenkins, Ansible, etc.)',
#    'Big Data (Hadoop, Spark, Teradata) experience'],
#   'keywords': [{'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'teradata', 'uniquenessScore': 0.162},
#    {'value': 'ansible', 'uniquenessScore': 0.151},
#    {'value': 'scala', 'uniquenessScore': 0.147},
#    {'value': 'jenkins', 'uniquenessScore': 0.097},
#    {'value': 'hadoop', 'uniquenessScore': 0.089},
#    {'value': 'spark', 'uniquenessScore': 0.085},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'big data', 'uniquenessScore': 0.057},
#    {'value': 'charlotte nc', 'uniquenessScore': 0.041},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'spring', 'uniquenessScore': 0.028},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'ct', 'uniquenessScore': 0.022},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'language', 'uniquenessScore': 0.01},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'york', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:44:02.880Z',
#   'status': 'active',
#   'shortId': '11jWoj',
#   'companyShortId': 'zx16gN',
#   'tags': ['django',
#    'teradata',
#    'ansible',
#    'scala',
#    'jenkins',
#    'hadoop',
#    'spark',
#    'backend',
#    'big data',
#    'charlotte nc',
#    'python',
#    'spring',
#    'java',
#    'ct',
#    'programming',
#    'developer',
#    'language',
#    'web',
#    'york',
#    'client',
#    'development',
#    'skills',
#    'team',
#    'application',
#    'experience']},
#  {'id': '2064c5c44e40384cfe3f09871424a4ff0f0ac6bf44c3e832c854386ef93f6989',
#   'type': 'sponsoredToOrganic',
#   'title': 'Backend Engineer - Python',
#   'url': 'https://neuvoo.com/job.php?id=a71dd2db68a4&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8adffdd93def8adcfadc3deegadc3aee3dea3de8baafdd9c4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'Open Systems Technologies',
#   'location_city': 'Charlotte',
#   'location_state': 'North Carolina',
#   'location_latitude': 35.198282,
#   'location_longitude': -80.830604,
#   'score': 0.3625355311355311,
#   'postedDate': '2020-05-29T22:20:45.713Z',
#   'updatedDate': '2020-05-29T22:20:45.713Z',
#   'provider': 'neuvoopremium',
#   'bullet': 'Our client is seeking a Backend Developer - Python to join their team in Bloomfield, CT, New York City, or Charlotte, NC.',
#   'bullets': ['Our client is seeking a Backend Developer - Python to join their team in Bloomfield, CT, New York City, or Charlotte, NC.',
#    'Advanced Python programming skills for Application development; 7+ years with OO Language (Python, Go, Scala, Java)',
#    'Experience with developing RESTful web services or a web framework (Spring, Django, Rails)',
#    'CI/CD experience (Jenkins, Ansible, etc.)',
#    'Big Data (Hadoop, Spark, Teradata) experience'],
#   'keywords': [{'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'teradata', 'uniquenessScore': 0.162},
#    {'value': 'ansible', 'uniquenessScore': 0.151},
#    {'value': 'scala', 'uniquenessScore': 0.147},
#    {'value': 'jenkins', 'uniquenessScore': 0.097},
#    {'value': 'hadoop', 'uniquenessScore': 0.089},
#    {'value': 'spark', 'uniquenessScore': 0.085},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'bloomfield', 'uniquenessScore': 0.076},
#    {'value': 'big data', 'uniquenessScore': 0.057},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'charlotte nc', 'uniquenessScore': 0.041},
#    {'value': 'spring', 'uniquenessScore': 0.028},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'ct', 'uniquenessScore': 0.022},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'language', 'uniquenessScore': 0.01},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'york', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:20:45.713Z',
#   'status': 'active',
#   'shortId': 'QOVagE',
#   'companyShortId': 'zx16gN',
#   'tags': ['django',
#    'teradata',
#    'ansible',
#    'scala',
#    'jenkins',
#    'hadoop',
#    'spark',
#    'backend',
#    'bloomfield',
#    'big data',
#    'python',
#    'charlotte nc',
#    'spring',
#    'java',
#    'ct',
#    'programming',
#    'developer',
#    'engineer',
#    'language',
#    'web',
#    'york',
#    'client',
#    'development',
#    'skills',
#    'team',
#    'experience',
#    'application']},
#  {'id': '8a622fb9f0c385cf001bbfbe3d33e7eb41e3e2fc5f76b05bb1ed7bcb234033b5',
#   'type': 'sponsoredToOrganic',
#   'title': 'VMware Developer',
#   'url': 'https://neuvoo.com/job.php?id=dca0d36cb874&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadc3aedgadf3degfadc3ded3dea3aedbaaedd984da9fdacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'eTeam Inc.',
#   'location_city': 'Cary',
#   'location_state': 'North Carolina',
#   'location_latitude': 35.80541,
#   'location_longitude': -78.797679,
#   'score': 0.26409743589743595,
#   'postedDate': '2020-05-30T01:14:57.001Z',
#   'updatedDate': '2020-05-30T01:14:57.001Z',
#   'provider': 'neuvoo',
#   'bullet': '5+ years of years of experience in application development using Python, Ansible.',
#   'bullets': ['5+ years of years of experience in application development using Python, Ansible.',
#    'Hands-on experience in API integration using Python',
#    'Hands-on experience with Database programming (Cloudant, Postgres)',
#    'Hands-on experience in building application software modules/components like (Building Integration API, Automation Script, new methods/function etc.)',
#    'Hands-on experience in writing test automation scripts using Python/ansible'],
#   'keywords': [{'value': 'ansible', 'uniquenessScore': 0.151},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'vmware', 'uniquenessScore': 0.072},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'script', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'integration', 'uniquenessScore': 0.018},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'writing', 'uniquenessScore': 0.01},
#    {'value': 'software', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:14:57.001Z',
#   'status': 'active',
#   'shortId': 'DJG1eE',
#   'companyShortId': 'z2Zjrz',
#   'tags': ['ansible',
#    'test automation',
#    'vmware',
#    'python',
#    'hands on',
#    'programming',
#    'script',
#    'api',
#    'developer',
#    'integration',
#    'database',
#    'writing',
#    'software',
#    'building',
#    'development',
#    'experience',
#    'application']},
#  {'id': '7fbc7c87c86686f7dbf338cff0944e3636db00968975a2a9a3b45f1dae569e20',
#   'type': 'sponsoredToOrganic',
#   'title': 'Linux/Unix Systems Technical Operations Manager – Trading Firm',
#   'url': 'https://neuvoo.com/job.php?id=c03a66f5f1a7&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadd3deggddd3aeffdda3dea3aea3debbaaadd9f4aaffda9aea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'REQUEST TECHNOLOGY',
#   'location_city': 'Chicago',
#   'location_state': 'Illinois',
#   'location_latitude': 41.968521,
#   'location_longitude': -87.703667,
#   'score': 0.2877545787545787,
#   'postedDate': '2020-05-30T01:09:23.594Z',
#   'updatedDate': '2020-05-30T01:09:23.594Z',
#   'provider': 'neuvoo',
#   'bullet': 'MUST have industry experience, Unix/Linus skills, hands-on, backend operations, DevOps skills, Python.',
#   'bullets': ['Looking for a candidate from a trading firm that grew up as a Linux Sytems Engineer and moved into management.',
#    'MUST have industry experience, Unix/Linus skills, hands-on, backend operations, DevOps skills, Python.',
#    'Strong scripting skills (unix shell and python).',
#    'Basic database knowledge (Sybase, MySQL).',
#    'Tagged as: linux, Management, python, trading, unix'],
#   'keywords': [{'value': 'sybase', 'uniquenessScore': 0.233},
#    {'value': 'mysql', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'shell', 'uniquenessScore': 0.071},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'trading', 'uniquenessScore': 0.065},
#    {'value': 'unix', 'uniquenessScore': 0.051},
#    {'value': 'operations manager', 'uniquenessScore': 0.043},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'linux', 'uniquenessScore': 0.036},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'firm', 'uniquenessScore': 0.015},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'basic', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'technical', 'uniquenessScore': 0.003},
#    {'value': 'industry', 'uniquenessScore': 0.002},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'management', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:09:23.594Z',
#   'status': 'active',
#   'shortId': '3kPqX5',
#   'companyShortId': 'yKqroz',
#   'tags': ['sybase',
#    'mysql',
#    'backend',
#    'shell',
#    'devops',
#    'trading',
#    'unix',
#    'operations manager',
#    'python',
#    'linux',
#    'hands on',
#    'database',
#    'firm',
#    'engineer',
#    'basic',
#    'systems',
#    'technical',
#    'industry',
#    'skills',
#    'management',
#    'experience']}]

# %%
df = pd.DataFrame.from_dict(flat)

# %%
type(flat)
# Out:
# list

# %%
flat
# Out:
# [{'id': '451c129852855c7fc5386e026d3fada198667042bd172fd2129274d0a9d6a560',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=844eb003d441&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83decgddc3aebfade3deg3deg3dedbaacdd9c4dacfdafaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3230307692307693,
#   'postedDate': '2020-05-30T00:57:19.331Z',
#   'updatedDate': '2020-05-30T00:57:19.331Z',
#   'provider': 'neuvoo',
#   'bullet': 'for Entry Level Python Developer',
#   'bullets': ['for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge of Python and Robot framework',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:57:19.331Z',
#   'status': 'active',
#   'shortId': 'v2Yd7a',
#   'companyShortId': 'zGxooN'},
#  {'id': '9486dd4822788545ef9176ba609b7fd22693d2320321745e9c3228cdfe6b00d8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Lead Full Stack Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=3a21bce968ad&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddd3aefgdde3deffade3aed3aeb3de7bdaadd984aaffaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'PeopleNTech LLC',
#   'location_city': 'Chandler',
#   'location_state': 'Arizona',
#   'location_latitude': 33.306009,
#   'location_longitude': -111.91928,
#   'score': 0.38537606837606836,
#   'postedDate': '2020-05-30T00:42:16.175Z',
#   'updatedDate': '2020-05-30T00:42:16.175Z',
#   'provider': 'neuvoo',
#   'bullet': 'Position- Lead Full Stack Python Developer',
#   'bullets': ['Position- Lead Full Stack Python Developer',
#    'Need someone with Python Full Stack web application background to be the lead.',
#    'Lead Full Stack Python Developer with Python based API WebServices building skills + Javascript Framework knowledge'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'lead', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'background', 'uniquenessScore': 0.003},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:42:16.175Z',
#   'status': 'active',
#   'shortId': '0VJlgp',
#   'companyShortId': 'N0XEWN'},
#  {'id': '19c729f4839f259829d1ccb69a00bb57bd2a5ec53b9d9d0d8e739d5cee527f17',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJFkPXyGCKR1H0P0P4lbHa_qSVR2RdN3Jf2qTux5466Ex4MJWnJYuXMwPnbLqbKJIj7or5pLbBdHe_LNPUpvmfPks8aEIe0BrVHYgkMWrL9KQ0zCVlXacT33ugWaumYRedU-8MV03hKhobPppLlDsX12FkcDG-v7RwZ5cHlCxRgJHSUd3Epj7XBpFZHtMNZ56OkKmXvXC4Js0k17qtIkrRYUu3SNpOu54OTSEfOr8v1FNwT68-lOQckhW-L9179m-VQ3IS7OwmguLG2GxfBCY70B2JSgD-C2MWApMF9I9z5IFbzJqeXKu8wd6Joxc7NqLWQHucqHxRnKtRFuImvEfUi_mi6EDV7',
#   'company': 'IntelliPro Group Inc.',
#   'location_city': 'Mountain View',
#   'location_state': 'CA',
#   'location_latitude': 37.412894,
#   'location_longitude': -122.04989,
#   'score': 0.2490761904761905,
#   'postedDate': '2020-05-15T10:45:17.000Z',
#   'updatedDate': '2020-05-30T18:04:01.181Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#   'bullets': ['Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#    'The project is to migrate critical internal systems to Python 3 or Java by the end of 2019, such that there is no service interruption to the pipeline and systems on 01/01/2020.',
#    'The work is expected to continue into 2020, and it should also complete the migration of non-critical systems written in Python 2.7 to Python 3 or Java by end of Q2 2020.',
#    'Refactor existing Python 2.7 code to continue to function into 2020 and beyond by upgrading to Python 3, or re-write in Java.',
#    'Investigate the code and identify Python 2.7 libraries, and update the code to use Google approved Python 3 libraries.'],
#   'keywords': [{'value': 'q2', 'uniquenessScore': 0.186},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'migration', 'uniquenessScore': 0.073},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'apps', 'uniquenessScore': 0.041},
#    {'value': 'pipeline', 'uniquenessScore': 0.037},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'investigate', 'uniquenessScore': 0.034},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'write', 'uniquenessScore': 0.01},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'google', 'uniquenessScore': 0.006},
#    {'value': 'project', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'service', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:01.181Z',
#   'status': 'active',
#   'shortId': 'j3KPab',
#   'companyShortId': 'NqnZ0y'},
#  {'id': 'ed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e68ab2617751522b7954d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Automation Tester with Python',
#   'url': 'https://neuvoo.com/job.php?id=edc1e79db0b6&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadb3aecgadd3deffadb3de93de73aecbaaedd9g4aaefdaaaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.35140000000000005,
#   'postedDate': '2020-05-30T01:18:29.056Z',
#   'updatedDate': '2020-05-30T01:18:29.056Z',
#   'provider': 'neuvoo',
#   'bullet': '4 yrs of experience in Test Automation using Python',
#   'bullets': ['4 yrs of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'automation tester', 'uniquenessScore': 0.269},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:18:29.056Z',
#   'status': 'active',
#   'shortId': 'xPE9xJ',
#   'companyShortId': 'zGxooN'},
#  {'id': 'af1ef1679f9469dc306867e22eba9bbb0b99c18b70815d8947db1720e417209d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Data analyst with Python',
#   'url': 'https://www.ziprecruiter.com/k/t/AALecNKlE-bkJx-U3zt9HmfAi3UEnlQJLyQCWSN6zLNrcxPVPm12-TS2CJ8U7qLK94v8tucj7VnWUnGM_ky-6NLZvkAqYqU2M_06zWq2ya85j-Jw4L52DqRvcCwfsnJTqj-qcTm_i--AYhS1Btlas2vLzDRNlMph8Dvw0A9RJ5eVy4qSwX6LgiB5NbEh3eSQVsXTjWNYU2B75ZElxrS4ubNTBHyNuovGH-SHqFq1L80YQHQFxXyaSe_9ErhSubUHaeNM6rEKIsikPBTPZm8e8zRN0RDhA3XKorD9mDPUXQWwBponytPXw_WVQpUYshhiEWB29nhzE9io9PBj9Jnn2lPtC6VgZoGiVIfcUjXqzwrgPQ',
#   'company': 'Two95 International Inc.',
#   'location_city': 'New York',
#   'location_state': 'NY',
#   'location_latitude': 40.74179,
#   'location_longitude': -73.999332,
#   'score': 0.3521787545787546,
#   'postedDate': '2020-05-28T22:46:34.000Z',
#   'updatedDate': '2020-05-30T18:04:39.697Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Data analyst with Python',
#   'bullets': ['Title: Data analyst with Python',
#    'Experience with SQL (Teradata, Oracle)',
#    'Familiarity with Python frameworks such as Django, Flask, Pyramid.',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Familiarity with event-driven programming in Python'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'teradata', 'uniquenessScore': 0.162},
#    {'value': 'pyramid', 'uniquenessScore': 0.14},
#    {'value': 'data analyst', 'uniquenessScore': 0.078},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'oracle', 'uniquenessScore': 0.026},
#    {'value': 'sql', 'uniquenessScore': 0.023},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'event', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:39.697Z',
#   'status': 'active',
#   'shortId': 'gQQ71l',
#   'companyShortId': 'yoPqYw'},
#  {'id': '48189aac0b1b8f7d416fc571a454a3983fcc7101d94c6ecec6ebacb29318de95',
#   'type': 'sponsoredToOrganic',
#   'title': 'Pyton Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJBMn7YDdELza40wo8nSs2nJtef1U-Gj8CO1lfzY0ghYp3U_r30TdhTflRRDqFIYFk9Pc2G6OAtu3DugtYS6fThzSh30IF9i_S647paAf3vUu8gGH9_Y3cdtkah0-dKnfHLlBuy3IvY0Dsb0pNjpyUMXkDwY7jTZ-cRTTkbZ16-lOFGnITP3sjKJ5uB-w8JSSP2sviBHLJWK1AnKLVgzLneS2H3VhrUgILzB1nC94uM5xu8WwpWQ5p8gyPnjlBU3xJrTTTbrGTT2dmVCnwk4x3ENmWxyKDMYlUpUkUScCyn9eG0leVb0AER8seBKQN3AWOJc6OveBIj-cJhc01fViPdjLU',
#   'company': 'Conflux Systems Inc.',
#   'location_city': 'Sanger',
#   'location_state': 'CA',
#   'location_latitude': 36.78402,
#   'location_longitude': -119.4687,
#   'score': 0.24978461538461535,
#   'postedDate': '2020-05-21T05:16:49.000Z',
#   'updatedDate': '2020-05-30T18:08:49.533Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Python Developer',
#   'bullets': ['Title: Python Developer',
#    'Python developer with excellent skills in for data processing and data mining.',
#    'Should have excellent knowledge in Python scripting',
#    'Must have handled large data file / database using Python objects',
#    'Experience in BFSI domain'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'data mining', 'uniquenessScore': 0.112},
#    {'value': 'data processing', 'uniquenessScore': 0.084},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'file', 'uniquenessScore': 0.01},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:49.533Z',
#   'status': 'active',
#   'shortId': 'E46REx',
#   'companyShortId': 'ye3mXV'},
#  {'id': 'fabdb7b4c116874f947468bee8018aee771fb3e4677a10bede179f0674ed970a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=244ab4aa01ac&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdde3decgddc3aeffade3dec3aef3aefbdagdd9f4aaffaadaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Diverse Lynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3610153846153846,
#   'postedDate': '2020-05-30T00:37:56.160Z',
#   'updatedDate': '2020-05-30T00:37:56.160Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Entry Level Python Developer',
#   'bullets': ['Role: Entry Level Python Developer',
#    'Job Description for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:37:56.160Z',
#   'status': 'active',
#   'shortId': '4ZAxA3',
#   'companyShortId': 'wYKRpN'},
#  {'id': '27970c6ac8d7eb957aa9bfc9aaabd2774670c5106b8fb6faccf9aca18aa58562',
#   'type': 'sponsoredToOrganic',
#   'title': 'Test Automation with Python',
#   'url': 'https://neuvoo.com/job.php?id=bb290c5c640b&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aeegdde3de7fddg3aed3deb3aedbdaadd9c4dagfaaeaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3520153846153846,
#   'postedDate': '2020-05-30T01:08:28.107Z',
#   'updatedDate': '2020-05-30T01:08:28.107Z',
#   'provider': 'neuvoo',
#   'bullet': '4 years of experience in Test Automation using Python',
#   'bullets': ['4 years of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:28.107Z',
#   'status': 'active',
#   'shortId': 'gvq1VE',
#   'companyShortId': 'zGxooN'},
#  {'id': '6754967c6158574200aacdb6f0bd4a94ce37c851ca619d9499416e8db1aec9f4',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://www.jobg8.com/Traffic.aspx?naCS%2fiGCVXm5EbYWGHo0LAa',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'New Jersey',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-29T00:08:46.155Z',
#   'updatedDate': '2020-05-29T00:08:46.155Z',
#   'provider': 'jobg8',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T00:08:46.155Z',
#   'status': 'active',
#   'shortId': '9XgDOj',
#   'companyShortId': 'N5gYBw'},
#  {'id': '5612ce01752a95238ee86a0da2af54918f16ee3592c580d43dd09e375308744b',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=8499018c4c73&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8dd8fddc3de78dd7fddg3defgdd83aed3dec3aedbda9dd9d4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'New Jersey',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-29T22:18:10.579Z',
#   'updatedDate': '2020-05-29T22:18:10.579Z',
#   'provider': 'neuvoopremium',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:18:10.579Z',
#   'status': 'active',
#   'shortId': '7Dmx1W',
#   'companyShortId': 'N5gYBw'},
#  {'id': '18f6dcc864fc65276b125ba4cd4eee4bf87b01264d92ce2ae1abc82e897111ef',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44whgff?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'NJ',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:05:15.998Z',
#   'provider': 'jobnet',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:05:15.998Z',
#   'status': 'active',
#   'shortId': 'dLoXDd',
#   'companyShortId': 'N5gYBw'},
#  {'id': '79792ee6ac23bac56caea374b45e6572930e37e8037b9115f4d38d48d7e0abc8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer (VBA / Python Developer)',
#   'url': 'https://neuvoo.com/job.php?id=732c9a24afcd&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd93dedgdde3aedfdd73aef3dee3decbaafda9a4aadfaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'idexcel Technologies',
#   'location_city': 'Boston',
#   'location_state': 'Massachusetts',
#   'location_latitude': 42.345258,
#   'location_longitude': -71.078871,
#   'score': 0.46863736263736266,
#   'postedDate': '2020-05-30T00:53:55.240Z',
#   'updatedDate': '2020-05-30T00:53:55.240Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Software Engineer (VBA / Python Developer)',
#   'bullets': ['Role: Software Engineer (VBA / Python Developer)',
#    'We are looking for a Software Engineer (VBA / Python) for our client, Fidelity Investments.',
#    'Programmer who is able to program in both VBA as well as Python for MS Excel',
#    'MS Excel programming experience in creating macros, plugins and modules with both VBA and Python',
#    'They are looking for a developer who can program in VBA and Python.'],
#   'keywords': [{'value': 'fidelity investments', 'uniquenessScore': 0.239},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'vba', 'uniquenessScore': 0.152},
#    {'value': 'programmer', 'uniquenessScore': 0.063},
#    {'value': 'ms excel', 'uniquenessScore': 0.063},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:53:55.240Z',
#   'status': 'active',
#   'shortId': '4pmQQ6',
#   'companyShortId': 'z3jDpw'},
#  {'id': 'fb8f578ce30e7068ee1e24af6c2a7dba83048000f99397bc08f4aab9ad6c5c5c',
#   'type': 'sponsoredToOrganic',
#   'title': 'Sr. Python Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALrZfq-fF-ViSW8mpZinXH4QANiyFn2QwMnWhpDpFxrq6ittTNXmhsyfQZ9UhAlXjJ-Ymd4w9VXSbWpTdIMz0qsCcvruA3CIbkPwuq1kl1YFCLkGCgWSWVmwKHLJg_Ohiuq6uzZgxGn46U6jWR-LZ5qtg1NevPzzBvpNXYG5IWKsOqeV-BgPenDwAfkdFW9rEqjsg2SSnUxyw52ntRj4o906WVtJ7aljBTR3njrU5_Rlo2MvGERgnnSG1lN0iHrhOFA5NbjDFCZpcS3QcBe0qG1tRdXsQdbrBm_iLyq4kZgcbG7qo8BivA9jA8TuSf8L2nmIWoKQ8wNnVPWY6WY',
#   'company': 'HCL Global',
#   'location_city': 'Jacksonville',
#   'location_state': 'FL',
#   'location_latitude': 30.466832,
#   'location_longitude': -81.547848,
#   'score': 0.32817728937728935,
#   'postedDate': '2020-05-21T16:07:24.000Z',
#   'updatedDate': '2020-05-30T18:08:55.508Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#   'bullets': ['Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#    'Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    'Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    'Must have demonstrated experience processing batch files using Python',
#    'To implement Enterprise Business API using Python-based on RESTful Service architectural style.'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'architectural', 'uniquenessScore': 0.051},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'style', 'uniquenessScore': 0.013},
#    {'value': 'enterprise', 'uniquenessScore': 0.012},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'needed', 'uniquenessScore': 0.003},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'service', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:55.508Z',
#   'status': 'active',
#   'shortId': 'V3Jn8n',
#   'companyShortId': 'NmO7vv'},
#  {'id': 'f6846d2400b38e2f726fdb132b601a144329f6dbaf68e6f90ac01a8ee810c614',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=061d99d0d3c4&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8ddgfdda3def8adcfdd73de7gadc3deg3aec3dedbaaddd9c4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'Georgia',
#   'location_latitude': 33.775206,
#   'location_longitude': -84.389428,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-29T22:09:20.937Z',
#   'updatedDate': '2020-05-29T22:09:20.937Z',
#   'provider': 'neuvoopremium',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:09:20.937Z',
#   'status': 'active',
#   'shortId': 'rRQPoQ',
#   'companyShortId': 'zjGa44'},
#  {'id': 'a5d56fd67e2b60b3163613a45055c0f91809066134ab9d2bb92f53399ea78eca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Developer / Analyst - Job ID TXho_6060',
#   'url': 'https://www.ziprecruiter.com/k/t/AAI2Gvqr0BOL5q7PlkPh1-diyQYTkyHnqmCQ28rZyt0Lek39SOPkEwToDvFgibsGCOnt8_sYhmIyf_XOL83xQUZ4UUtDP5I4ZJ8H0_ZBczmIkaqagLMLpxFz1nzaqzbVkH_OQCmNegUvyiSMCtrAIJrSHmAlEcMs7qm3RxtO2y7irwHlO6J_yZXWHSioeL0wSvvBce0iaw__OucN4pbAtPBX_amdk6qRq3enItqClVR8zOTekA1BJhjlSGaaZQ6b5JAgmMJBhjymQNWeCdTRciOMTmm8BXepvalEoEv70Nb4biqvASiK4y59bDWo--eZbozbOqXqXPfFiMWl-m8KhwmE51-5mqfR1ixSCN9MGpVvRZpk7PeSv1wMrfpKXkodehGVQDKi2g',
#   'company': 'Talbridge Corporation',
#   'location_city': 'Houston',
#   'location_state': 'TX',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.5984886446886447,
#   'postedDate': '2020-05-02T13:18:04.000Z',
#   'updatedDate': '2020-05-30T04:04:48.588Z',
#   'provider': 'ziprecruiterpriority',
#   'bullet': 'Senior Python Developer / Analyst',
#   'bullets': ['Senior Python Developer / Analyst',
#    'Experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for Mid Continental Business Unit.',
#    '· Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '· Data Science domain exposure – very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T04:04:48.588Z',
#   'status': 'active',
#   'shortId': 'apWGmB',
#   'companyShortId': 'Nm1DVN'},
#  {'id': 'c768672ccf49e22eb3313855ffbe79cf850a948340e92591b7ccc37de1a3f605',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://www.jobg8.com/Traffic.aspx?RIGW%2ftw9s6tvQE16t%2fcwaAc',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'Georgia',
#   'location_latitude': 33.855904,
#   'location_longitude': -84.395303,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-29T00:04:55.861Z',
#   'updatedDate': '2020-05-29T00:04:55.861Z',
#   'provider': 'jobg8',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T00:04:55.861Z',
#   'status': 'active',
#   'shortId': 'EREBaG',
#   'companyShortId': 'zjGa44'},
#  {'id': '6bedddc9528fd855dae03c97d37e4166b490eef7bead768837c88f5f690d7fca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44suek3?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'GA',
#   'location_latitude': 33.855904,
#   'location_longitude': -84.395303,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:03:57.464Z',
#   'provider': 'jobnet',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:03:57.464Z',
#   'status': 'active',
#   'shortId': 'qae3BM',
#   'companyShortId': 'zjGa44'},
#  {'id': '76c5baaca2e404b080ace05f1673c51385e84a9abd392a3c72eac3779988d260',
#   'type': 'sponsoredToOrganic',
#   'title': 'Contract: Senior Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=bee9098ec9c4&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aebgadb3de7fddg3de73de83aebbaaddd974aadfdacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'EXPATS DIRECT LIMITED',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.6350043956043956,
#   'postedDate': '2020-05-30T01:08:56.906Z',
#   'updatedDate': '2020-05-30T01:08:56.906Z',
#   'provider': 'neuvoo',
#   'bullet': 'The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#   'bullets': ['The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for MCBU, AES NOJV.',
#    '-Our Client is seeking an experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    '-Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '-Data Science domain exposure - very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'aes', 'uniquenessScore': 0.225},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'contract', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'business', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:56.906Z',
#   'status': 'active',
#   'shortId': 'PbXQmV',
#   'companyShortId': 'N51apb'},
#  {'id': 'b0dddf2a8b18886af78dbd386388e7745e1f2cc45f4c761e695f0620a29b1e2a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://neuvoo.com/job.php?id=ca9a27c53913&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadd3aefgdd73aeffdde3de93aed3debbdaddd974daffdadaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Enflux',
#   'location_city': 'San Antonio',
#   'location_state': 'Texas',
#   'location_latitude': 29.561734,
#   'location_longitude': -98.355891,
#   'score': 0.27550549450549455,
#   'postedDate': '2020-05-30T01:11:20.246Z',
#   'updatedDate': '2020-05-30T01:11:20.246Z',
#   'provider': 'neuvoo',
#   'bullet': "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#   'bullets': ['Enflux is seeking a Software Engineer to be a core part of our development team.',
#    "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#    "There are parts of Python you love, parts of Python you'd change, but you appreciate the undeniable power of Python to help you get things done.",
#    'Experience with Elasticsearch',
#    'No visa sponsorship is available for this position'],
#   'keywords': [{'value': 'elasticsearch', 'uniquenessScore': 0.223},
#    {'value': 'no visa', 'uniquenessScore': 0.156},
#    {'value': 'mid level', 'uniquenessScore': 0.127},
#    {'value': 'visa sponsorship', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'saas', 'uniquenessScore': 0.062},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'core', 'uniquenessScore': 0.009},
#    {'value': 'change', 'uniquenessScore': 0.005},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'available', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'help', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:11:20.246Z',
#   'status': 'active',
#   'shortId': '5JY9R4',
#   'companyShortId': 'yAd1b4'},
#  {'id': 'ecd49eb280663b6dc45cf1af4eac791531774beaf045c87393904b4571e23e98',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAIQxM_YapLU_T7yJ5L5XtRXEod5el4E8JKR96Ra9VSAO7Va1hcJVrGHjGPRjA4HimawnJhLiOpVJGuLrlOZh7typ0WzBA7-nwL-660ZKzFledZNJ_-8RE4Kf4JutCI6XRI-wiCJ-GCiN_sdl6SSqxNlJtdIrAeHVqYdZglMC6hn81Jul5_jhoQlMeDhT5yYq6oX2bIfvOdeVNVEPcLSvVNfpzTzK5PHfgvXz-nH_tPnvQzAib8DPv57b9e6o6CssfvNCkN5e5oWZWZKQ5WDOXzRhFFzxHbHFVDg32vSPwQS9AxVGn8LczTqHpJRTHLD9C5DqFfp4N50Bq7LLA7uC1XoYQWPa6NWfQ',
#   'company': 'IdeasJam',
#   'location_city': 'Remote',
#   'location_state': 'OR',
#   'location_latitude': 43.1148,
#   'location_longitude': -124.1568,
#   'score': 0.552541391941392,
#   'postedDate': '2020-05-16T09:36:59.000Z',
#   'updatedDate': '2020-05-29T18:06:24.038Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#   'bullets': ['This is a full stack developer role working in a fast paced environment.',
#    'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#    'Engineer should have a strong understanding of the back-end technologies (Python/Django), front-end technologies (any main JavaScript framework), and strong understandings of DevOps (preferably Docker).',
#    'Maintaining and improving Django / python-based DevOps using Docker.',
#    'Understanding of the threading limitations of Python, and multi-process architecture'],
#   'keywords': [{'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'full stack developer', 'uniquenessScore': 0.14},
#    {'value': 'docker', 'uniquenessScore': 0.12},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'fast paced', 'uniquenessScore': 0.015},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002}],
#   'validThrough': '2020-05-31T18:06:24.038Z',
#   'status': 'active',
#   'shortId': '5D9QQV',
#   'companyShortId': 'Kp21DK'},
#  {'id': '185b51af9bb8b23af47c615f6bb791cd689d0942c5d5e24029afa80b664bed06',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Data Engineer',
#   'url': 'https://neuvoo.com/job.php?id=f74c7a022f06&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gada3de9gddc3aedfdd93aef3deg3deebdaeda9a4dagfdaaaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Shimento Inc',
#   'location_city': 'San Francisco',
#   'location_state': 'California',
#   'location_latitude': 37.79801,
#   'location_longitude': -122.39696,
#   'score': 0.8355860805860807,
#   'postedDate': '2020-05-30T01:20:24.892Z',
#   'updatedDate': '2020-05-30T01:20:24.892Z',
#   'provider': 'neuvoo',
#   'bullet': 'Title: Senior Python Data Engineer',
#   'bullets': ['Title: Senior Python Data Engineer',
#    'Senior Python Data Engineer',
#    'We are currently looking for a senior Python Data Engineer to join our asset and Liability Technology team providing service to Client Corporate Treasury.',
#    'Senior Python Data Engineer is responsible to create reusable framework using Python to streamline data process within ALM Treasury.',
#    'Conduct and manage strategic analyses of Data Engineering environment to manage High volume data using custom pipe replacing existing SSIS data extraction process.'],
#   'keywords': [{'value': 'python data', 'uniquenessScore': 0.507},
#    {'value': 'data engineering', 'uniquenessScore': 0.236},
#    {'value': 'alm', 'uniquenessScore': 0.163},
#    {'value': 'ssis', 'uniquenessScore': 0.128},
#    {'value': 'extraction', 'uniquenessScore': 0.115},
#    {'value': 'pipe', 'uniquenessScore': 0.082},
#    {'value': 'treasury', 'uniquenessScore': 0.07},
#    {'value': 'streamline', 'uniquenessScore': 0.07},
#    {'value': 'liability', 'uniquenessScore': 0.024},
#    {'value': 'asset', 'uniquenessScore': 0.02},
#    {'value': 'strategic', 'uniquenessScore': 0.011},
#    {'value': 'corporate', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'service', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:20:24.892Z',
#   'status': 'active',
#   'shortId': 'xlWBVY',
#   'companyShortId': 'zQX0jp'},
#  {'id': 'a4536a9eccb22c02631dc2b4da1d2b2b6f4b9385faa7e5f2760776e1a2dfe2d2',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALKsP7aJZ4BmYEBWQCbYbvST-bFkTCU92Rzv7LTJN73XLxOVGIzbNTfWJ2XcLgbryq9EMDZsLZkIqufYWkw3AYk3Crqk3afA1LDUZjagAw3Kb5GS_ToKDhX50zKk1be0h_DmYHT6zqOXMoF5w830-NWsOlzDVffpufurZKevcKN08kPbdT-PY2t1uHSSCNSgqAm87VyGXs5JaO0cpScl_m9UPsdapzidjabweK3HoQ7zH6GzcrwQV-znjCXmNttcWGIK7DHzRC3GRJX-giokO_-j_YwqijkVHhFbjSrvaXVe0APbYEvyje8Dty7aVHOSfs_hj3i0dhMdcs',
#   'company': 'Enflux',
#   'location_city': 'San Antonio',
#   'location_state': 'TX',
#   'location_latitude': 29.561734,
#   'location_longitude': -98.355891,
#   'score': 0.27581318681318684,
#   'postedDate': '2020-05-25T09:18:52.000Z',
#   'updatedDate': '2020-05-30T18:02:54.787Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#   'bullets': ['Enflux is seeking a Software Engineer to be a core part of our development team.',
#    "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#    "There are parts of Python you love, parts of Python you'd change, but you appreciate the undeniable power of Python to help you get things done.",
#    'Experience with Elasticsearch',
#    'No visa sponsorship is available for this position*'],
#   'keywords': [{'value': 'elasticsearch', 'uniquenessScore': 0.223},
#    {'value': 'no visa', 'uniquenessScore': 0.156},
#    {'value': 'mid level', 'uniquenessScore': 0.127},
#    {'value': 'visa sponsorship', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'saas', 'uniquenessScore': 0.062},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'core', 'uniquenessScore': 0.009},
#    {'value': 'change', 'uniquenessScore': 0.005},
# ...
#   'provider': 'neuvoopremium',
#   'bullet': 'If you are an experienced Python Developer looking for a position with a leading company, Bartech can help!',
#   'bullets': ['If you are an experienced Python Developer looking for a position with a leading company, Bartech can help!',
#    'Our client has a need for a Python Developer.',
#    'The candidate should also be familiar with data analysis using Python scripts and SQL database management.',
#    'As a Python Developer you must represent our company well by being responsible, punctual and motivated to go above and beyond the call of duty.',
#    'As a Python Developer with Bartech, you will be working through an established and respected staffing organization with 41 years of serving as a trusted partner to our client companies.'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'sql database', 'uniquenessScore': 0.164},
#    {'value': 'above and beyond', 'uniquenessScore': 0.054},
#    {'value': 'to go', 'uniquenessScore': 0.029},
#    {'value': 'analysis', 'uniquenessScore': 0.008},
#    {'value': 'serving', 'uniquenessScore': 0.007},
#    {'value': 'staffing', 'uniquenessScore': 0.007},
#    {'value': 'partner', 'uniquenessScore': 0.005},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'organization', 'uniquenessScore': 0.004},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'company', 'uniquenessScore': 0.001},
#    {'value': 'management', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:28:31.344Z',
#   'status': 'active',
#   'shortId': 'rRQ5x7',
#   'companyShortId': 'zg3RYz'},
#  {'id': '60aa2ec7afaf8c7ba9d37fd12cc0accf44b99d8740edb9408e0a2e045e256d82',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Development Engineer - AWS SDK for Python (Boto3) and AWS CLI',
#   'url': 'https://joblift.com/details/e8550016-f621-4e5d-b0f5-80f5212af1b5?fecd=OQbXmzdmK&utm_source=kimble_us_dynamic&utm_medium=external_feed&utm_campaign=dynamic',
#   'company': 'Amazon',
#   'location_city': 'Seattle',
#   'location_state': 'Washington',
#   'location_latitude': 47.638776,
#   'location_longitude': -122.36617,
#   'score': 0.38920000000000005,
#   'postedDate': '2020-05-20T07:39:30.000Z',
#   'updatedDate': '2020-05-29T07:14:06.869Z',
#   'provider': 'joblift',
#   'bullet': 'The AWS SDK for Python team is searching for Python developers to build open source tools for AWS in Python.',
#   'bullets': ['The AWS SDK for Python team is searching for Python developers to build open source tools for AWS in Python.',
#    'You will design and implement libraries and features to enable Python developers to harness the power of AWS cloud computing.',
#    'You will have opportunities to present at conferences, blog, develop open source software and engage directly with users.',
#    'Join the AWS SDKs and Tools team and help bring the power of AWS cloud computing to the Python community!',
#    '1+ years of experience contributing to the architecture and design (architecture, design patterns, reliability and scaling) of new and current systems.'],
#   'keywords': [{'value': 'aws cloud', 'uniquenessScore': 0.205},
#    {'value': 'architecture design', 'uniquenessScore': 0.122},
#    {'value': 'harness', 'uniquenessScore': 0.11},
#    {'value': 'cloud computing', 'uniquenessScore': 0.104},
#    {'value': 'open source', 'uniquenessScore': 0.091},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'reliability', 'uniquenessScore': 0.03},
#    {'value': 'engage', 'uniquenessScore': 0.016},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'software', 'uniquenessScore': 0.005},
#    {'value': 'community', 'uniquenessScore': 0.004},
#    {'value': 'blog', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'current', 'uniquenessScore': 0.002},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T07:14:06.869Z',
#   'status': 'active',
#   'shortId': 'Gvd9qg',
#   'companyShortId': 'z4bL3y'},
#  {'id': '42f14c89167c5fbe14ee33d9953c2c7c267e731ddbde9dd3dafacfec630ec020',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python/Django Engineer - URGENT!',
#   'url': 'https://click.appcast.io/track/44rc7cc?cs=5vq&jg=qx9&bid=ZTAIU9X3zQHjJYLb9Yqb8A==',
#   'company': 'CyberCoders',
#   'location_city': 'Madison',
#   'location_state': 'WI',
#   'location_latitude': 43.072549,
#   'location_longitude': -89.402181,
#   'score': 1.3041472527472528,
#   'postedDate': '2020-05-29T00:00:00.000Z',
#   'updatedDate': '2020-05-29T20:29:30.239Z',
#   'provider': 'careerbliss',
#   'bullet': 'If you are a Senior Python/Django Engineer with experience, please read on!',
#   'bullets': ['If you are a Senior Python/Django Engineer with experience, please read on!',
#    'As our main Python Developer, you will be responsible for everything from our back-end technologies (python/django), front-end techs (Vue.js), and some DevOps (Heroku).',
#    'MUST HAVE: - BS in related field OR equivalent professional experience - 3+ years of full-stack engineering experience - 2+ years of experience with Python 3 and Django REST framework - PostgreSQL - Javascript (Vue.js preferably) - Heroku',
#    "NICE TO HAVE: - Vue.js - DevOps - event-driven programming - User Authentication/AuthorizationWhat's In It for You",
#    '- Competitive Salary DOE - Comprehensive Benefits Package - 401K with match - Flexible Schedule - Generous PTOSo, if you are a Senior Python/Django Engineer with experience, please apply today!'],
#   'keywords': [{'value': 'vue js', 'uniquenessScore': 0.816},
#    {'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'postgresql', 'uniquenessScore': 0.173},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'doe', 'uniquenessScore': 0.053},
#    {'value': 'urgent', 'uniquenessScore': 0.043},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'flexible schedule', 'uniquenessScore': 0.017},
#    {'value': 'event', 'uniquenessScore': 0.013},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'package', 'uniquenessScore': 0.007},
#    {'value': '401k', 'uniquenessScore': 0.004},
#    {'value': 'field', 'uniquenessScore': 0.004},
#    {'value': 'salary', 'uniquenessScore': 0.002},
#    {'value': 'professional', 'uniquenessScore': 0.002},
#    {'value': 'today', 'uniquenessScore': 0.002},
#    {'value': 'apply', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'benefits', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T20:29:30.239Z',
#   'status': 'active',
#   'shortId': 'dLn4Zd',
#   'companyShortId': 'yKQboz'},
#  {'id': 'f672c247002c33cb59e1c945171a6b82635bf350662a2b6541097b7d2148fa44',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Engineer - Python, IOT, Agile',
#   'url': 'https://click.appcast.io/track/44rcaz1?cs=5vq&jg=qx9&bid=ZTAIU9X3zQHjJYLb9Yqb8A==',
#   'company': 'CyberCoders',
#   'location_city': 'Costa Mesa',
#   'location_state': 'CA',
#   'location_latitude': 33.680139,
#   'location_longitude': -117.90845,
#   'score': 0.3877443223443223,
#   'postedDate': '2020-05-29T00:00:00.000Z',
#   'updatedDate': '2020-05-29T20:31:48.596Z',
#   'provider': 'careerbliss',
#   'bullet': 'If you are a Senior Python Engineer with experience, please read on!',
#   'bullets': ['If you are a Senior Python Engineer with experience, please read on!',
#    'As a disrupter in the growing sector of IoT, we are looking to add a senior level developer to our team to help with the transfer of our codebase from PHP to Python.',
#    'Our fun office environment, traditional start-up perks, and experienced team will make you feel right at home.',
#    "- Python - IOT - Agile - PostgreSQL - RESTful API's - Django - JQuery - Bootstrap - Azure - GITSo, if you are a Senior Python Engineer with experience, please apply today!",
#    'Category: Technology, Keywords: Python Engineer'],
#   'keywords': [{'value': 'right at home', 'uniquenessScore': 0.255},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'postgresql', 'uniquenessScore': 0.173},
#    {'value': 'iot', 'uniquenessScore': 0.13},
#    {'value': 'bootstrap', 'uniquenessScore': 0.111},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'php', 'uniquenessScore': 0.075},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'jquery', 'uniquenessScore': 0.034},
#    {'value': 'agile', 'uniquenessScore': 0.026},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'transfer', 'uniquenessScore': 0.016},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'fun', 'uniquenessScore': 0.009},
#    {'value': 'category', 'uniquenessScore': 0.006},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'office', 'uniquenessScore': 0.002},
#    {'value': 'today', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'apply', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T20:31:48.596Z',
#   'status': 'active',
#   'shortId': 'X9VegV',
#   'companyShortId': 'yKQboz'},
#  {'id': '95cfe7bf1d8ac67f350ddc1e7124d0fc39715de7c4f7e9f80265428df1fa202f',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python developer',
#   'url': 'https://neuvoo.com/job.php?id=a41e7d61ed5b&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadf3decgddf3aebfdd93aec3dea3defbaabda9c4dabfaaeaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Diverse Lynx',
#   'location_city': 'Winchester',
#   'location_state': 'California',
#   'location_latitude': 33.625979,
#   'location_longitude': -117.06853,
#   'score': 0.3487157509157509,
#   'postedDate': '2020-05-30T01:03:48.741Z',
#   'updatedDate': '2020-05-30T01:03:48.741Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Python developer',
#   'bullets': ['Role: Python developer',
#    '6+ yrs of programming/development experience with expert Coding skills in Python for Mongo DB CRUD operations and in aggregation framework; must have knowledge of MongoDB Clustering and Mongo DB scaling based on work Load.',
#    'Code/develop applications to program specifications for mongoDB / mongoDB Atlas (cloud database).',
#    'Write unit test code, using tools and writing integration test cases using python.',
#    'The software developer should be adept in the following skills: Python, MongoDB or other NoSQL database, Cloud technologies , Linux/Windows as a development environment, data validation frame work using python/Pyspark.'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'atlas', 'uniquenessScore': 0.151},
#    {'value': 'mongodb', 'uniquenessScore': 0.145},
#    {'value': 'software developer', 'uniquenessScore': 0.064},
#    {'value': 'linux', 'uniquenessScore': 0.036},
#    {'value': 'validation', 'uniquenessScore': 0.034},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'cloud', 'uniquenessScore': 0.021},
#    {'value': 'frame', 'uniquenessScore': 0.021},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'cases', 'uniquenessScore': 0.02},
#    {'value': 'integration', 'uniquenessScore': 0.018},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'windows', 'uniquenessScore': 0.014},
#    {'value': 'write', 'uniquenessScore': 0.01},
#    {'value': 'writing', 'uniquenessScore': 0.01},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'operations', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:03:48.741Z',
#   'status': 'active',
#   'shortId': 'Z666EP',
#   'companyShortId': 'wYKRpN'},
#  {'id': 'b3e67e8cd83229661972799f123d6b5b3ddaa8e8148b40031dc9eceb2f345d13',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=87a87cb35b17&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83de9gadf3de8fdd93aed3aee3dedbdabda9e4daffda9aea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'TalentBurst, Inc.',
#   'location_city': 'Merrimack',
#   'location_state': 'New Hampshire',
#   'location_latitude': 42.863038,
#   'location_longitude': -71.516973,
#   'score': 0.6508285714285714,
#   'postedDate': '2020-05-30T00:57:49.173Z',
#   'updatedDate': '2020-05-30T00:57:49.173Z',
#   'provider': 'neuvoo',
#   'bullet': 'We are seeking a savvy Python developer to join our Innovation team and to power Fidelity digital product and services through innovation, collaboration and clarity.',
#   'bullets': ['We are seeking a savvy Python developer to join our Innovation team and to power Fidelity digital product and services through innovation, collaboration and clarity.',
#    'The ideal candidate is a top-tier Python developer who has experience building RESTful backend applications and microservices.',
#    'Hands-on experience with any one of the tools - Python, pandas/numpy, scikit-learn, Jupyter / any Python IDE along with Python or R, AWS / Cloud, Java, RDBMS, REST APIs',
#    'Assist in crafting data pipelines involving data cleaning, transformation, streaming enrichment / analytics and normalization',
#    'Asset Management Technology (AMT) provides worldwide technology and support to all the Investment Management, Research, Trading and Investment Operations functions.'],
#   'keywords': [{'value': 'investment operations', 'uniquenessScore': 0.346},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'aws cloud', 'uniquenessScore': 0.205},
#    {'value': 'amt', 'uniquenessScore': 0.174},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'streaming', 'uniquenessScore': 0.14},
#    {'value': 'crafting', 'uniquenessScore': 0.136},
#    {'value': 'top tier', 'uniquenessScore': 0.132},
#    {'value': 'fidelity', 'uniquenessScore': 0.126},
#    {'value': 'investment management', 'uniquenessScore': 0.089},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'enrichment', 'uniquenessScore': 0.079},
#    {'value': 'clarity', 'uniquenessScore': 0.074},
#    {'value': 'trading', 'uniquenessScore': 0.065},
#    {'value': 'asset management', 'uniquenessScore': 0.054},
#    {'value': 'transformation', 'uniquenessScore': 0.045},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'worldwide', 'uniquenessScore': 0.02},
#    {'value': 'digital', 'uniquenessScore': 0.015},
#    {'value': 'collaboration', 'uniquenessScore': 0.015},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'innovation', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'ideal', 'uniquenessScore': 0.011},
#    {'value': 'cleaning', 'uniquenessScore': 0.01},
#    {'value': 'research', 'uniquenessScore': 0.007},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:57:49.173Z',
#   'status': 'active',
#   'shortId': 'e2VZL5',
#   'companyShortId': 'zvQDlw'}]

# %%
# keys = [n['keywords'] for n in flat]
keys = []
for x in flat:
    keys.append(x['keywords'])
# my_tags = [n['value'] for n in j['keywords'] for j in flat]

# %%
flat
# Out:
# [{'id': '451c129852855c7fc5386e026d3fada198667042bd172fd2129274d0a9d6a560',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=844eb003d441&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83decgddc3aebfade3deg3deg3dedbaacdd9c4dacfdafaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3230307692307693,
#   'postedDate': '2020-05-30T00:57:19.331Z',
#   'updatedDate': '2020-05-30T00:57:19.331Z',
#   'provider': 'neuvoo',
#   'bullet': 'for Entry Level Python Developer',
#   'bullets': ['for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge of Python and Robot framework',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:57:19.331Z',
#   'status': 'active',
#   'shortId': 'v2Yd7a',
#   'companyShortId': 'zGxooN'},
#  {'id': '9486dd4822788545ef9176ba609b7fd22693d2320321745e9c3228cdfe6b00d8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Lead Full Stack Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=3a21bce968ad&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gddd3aefgdde3deffade3aed3aeb3de7bdaadd984aaffaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'PeopleNTech LLC',
#   'location_city': 'Chandler',
#   'location_state': 'Arizona',
#   'location_latitude': 33.306009,
#   'location_longitude': -111.91928,
#   'score': 0.38537606837606836,
#   'postedDate': '2020-05-30T00:42:16.175Z',
#   'updatedDate': '2020-05-30T00:42:16.175Z',
#   'provider': 'neuvoo',
#   'bullet': 'Position- Lead Full Stack Python Developer',
#   'bullets': ['Position- Lead Full Stack Python Developer',
#    'Need someone with Python Full Stack web application background to be the lead.',
#    'Lead Full Stack Python Developer with Python based API WebServices building skills + Javascript Framework knowledge'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'lead', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'background', 'uniquenessScore': 0.003},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:42:16.175Z',
#   'status': 'active',
#   'shortId': '0VJlgp',
#   'companyShortId': 'N0XEWN'},
#  {'id': '19c729f4839f259829d1ccb69a00bb57bd2a5ec53b9d9d0d8e739d5cee527f17',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJFkPXyGCKR1H0P0P4lbHa_qSVR2RdN3Jf2qTux5466Ex4MJWnJYuXMwPnbLqbKJIj7or5pLbBdHe_LNPUpvmfPks8aEIe0BrVHYgkMWrL9KQ0zCVlXacT33ugWaumYRedU-8MV03hKhobPppLlDsX12FkcDG-v7RwZ5cHlCxRgJHSUd3Epj7XBpFZHtMNZ56OkKmXvXC4Js0k17qtIkrRYUu3SNpOu54OTSEfOr8v1FNwT68-lOQckhW-L9179m-VQ3IS7OwmguLG2GxfBCY70B2JSgD-C2MWApMF9I9z5IFbzJqeXKu8wd6Joxc7NqLWQHucqHxRnKtRFuImvEfUi_mi6EDV7',
#   'company': 'IntelliPro Group Inc.',
#   'location_city': 'Mountain View',
#   'location_state': 'CA',
#   'location_latitude': 37.412894,
#   'location_longitude': -122.04989,
#   'score': 0.2490761904761905,
#   'postedDate': '2020-05-15T10:45:17.000Z',
#   'updatedDate': '2020-05-30T18:04:01.181Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#   'bullets': ['Position DescriptionProject Overview: As Python 2.7 is reaching end of life, many parts of our systems require update from Python 2.7 to Python 3, or be re-written in Java. The system consists of both backend pipeline and web apps that are written in Python 2.7.',
#    'The project is to migrate critical internal systems to Python 3 or Java by the end of 2019, such that there is no service interruption to the pipeline and systems on 01/01/2020.',
#    'The work is expected to continue into 2020, and it should also complete the migration of non-critical systems written in Python 2.7 to Python 3 or Java by end of Q2 2020.',
#    'Refactor existing Python 2.7 code to continue to function into 2020 and beyond by upgrading to Python 3, or re-write in Java.',
#    'Investigate the code and identify Python 2.7 libraries, and update the code to use Google approved Python 3 libraries.'],
#   'keywords': [{'value': 'q2', 'uniquenessScore': 0.186},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'migration', 'uniquenessScore': 0.073},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'apps', 'uniquenessScore': 0.041},
#    {'value': 'pipeline', 'uniquenessScore': 0.037},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'investigate', 'uniquenessScore': 0.034},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'write', 'uniquenessScore': 0.01},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'google', 'uniquenessScore': 0.006},
#    {'value': 'project', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'service', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:01.181Z',
#   'status': 'active',
#   'shortId': 'j3KPab',
#   'companyShortId': 'NqnZ0y'},
#  {'id': 'ed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e68ab2617751522b7954d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Automation Tester with Python',
#   'url': 'https://neuvoo.com/job.php?id=edc1e79db0b6&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadb3aecgadd3deffadb3de93de73aecbaaedd9g4aaefdaaaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.35140000000000005,
#   'postedDate': '2020-05-30T01:18:29.056Z',
#   'updatedDate': '2020-05-30T01:18:29.056Z',
#   'provider': 'neuvoo',
#   'bullet': '4 yrs of experience in Test Automation using Python',
#   'bullets': ['4 yrs of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'automation tester', 'uniquenessScore': 0.269},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:18:29.056Z',
#   'status': 'active',
#   'shortId': 'xPE9xJ',
#   'companyShortId': 'zGxooN'},
#  {'id': 'af1ef1679f9469dc306867e22eba9bbb0b99c18b70815d8947db1720e417209d',
#   'type': 'sponsoredToOrganic',
#   'title': 'Data analyst with Python',
#   'url': 'https://www.ziprecruiter.com/k/t/AALecNKlE-bkJx-U3zt9HmfAi3UEnlQJLyQCWSN6zLNrcxPVPm12-TS2CJ8U7qLK94v8tucj7VnWUnGM_ky-6NLZvkAqYqU2M_06zWq2ya85j-Jw4L52DqRvcCwfsnJTqj-qcTm_i--AYhS1Btlas2vLzDRNlMph8Dvw0A9RJ5eVy4qSwX6LgiB5NbEh3eSQVsXTjWNYU2B75ZElxrS4ubNTBHyNuovGH-SHqFq1L80YQHQFxXyaSe_9ErhSubUHaeNM6rEKIsikPBTPZm8e8zRN0RDhA3XKorD9mDPUXQWwBponytPXw_WVQpUYshhiEWB29nhzE9io9PBj9Jnn2lPtC6VgZoGiVIfcUjXqzwrgPQ',
#   'company': 'Two95 International Inc.',
#   'location_city': 'New York',
#   'location_state': 'NY',
#   'location_latitude': 40.74179,
#   'location_longitude': -73.999332,
#   'score': 0.3521787545787546,
#   'postedDate': '2020-05-28T22:46:34.000Z',
#   'updatedDate': '2020-05-30T18:04:39.697Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Data analyst with Python',
#   'bullets': ['Title: Data analyst with Python',
#    'Experience with SQL (Teradata, Oracle)',
#    'Familiarity with Python frameworks such as Django, Flask, Pyramid.',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Familiarity with event-driven programming in Python'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'teradata', 'uniquenessScore': 0.162},
#    {'value': 'pyramid', 'uniquenessScore': 0.14},
#    {'value': 'data analyst', 'uniquenessScore': 0.078},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'oracle', 'uniquenessScore': 0.026},
#    {'value': 'sql', 'uniquenessScore': 0.023},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'event', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:04:39.697Z',
#   'status': 'active',
#   'shortId': 'gQQ71l',
#   'companyShortId': 'yoPqYw'},
#  {'id': '48189aac0b1b8f7d416fc571a454a3983fcc7101d94c6ecec6ebacb29318de95',
#   'type': 'sponsoredToOrganic',
#   'title': 'Pyton Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAJBMn7YDdELza40wo8nSs2nJtef1U-Gj8CO1lfzY0ghYp3U_r30TdhTflRRDqFIYFk9Pc2G6OAtu3DugtYS6fThzSh30IF9i_S647paAf3vUu8gGH9_Y3cdtkah0-dKnfHLlBuy3IvY0Dsb0pNjpyUMXkDwY7jTZ-cRTTkbZ16-lOFGnITP3sjKJ5uB-w8JSSP2sviBHLJWK1AnKLVgzLneS2H3VhrUgILzB1nC94uM5xu8WwpWQ5p8gyPnjlBU3xJrTTTbrGTT2dmVCnwk4x3ENmWxyKDMYlUpUkUScCyn9eG0leVb0AER8seBKQN3AWOJc6OveBIj-cJhc01fViPdjLU',
#   'company': 'Conflux Systems Inc.',
#   'location_city': 'Sanger',
#   'location_state': 'CA',
#   'location_latitude': 36.78402,
#   'location_longitude': -119.4687,
#   'score': 0.24978461538461535,
#   'postedDate': '2020-05-21T05:16:49.000Z',
#   'updatedDate': '2020-05-30T18:08:49.533Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Title: Python Developer',
#   'bullets': ['Title: Python Developer',
#    'Python developer with excellent skills in for data processing and data mining.',
#    'Should have excellent knowledge in Python scripting',
#    'Must have handled large data file / database using Python objects',
#    'Experience in BFSI domain'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'data mining', 'uniquenessScore': 0.112},
#    {'value': 'data processing', 'uniquenessScore': 0.084},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'file', 'uniquenessScore': 0.01},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:49.533Z',
#   'status': 'active',
#   'shortId': 'E46REx',
#   'companyShortId': 'ye3mXV'},
#  {'id': 'fabdb7b4c116874f947468bee8018aee771fb3e4677a10bede179f0674ed970a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Entry Level Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=244ab4aa01ac&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdde3decgddc3aeffade3dec3aef3aefbdagdd9f4aaffaadaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Diverse Lynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3610153846153846,
#   'postedDate': '2020-05-30T00:37:56.160Z',
#   'updatedDate': '2020-05-30T00:37:56.160Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Entry Level Python Developer',
#   'bullets': ['Role: Entry Level Python Developer',
#    'Job Description for Entry Level Python Developer',
#    'Fresh Graduate or Work experience in Test Automation using Python',
#    'Knowledge ofPython Library - OpenCV, Pygui',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:37:56.160Z',
#   'status': 'active',
#   'shortId': '4ZAxA3',
#   'companyShortId': 'wYKRpN'},
#  {'id': '27970c6ac8d7eb957aa9bfc9aaabd2774670c5106b8fb6faccf9aca18aa58562',
#   'type': 'sponsoredToOrganic',
#   'title': 'Test Automation with Python',
#   'url': 'https://neuvoo.com/job.php?id=bb290c5c640b&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aeegdde3de7fddg3aed3deb3aedbdaadd9c4dagfaaeaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'DiverseLynx',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.3520153846153846,
#   'postedDate': '2020-05-30T01:08:28.107Z',
#   'updatedDate': '2020-05-30T01:08:28.107Z',
#   'provider': 'neuvoo',
#   'bullet': '4 years of experience in Test Automation using Python',
#   'bullets': ['4 years of experience in Test Automation using Python',
#    'Hands on experience using Python and Robot framework',
#    'Test Automation using Python Library - OpenCV, Pygui',
#    'Strong experience in coding standards for test automation.',
#    'Develop Test Automation scripts using Python'],
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:28.107Z',
#   'status': 'active',
#   'shortId': 'gvq1VE',
#   'companyShortId': 'zGxooN'},
#  {'id': '6754967c6158574200aacdb6f0bd4a94ce37c851ca619d9499416e8db1aec9f4',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://www.jobg8.com/Traffic.aspx?naCS%2fiGCVXm5EbYWGHo0LAa',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'New Jersey',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-29T00:08:46.155Z',
#   'updatedDate': '2020-05-29T00:08:46.155Z',
#   'provider': 'jobg8',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T00:08:46.155Z',
#   'status': 'active',
#   'shortId': '9XgDOj',
#   'companyShortId': 'N5gYBw'},
#  {'id': '5612ce01752a95238ee86a0da2af54918f16ee3592c580d43dd09e375308744b',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=8499018c4c73&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8dd8fddc3de78dd7fddg3defgdd83aed3dec3aedbda9dd9d4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'New Jersey',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-29T22:18:10.579Z',
#   'updatedDate': '2020-05-29T22:18:10.579Z',
#   'provider': 'neuvoopremium',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:18:10.579Z',
#   'status': 'active',
#   'shortId': '7Dmx1W',
#   'companyShortId': 'N5gYBw'},
#  {'id': '18f6dcc864fc65276b125ba4cd4eee4bf87b01264d92ce2ae1abc82e897111ef',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44whgff?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'DISYS',
#   'location_city': 'Jersey City',
#   'location_state': 'NJ',
#   'location_latitude': 40.733081,
#   'location_longitude': -74.041881,
#   'score': 0.5026652014652015,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:05:15.998Z',
#   'provider': 'jobnet',
#   'bullet': 'Title : Python Developer',
#   'bullets': ['Title : Python Developer',
#    'Elastic Search with Python Developer Markets Data team is building the next generation Data fabric to solve for Business, Analytics and growing regulatory needs.',
#    'Expert in Python, with knowledge of at least one Python web framework (Flask or Django)',
#    'Understanding of the threading limitations of Python, and multi-process architecture',
#    'Experience working in Spring Boot, Microservices based architecture framework'],
#   'keywords': [{'value': 'flask', 'uniquenessScore': 0.371},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'spring boot', 'uniquenessScore': 0.214},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'fabric', 'uniquenessScore': 0.11},
#    {'value': 'next generation', 'uniquenessScore': 0.053},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'regulatory', 'uniquenessScore': 0.012},
#    {'value': 'web', 'uniquenessScore': 0.007},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'search', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:05:15.998Z',
#   'status': 'active',
#   'shortId': 'dLoXDd',
#   'companyShortId': 'N5gYBw'},
#  {'id': '79792ee6ac23bac56caea374b45e6572930e37e8037b9115f4d38d48d7e0abc8',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer (VBA / Python Developer)',
#   'url': 'https://neuvoo.com/job.php?id=732c9a24afcd&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd93dedgdde3aedfdd73aef3dee3decbaafda9a4aadfaacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'idexcel Technologies',
#   'location_city': 'Boston',
#   'location_state': 'Massachusetts',
#   'location_latitude': 42.345258,
#   'location_longitude': -71.078871,
#   'score': 0.46863736263736266,
#   'postedDate': '2020-05-30T00:53:55.240Z',
#   'updatedDate': '2020-05-30T00:53:55.240Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Software Engineer (VBA / Python Developer)',
#   'bullets': ['Role: Software Engineer (VBA / Python Developer)',
#    'We are looking for a Software Engineer (VBA / Python) for our client, Fidelity Investments.',
#    'Programmer who is able to program in both VBA as well as Python for MS Excel',
#    'MS Excel programming experience in creating macros, plugins and modules with both VBA and Python',
#    'They are looking for a developer who can program in VBA and Python.'],
#   'keywords': [{'value': 'fidelity investments', 'uniquenessScore': 0.239},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'vba', 'uniquenessScore': 0.152},
#    {'value': 'programmer', 'uniquenessScore': 0.063},
#    {'value': 'ms excel', 'uniquenessScore': 0.063},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:53:55.240Z',
#   'status': 'active',
#   'shortId': '4pmQQ6',
#   'companyShortId': 'z3jDpw'},
#  {'id': 'fb8f578ce30e7068ee1e24af6c2a7dba83048000f99397bc08f4aab9ad6c5c5c',
#   'type': 'sponsoredToOrganic',
#   'title': 'Sr. Python Developer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALrZfq-fF-ViSW8mpZinXH4QANiyFn2QwMnWhpDpFxrq6ittTNXmhsyfQZ9UhAlXjJ-Ymd4w9VXSbWpTdIMz0qsCcvruA3CIbkPwuq1kl1YFCLkGCgWSWVmwKHLJg_Ohiuq6uzZgxGn46U6jWR-LZ5qtg1NevPzzBvpNXYG5IWKsOqeV-BgPenDwAfkdFW9rEqjsg2SSnUxyw52ntRj4o906WVtJ7aljBTR3njrU5_Rlo2MvGERgnnSG1lN0iHrhOFA5NbjDFCZpcS3QcBe0qG1tRdXsQdbrBm_iLyq4kZgcbG7qo8BivA9jA8TuSf8L2nmIWoKQ8wNnVPWY6WY',
#   'company': 'HCL Global',
#   'location_city': 'Jacksonville',
#   'location_state': 'FL',
#   'location_latitude': 30.466832,
#   'location_longitude': -81.547848,
#   'score': 0.32817728937728935,
#   'postedDate': '2020-05-21T16:07:24.000Z',
#   'updatedDate': '2020-05-30T18:08:55.508Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#   'bullets': ['Developers needed to implement Enterprise Business API using Python-based on RESTful Service architectural style.',
#    'Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    'Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    'Must have demonstrated experience processing batch files using Python',
#    'To implement Enterprise Business API using Python-based on RESTful Service architectural style.'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'architectural', 'uniquenessScore': 0.051},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'style', 'uniquenessScore': 0.013},
#    {'value': 'enterprise', 'uniquenessScore': 0.012},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'needed', 'uniquenessScore': 0.003},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'service', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T18:08:55.508Z',
#   'status': 'active',
#   'shortId': 'V3Jn8n',
#   'companyShortId': 'NmO7vv'},
#  {'id': 'f6846d2400b38e2f726fdb132b601a144329f6dbaf68e6f90ac01a8ee810c614',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=061d99d0d3c4&source=kimblegroup&utm_source=partner&utm_medium=kimblegroup&puid=8ddgfdda3def8adcfdd73de7gadc3deg3aec3dedbaaddd9c4ea3fdafadab3ee3gbdb8bdd1cbccea37dafedab3de7fddggdd9add87d',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'Georgia',
#   'location_latitude': 33.775206,
#   'location_longitude': -84.389428,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-29T22:09:20.937Z',
#   'updatedDate': '2020-05-29T22:09:20.937Z',
#   'provider': 'neuvoopremium',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:09:20.937Z',
#   'status': 'active',
#   'shortId': 'rRQPoQ',
#   'companyShortId': 'zjGa44'},
#  {'id': 'a5d56fd67e2b60b3163613a45055c0f91809066134ab9d2bb92f53399ea78eca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Developer / Analyst - Job ID TXho_6060',
#   'url': 'https://www.ziprecruiter.com/k/t/AAI2Gvqr0BOL5q7PlkPh1-diyQYTkyHnqmCQ28rZyt0Lek39SOPkEwToDvFgibsGCOnt8_sYhmIyf_XOL83xQUZ4UUtDP5I4ZJ8H0_ZBczmIkaqagLMLpxFz1nzaqzbVkH_OQCmNegUvyiSMCtrAIJrSHmAlEcMs7qm3RxtO2y7irwHlO6J_yZXWHSioeL0wSvvBce0iaw__OucN4pbAtPBX_amdk6qRq3enItqClVR8zOTekA1BJhjlSGaaZQ6b5JAgmMJBhjymQNWeCdTRciOMTmm8BXepvalEoEv70Nb4biqvASiK4y59bDWo--eZbozbOqXqXPfFiMWl-m8KhwmE51-5mqfR1ixSCN9MGpVvRZpk7PeSv1wMrfpKXkodehGVQDKi2g',
#   'company': 'Talbridge Corporation',
#   'location_city': 'Houston',
#   'location_state': 'TX',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.5984886446886447,
#   'postedDate': '2020-05-02T13:18:04.000Z',
#   'updatedDate': '2020-05-30T04:04:48.588Z',
#   'provider': 'ziprecruiterpriority',
#   'bullet': 'Senior Python Developer / Analyst',
#   'bullets': ['Senior Python Developer / Analyst',
#    'Experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for Mid Continental Business Unit.',
#    '· Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '· Data Science domain exposure – very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001},
#    {'value': 'job', 'uniquenessScore': 0.001},
#    {'value': 'business', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T04:04:48.588Z',
#   'status': 'active',
#   'shortId': 'apWGmB',
#   'companyShortId': 'Nm1DVN'},
#  {'id': 'c768672ccf49e22eb3313855ffbe79cf850a948340e92591b7ccc37de1a3f605',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://www.jobg8.com/Traffic.aspx?RIGW%2ftw9s6tvQE16t%2fcwaAc',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'Georgia',
#   'location_latitude': 33.855904,
#   'location_longitude': -84.395303,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-29T00:04:55.861Z',
#   'updatedDate': '2020-05-29T00:04:55.861Z',
#   'provider': 'jobg8',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T00:04:55.861Z',
#   'status': 'active',
#   'shortId': 'EREBaG',
#   'companyShortId': 'zjGa44'},
#  {'id': '6bedddc9528fd855dae03c97d37e4166b490eef7bead768837c88f5f690d7fca',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://click.appcast.io/track/44suek3?cs=gpc&jg=1i5m&bid=RjisTn_QvJ_s6s7uxZBkFw==',
#   'company': 'Skiltrek LLC',
#   'location_city': 'Atlanta',
#   'location_state': 'GA',
#   'location_latitude': 33.855904,
#   'location_longitude': -84.395303,
#   'score': 0.3052021978021978,
#   'postedDate': '2020-05-28T00:00:00.000Z',
#   'updatedDate': '2020-05-30T13:03:57.464Z',
#   'provider': 'jobnet',
#   'bullet': '· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#   'bullets': ['· Looking for Python developers who have developed Backend API services using Python and corresponding libraries',
#    '· Responsible for development, programming, coding of Information Technology solutions using Python to enable Florida Blue Customer Experience applications.',
#    '· Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    'Excellent understanding of Python programming mode and required libraries to develop REST API Services.',
#    '· Must have demonstrated experience processing batch files using Python'],
#   'keywords': [{'value': 'florida blue', 'uniquenessScore': 0.531},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'batch', 'uniquenessScore': 0.071},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'information technology', 'uniquenessScore': 0.014},
#    {'value': 'processing', 'uniquenessScore': 0.008},
#    {'value': 'solutions', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T13:03:57.464Z',
#   'status': 'active',
#   'shortId': 'qae3BM',
#   'companyShortId': 'zjGa44'},
#  {'id': '76c5baaca2e404b080ace05f1673c51385e84a9abd392a3c72eac3779988d260',
#   'type': 'sponsoredToOrganic',
#   'title': 'Contract: Senior Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=bee9098ec9c4&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gade3aebgadb3de7fddg3de73de83aebbaaddd974aadfdacaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'EXPATS DIRECT LIMITED',
#   'location_city': 'Houston',
#   'location_state': 'Texas',
#   'location_latitude': 29.674496,
#   'location_longitude': -95.247573,
#   'score': 0.6350043956043956,
#   'postedDate': '2020-05-30T01:08:56.906Z',
#   'updatedDate': '2020-05-30T01:08:56.906Z',
#   'provider': 'neuvoo',
#   'bullet': 'The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#   'bullets': ['The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    'They Python Developer will be working with the data science team to complete application solution for MCBU, AES NOJV.',
#    '-Our Client is seeking an experienced Senior Python Developer/Analyst to support the GUS MCBU (Global Upstream Mid Continental Business Unit) in Houston, TX. The Python Developer will responsible for the day to day development code and test-driven development code in Python.',
#    '-Technology stack: Python, Azure, Databricks, NumPy, Anaconda, Tensorflow, Pandas',
#    '-Data Science domain exposure - very nice to have'],
#   'keywords': [{'value': 'databricks', 'uniquenessScore': 0.598},
#    {'value': 'tensorflow', 'uniquenessScore': 0.332},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'aes', 'uniquenessScore': 0.225},
#    {'value': 'upstream', 'uniquenessScore': 0.147},
#    {'value': 'continental', 'uniquenessScore': 0.111},
#    {'value': 'data science', 'uniquenessScore': 0.103},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'domain', 'uniquenessScore': 0.033},
#    {'value': 'houston tx', 'uniquenessScore': 0.033},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'global', 'uniquenessScore': 0.007},
#    {'value': 'analyst', 'uniquenessScore': 0.007},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'contract', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'business', 'uniquenessScore': 0.001},
#    {'value': 'application', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:08:56.906Z',
#   'status': 'active',
#   'shortId': 'PbXQmV',
#   'companyShortId': 'N51apb'},
#  {'id': 'b0dddf2a8b18886af78dbd386388e7745e1f2cc45f4c761e695f0620a29b1e2a',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://neuvoo.com/job.php?id=ca9a27c53913&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadd3aefgdd73aeffdde3de93aed3debbdaddd974daffdadaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Enflux',
#   'location_city': 'San Antonio',
#   'location_state': 'Texas',
#   'location_latitude': 29.561734,
#   'location_longitude': -98.355891,
#   'score': 0.27550549450549455,
#   'postedDate': '2020-05-30T01:11:20.246Z',
#   'updatedDate': '2020-05-30T01:11:20.246Z',
#   'provider': 'neuvoo',
#   'bullet': "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#   'bullets': ['Enflux is seeking a Software Engineer to be a core part of our development team.',
#    "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#    "There are parts of Python you love, parts of Python you'd change, but you appreciate the undeniable power of Python to help you get things done.",
#    'Experience with Elasticsearch',
#    'No visa sponsorship is available for this position'],
#   'keywords': [{'value': 'elasticsearch', 'uniquenessScore': 0.223},
#    {'value': 'no visa', 'uniquenessScore': 0.156},
#    {'value': 'mid level', 'uniquenessScore': 0.127},
#    {'value': 'visa sponsorship', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'saas', 'uniquenessScore': 0.062},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'core', 'uniquenessScore': 0.009},
#    {'value': 'change', 'uniquenessScore': 0.005},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'available', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'help', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:11:20.246Z',
#   'status': 'active',
#   'shortId': '5JY9R4',
#   'companyShortId': 'yAd1b4'},
#  {'id': 'ecd49eb280663b6dc45cf1af4eac791531774beaf045c87393904b4571e23e98',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AAIQxM_YapLU_T7yJ5L5XtRXEod5el4E8JKR96Ra9VSAO7Va1hcJVrGHjGPRjA4HimawnJhLiOpVJGuLrlOZh7typ0WzBA7-nwL-660ZKzFledZNJ_-8RE4Kf4JutCI6XRI-wiCJ-GCiN_sdl6SSqxNlJtdIrAeHVqYdZglMC6hn81Jul5_jhoQlMeDhT5yYq6oX2bIfvOdeVNVEPcLSvVNfpzTzK5PHfgvXz-nH_tPnvQzAib8DPv57b9e6o6CssfvNCkN5e5oWZWZKQ5WDOXzRhFFzxHbHFVDg32vSPwQS9AxVGn8LczTqHpJRTHLD9C5DqFfp4N50Bq7LLA7uC1XoYQWPa6NWfQ',
#   'company': 'IdeasJam',
#   'location_city': 'Remote',
#   'location_state': 'OR',
#   'location_latitude': 43.1148,
#   'location_longitude': -124.1568,
#   'score': 0.552541391941392,
#   'postedDate': '2020-05-16T09:36:59.000Z',
#   'updatedDate': '2020-05-29T18:06:24.038Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': 'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#   'bullets': ['This is a full stack developer role working in a fast paced environment.',
#    'This Engineer will be the main Python developer responsible for all things Django / Python related.',
#    'Engineer should have a strong understanding of the back-end technologies (Python/Django), front-end technologies (any main JavaScript framework), and strong understandings of DevOps (preferably Docker).',
#    'Maintaining and improving Django / python-based DevOps using Docker.',
#    'Understanding of the threading limitations of Python, and multi-process architecture'],
#   'keywords': [{'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'threading', 'uniquenessScore': 0.209},
#    {'value': 'full stack developer', 'uniquenessScore': 0.14},
#    {'value': 'docker', 'uniquenessScore': 0.12},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'architecture', 'uniquenessScore': 0.022},
#    {'value': 'fast paced', 'uniquenessScore': 0.015},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'process', 'uniquenessScore': 0.002}],
#   'validThrough': '2020-05-31T18:06:24.038Z',
#   'status': 'active',
#   'shortId': '5D9QQV',
#   'companyShortId': 'Kp21DK'},
#  {'id': '185b51af9bb8b23af47c615f6bb791cd689d0942c5d5e24029afa80b664bed06',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Data Engineer',
#   'url': 'https://neuvoo.com/job.php?id=f74c7a022f06&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gada3de9gddc3aedfdd93aef3deg3deebdaeda9a4dagfdaaaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Shimento Inc',
#   'location_city': 'San Francisco',
#   'location_state': 'California',
#   'location_latitude': 37.79801,
#   'location_longitude': -122.39696,
#   'score': 0.8355860805860807,
#   'postedDate': '2020-05-30T01:20:24.892Z',
#   'updatedDate': '2020-05-30T01:20:24.892Z',
#   'provider': 'neuvoo',
#   'bullet': 'Title: Senior Python Data Engineer',
#   'bullets': ['Title: Senior Python Data Engineer',
#    'Senior Python Data Engineer',
#    'We are currently looking for a senior Python Data Engineer to join our asset and Liability Technology team providing service to Client Corporate Treasury.',
#    'Senior Python Data Engineer is responsible to create reusable framework using Python to streamline data process within ALM Treasury.',
#    'Conduct and manage strategic analyses of Data Engineering environment to manage High volume data using custom pipe replacing existing SSIS data extraction process.'],
#   'keywords': [{'value': 'python data', 'uniquenessScore': 0.507},
#    {'value': 'data engineering', 'uniquenessScore': 0.236},
#    {'value': 'alm', 'uniquenessScore': 0.163},
#    {'value': 'ssis', 'uniquenessScore': 0.128},
#    {'value': 'extraction', 'uniquenessScore': 0.115},
#    {'value': 'pipe', 'uniquenessScore': 0.082},
#    {'value': 'treasury', 'uniquenessScore': 0.07},
#    {'value': 'streamline', 'uniquenessScore': 0.07},
#    {'value': 'liability', 'uniquenessScore': 0.024},
#    {'value': 'asset', 'uniquenessScore': 0.02},
#    {'value': 'strategic', 'uniquenessScore': 0.011},
#    {'value': 'corporate', 'uniquenessScore': 0.006},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'process', 'uniquenessScore': 0.002},
#    {'value': 'title', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'service', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:20:24.892Z',
#   'status': 'active',
#   'shortId': 'xlWBVY',
#   'companyShortId': 'zQX0jp'},
#  {'id': 'a4536a9eccb22c02631dc2b4da1d2b2b6f4b9385faa7e5f2760776e1a2dfe2d2',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Engineer',
#   'url': 'https://www.ziprecruiter.com/k/t/AALKsP7aJZ4BmYEBWQCbYbvST-bFkTCU92Rzv7LTJN73XLxOVGIzbNTfWJ2XcLgbryq9EMDZsLZkIqufYWkw3AYk3Crqk3afA1LDUZjagAw3Kb5GS_ToKDhX50zKk1be0h_DmYHT6zqOXMoF5w830-NWsOlzDVffpufurZKevcKN08kPbdT-PY2t1uHSSCNSgqAm87VyGXs5JaO0cpScl_m9UPsdapzidjabweK3HoQ7zH6GzcrwQV-znjCXmNttcWGIK7DHzRC3GRJX-giokO_-j_YwqijkVHhFbjSrvaXVe0APbYEvyje8Dty7aVHOSfs_hj3i0dhMdcs',
#   'company': 'Enflux',
#   'location_city': 'San Antonio',
#   'location_state': 'TX',
#   'location_latitude': 29.561734,
#   'location_longitude': -98.355891,
#   'score': 0.27581318681318684,
#   'postedDate': '2020-05-25T09:18:52.000Z',
#   'updatedDate': '2020-05-30T18:02:54.787Z',
#   'provider': 'ziprecruitertest10',
#   'bullet': "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#   'bullets': ['Enflux is seeking a Software Engineer to be a core part of our development team.',
#    "You're a junior or mid-level Python and backend developer who is familiar with all parts of a Python SaaS stack.",
#    "There are parts of Python you love, parts of Python you'd change, but you appreciate the undeniable power of Python to help you get things done.",
#    'Experience with Elasticsearch',
#    'No visa sponsorship is available for this position*'],
#   'keywords': [{'value': 'elasticsearch', 'uniquenessScore': 0.223},
#    {'value': 'no visa', 'uniquenessScore': 0.156},
#    {'value': 'mid level', 'uniquenessScore': 0.127},
#    {'value': 'visa sponsorship', 'uniquenessScore': 0.086},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'saas', 'uniquenessScore': 0.062},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'software engineer', 'uniquenessScore': 0.036},
#    {'value': 'junior', 'uniquenessScore': 0.032},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'parts', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'core', 'uniquenessScore': 0.009},
#    {'value': 'change', 'uniquenessScore': 0.005},
# ...
#   'provider': 'neuvoopremium',
#   'bullet': 'If you are an experienced Python Developer looking for a position with a leading company, Bartech can help!',
#   'bullets': ['If you are an experienced Python Developer looking for a position with a leading company, Bartech can help!',
#    'Our client has a need for a Python Developer.',
#    'The candidate should also be familiar with data analysis using Python scripts and SQL database management.',
#    'As a Python Developer you must represent our company well by being responsible, punctual and motivated to go above and beyond the call of duty.',
#    'As a Python Developer with Bartech, you will be working through an established and respected staffing organization with 41 years of serving as a trusted partner to our client companies.'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'sql database', 'uniquenessScore': 0.164},
#    {'value': 'above and beyond', 'uniquenessScore': 0.054},
#    {'value': 'to go', 'uniquenessScore': 0.029},
#    {'value': 'analysis', 'uniquenessScore': 0.008},
#    {'value': 'serving', 'uniquenessScore': 0.007},
#    {'value': 'staffing', 'uniquenessScore': 0.007},
#    {'value': 'partner', 'uniquenessScore': 0.005},
#    {'value': 'client', 'uniquenessScore': 0.005},
#    {'value': 'organization', 'uniquenessScore': 0.004},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'company', 'uniquenessScore': 0.001},
#    {'value': 'management', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T22:28:31.344Z',
#   'status': 'active',
#   'shortId': 'rRQ5x7',
#   'companyShortId': 'zg3RYz'},
#  {'id': '60aa2ec7afaf8c7ba9d37fd12cc0accf44b99d8740edb9408e0a2e045e256d82',
#   'type': 'sponsoredToOrganic',
#   'title': 'Software Development Engineer - AWS SDK for Python (Boto3) and AWS CLI',
#   'url': 'https://joblift.com/details/e8550016-f621-4e5d-b0f5-80f5212af1b5?fecd=OQbXmzdmK&utm_source=kimble_us_dynamic&utm_medium=external_feed&utm_campaign=dynamic',
#   'company': 'Amazon',
#   'location_city': 'Seattle',
#   'location_state': 'Washington',
#   'location_latitude': 47.638776,
#   'location_longitude': -122.36617,
#   'score': 0.38920000000000005,
#   'postedDate': '2020-05-20T07:39:30.000Z',
#   'updatedDate': '2020-05-29T07:14:06.869Z',
#   'provider': 'joblift',
#   'bullet': 'The AWS SDK for Python team is searching for Python developers to build open source tools for AWS in Python.',
#   'bullets': ['The AWS SDK for Python team is searching for Python developers to build open source tools for AWS in Python.',
#    'You will design and implement libraries and features to enable Python developers to harness the power of AWS cloud computing.',
#    'You will have opportunities to present at conferences, blog, develop open source software and engage directly with users.',
#    'Join the AWS SDKs and Tools team and help bring the power of AWS cloud computing to the Python community!',
#    '1+ years of experience contributing to the architecture and design (architecture, design patterns, reliability and scaling) of new and current systems.'],
#   'keywords': [{'value': 'aws cloud', 'uniquenessScore': 0.205},
#    {'value': 'architecture design', 'uniquenessScore': 0.122},
#    {'value': 'harness', 'uniquenessScore': 0.11},
#    {'value': 'cloud computing', 'uniquenessScore': 0.104},
#    {'value': 'open source', 'uniquenessScore': 0.091},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'reliability', 'uniquenessScore': 0.03},
#    {'value': 'engage', 'uniquenessScore': 0.016},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'software', 'uniquenessScore': 0.005},
#    {'value': 'community', 'uniquenessScore': 0.004},
#    {'value': 'blog', 'uniquenessScore': 0.004},
#    {'value': 'systems', 'uniquenessScore': 0.003},
#    {'value': 'enable', 'uniquenessScore': 0.002},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'current', 'uniquenessScore': 0.002},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T07:14:06.869Z',
#   'status': 'active',
#   'shortId': 'Gvd9qg',
#   'companyShortId': 'z4bL3y'},
#  {'id': '42f14c89167c5fbe14ee33d9953c2c7c267e731ddbde9dd3dafacfec630ec020',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python/Django Engineer - URGENT!',
#   'url': 'https://click.appcast.io/track/44rc7cc?cs=5vq&jg=qx9&bid=ZTAIU9X3zQHjJYLb9Yqb8A==',
#   'company': 'CyberCoders',
#   'location_city': 'Madison',
#   'location_state': 'WI',
#   'location_latitude': 43.072549,
#   'location_longitude': -89.402181,
#   'score': 1.3041472527472528,
#   'postedDate': '2020-05-29T00:00:00.000Z',
#   'updatedDate': '2020-05-29T20:29:30.239Z',
#   'provider': 'careerbliss',
#   'bullet': 'If you are a Senior Python/Django Engineer with experience, please read on!',
#   'bullets': ['If you are a Senior Python/Django Engineer with experience, please read on!',
#    'As our main Python Developer, you will be responsible for everything from our back-end technologies (python/django), front-end techs (Vue.js), and some DevOps (Heroku).',
#    'MUST HAVE: - BS in related field OR equivalent professional experience - 3+ years of full-stack engineering experience - 2+ years of experience with Python 3 and Django REST framework - PostgreSQL - Javascript (Vue.js preferably) - Heroku',
#    "NICE TO HAVE: - Vue.js - DevOps - event-driven programming - User Authentication/AuthorizationWhat's In It for You",
#    '- Competitive Salary DOE - Comprehensive Benefits Package - 401K with match - Flexible Schedule - Generous PTOSo, if you are a Senior Python/Django Engineer with experience, please apply today!'],
#   'keywords': [{'value': 'vue js', 'uniquenessScore': 0.816},
#    {'value': 'python django', 'uniquenessScore': 0.308},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'postgresql', 'uniquenessScore': 0.173},
#    {'value': 'full stack', 'uniquenessScore': 0.079},
#    {'value': 'devops', 'uniquenessScore': 0.065},
#    {'value': 'doe', 'uniquenessScore': 0.053},
#    {'value': 'urgent', 'uniquenessScore': 0.043},
#    {'value': 'front end', 'uniquenessScore': 0.038},
#    {'value': 'nice', 'uniquenessScore': 0.033},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'flexible schedule', 'uniquenessScore': 0.017},
#    {'value': 'event', 'uniquenessScore': 0.013},
#    {'value': 'javascript', 'uniquenessScore': 0.013},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'package', 'uniquenessScore': 0.007},
#    {'value': '401k', 'uniquenessScore': 0.004},
#    {'value': 'field', 'uniquenessScore': 0.004},
#    {'value': 'salary', 'uniquenessScore': 0.002},
#    {'value': 'professional', 'uniquenessScore': 0.002},
#    {'value': 'today', 'uniquenessScore': 0.002},
#    {'value': 'apply', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'benefits', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T20:29:30.239Z',
#   'status': 'active',
#   'shortId': 'dLn4Zd',
#   'companyShortId': 'yKQboz'},
#  {'id': 'f672c247002c33cb59e1c945171a6b82635bf350662a2b6541097b7d2148fa44',
#   'type': 'sponsoredToOrganic',
#   'title': 'Senior Python Engineer - Python, IOT, Agile',
#   'url': 'https://click.appcast.io/track/44rcaz1?cs=5vq&jg=qx9&bid=ZTAIU9X3zQHjJYLb9Yqb8A==',
#   'company': 'CyberCoders',
#   'location_city': 'Costa Mesa',
#   'location_state': 'CA',
#   'location_latitude': 33.680139,
#   'location_longitude': -117.90845,
#   'score': 0.3877443223443223,
#   'postedDate': '2020-05-29T00:00:00.000Z',
#   'updatedDate': '2020-05-29T20:31:48.596Z',
#   'provider': 'careerbliss',
#   'bullet': 'If you are a Senior Python Engineer with experience, please read on!',
#   'bullets': ['If you are a Senior Python Engineer with experience, please read on!',
#    'As a disrupter in the growing sector of IoT, we are looking to add a senior level developer to our team to help with the transfer of our codebase from PHP to Python.',
#    'Our fun office environment, traditional start-up perks, and experienced team will make you feel right at home.',
#    "- Python - IOT - Agile - PostgreSQL - RESTful API's - Django - JQuery - Bootstrap - Azure - GITSo, if you are a Senior Python Engineer with experience, please apply today!",
#    'Category: Technology, Keywords: Python Engineer'],
#   'keywords': [{'value': 'right at home', 'uniquenessScore': 0.255},
#    {'value': 'django', 'uniquenessScore': 0.225},
#    {'value': 'postgresql', 'uniquenessScore': 0.173},
#    {'value': 'iot', 'uniquenessScore': 0.13},
#    {'value': 'bootstrap', 'uniquenessScore': 0.111},
#    {'value': 'azure', 'uniquenessScore': 0.077},
#    {'value': 'php', 'uniquenessScore': 0.075},
#    {'value': 'python', 'uniquenessScore': 0.041},
#    {'value': 'jquery', 'uniquenessScore': 0.034},
#    {'value': 'agile', 'uniquenessScore': 0.026},
#    {'value': 'api', 'uniquenessScore': 0.021},
#    {'value': 'developer', 'uniquenessScore': 0.019},
#    {'value': 'transfer', 'uniquenessScore': 0.016},
#    {'value': 'engineer', 'uniquenessScore': 0.012},
#    {'value': 'fun', 'uniquenessScore': 0.009},
#    {'value': 'category', 'uniquenessScore': 0.006},
#    {'value': 'growing', 'uniquenessScore': 0.005},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'office', 'uniquenessScore': 0.002},
#    {'value': 'today', 'uniquenessScore': 0.002},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'help', 'uniquenessScore': 0.001},
#    {'value': 'apply', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-05-31T20:31:48.596Z',
#   'status': 'active',
#   'shortId': 'X9VegV',
#   'companyShortId': 'yKQboz'},
#  {'id': '95cfe7bf1d8ac67f350ddc1e7124d0fc39715de7c4f7e9f80265428df1fa202f',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python developer',
#   'url': 'https://neuvoo.com/job.php?id=a41e7d61ed5b&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gadf3decgddf3aebfdd93aec3dea3defbaabda9c4dabfaaeaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'Diverse Lynx',
#   'location_city': 'Winchester',
#   'location_state': 'California',
#   'location_latitude': 33.625979,
#   'location_longitude': -117.06853,
#   'score': 0.3487157509157509,
#   'postedDate': '2020-05-30T01:03:48.741Z',
#   'updatedDate': '2020-05-30T01:03:48.741Z',
#   'provider': 'neuvoo',
#   'bullet': 'Role: Python developer',
#   'bullets': ['Role: Python developer',
#    '6+ yrs of programming/development experience with expert Coding skills in Python for Mongo DB CRUD operations and in aggregation framework; must have knowledge of MongoDB Clustering and Mongo DB scaling based on work Load.',
#    'Code/develop applications to program specifications for mongoDB / mongoDB Atlas (cloud database).',
#    'Write unit test code, using tools and writing integration test cases using python.',
#    'The software developer should be adept in the following skills: Python, MongoDB or other NoSQL database, Cloud technologies , Linux/Windows as a development environment, data validation frame work using python/Pyspark.'],
#   'keywords': [{'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'atlas', 'uniquenessScore': 0.151},
#    {'value': 'mongodb', 'uniquenessScore': 0.145},
#    {'value': 'software developer', 'uniquenessScore': 0.064},
#    {'value': 'linux', 'uniquenessScore': 0.036},
#    {'value': 'validation', 'uniquenessScore': 0.034},
#    {'value': 'coding', 'uniquenessScore': 0.03},
#    {'value': 'cloud', 'uniquenessScore': 0.021},
#    {'value': 'frame', 'uniquenessScore': 0.021},
#    {'value': 'programming', 'uniquenessScore': 0.021},
#    {'value': 'cases', 'uniquenessScore': 0.02},
#    {'value': 'integration', 'uniquenessScore': 0.018},
#    {'value': 'database', 'uniquenessScore': 0.016},
#    {'value': 'windows', 'uniquenessScore': 0.014},
#    {'value': 'write', 'uniquenessScore': 0.01},
#    {'value': 'writing', 'uniquenessScore': 0.01},
#    {'value': 'test', 'uniquenessScore': 0.007},
#    {'value': 'operations', 'uniquenessScore': 0.003},
#    {'value': 'code', 'uniquenessScore': 0.003},
#    {'value': 'development', 'uniquenessScore': 0.002},
#    {'value': 'skills', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T01:03:48.741Z',
#   'status': 'active',
#   'shortId': 'Z666EP',
#   'companyShortId': 'wYKRpN'},
#  {'id': 'b3e67e8cd83229661972799f123d6b5b3ddaa8e8148b40031dc9eceb2f345d13',
#   'type': 'sponsoredToOrganic',
#   'title': 'Python Developer',
#   'url': 'https://neuvoo.com/job.php?id=87a87cb35b17&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83de9gadf3de8fdd93aed3aee3dedbdabda9e4daffda9aea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#   'company': 'TalentBurst, Inc.',
#   'location_city': 'Merrimack',
#   'location_state': 'New Hampshire',
#   'location_latitude': 42.863038,
#   'location_longitude': -71.516973,
#   'score': 0.6508285714285714,
#   'postedDate': '2020-05-30T00:57:49.173Z',
#   'updatedDate': '2020-05-30T00:57:49.173Z',
#   'provider': 'neuvoo',
#   'bullet': 'We are seeking a savvy Python developer to join our Innovation team and to power Fidelity digital product and services through innovation, collaboration and clarity.',
#   'bullets': ['We are seeking a savvy Python developer to join our Innovation team and to power Fidelity digital product and services through innovation, collaboration and clarity.',
#    'The ideal candidate is a top-tier Python developer who has experience building RESTful backend applications and microservices.',
#    'Hands-on experience with any one of the tools - Python, pandas/numpy, scikit-learn, Jupyter / any Python IDE along with Python or R, AWS / Cloud, Java, RDBMS, REST APIs',
#    'Assist in crafting data pipelines involving data cleaning, transformation, streaming enrichment / analytics and normalization',
#    'Asset Management Technology (AMT) provides worldwide technology and support to all the Investment Management, Research, Trading and Investment Operations functions.'],
#   'keywords': [{'value': 'investment operations', 'uniquenessScore': 0.346},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'aws cloud', 'uniquenessScore': 0.205},
#    {'value': 'amt', 'uniquenessScore': 0.174},
#    {'value': 'microservices', 'uniquenessScore': 0.154},
#    {'value': 'streaming', 'uniquenessScore': 0.14},
#    {'value': 'crafting', 'uniquenessScore': 0.136},
#    {'value': 'top tier', 'uniquenessScore': 0.132},
#    {'value': 'fidelity', 'uniquenessScore': 0.126},
#    {'value': 'investment management', 'uniquenessScore': 0.089},
#    {'value': 'backend', 'uniquenessScore': 0.08},
#    {'value': 'enrichment', 'uniquenessScore': 0.079},
#    {'value': 'clarity', 'uniquenessScore': 0.074},
#    {'value': 'trading', 'uniquenessScore': 0.065},
#    {'value': 'asset management', 'uniquenessScore': 0.054},
#    {'value': 'transformation', 'uniquenessScore': 0.045},
#    {'value': 'hands on', 'uniquenessScore': 0.035},
#    {'value': 'java', 'uniquenessScore': 0.026},
#    {'value': 'worldwide', 'uniquenessScore': 0.02},
#    {'value': 'digital', 'uniquenessScore': 0.015},
#    {'value': 'collaboration', 'uniquenessScore': 0.015},
#    {'value': 'analytics', 'uniquenessScore': 0.015},
#    {'value': 'innovation', 'uniquenessScore': 0.012},
#    {'value': 'power', 'uniquenessScore': 0.011},
#    {'value': 'ideal', 'uniquenessScore': 0.011},
#    {'value': 'cleaning', 'uniquenessScore': 0.01},
#    {'value': 'research', 'uniquenessScore': 0.007},
#    {'value': 'building', 'uniquenessScore': 0.005},
#    {'value': 'data', 'uniquenessScore': 0.003},
#    {'value': 'technology', 'uniquenessScore': 0.003},
#    {'value': 'team', 'uniquenessScore': 0.001},
#    {'value': 'experience', 'uniquenessScore': 0.001},
#    {'value': 'support', 'uniquenessScore': 0.001}],
#   'validThrough': '2020-06-01T00:57:49.173Z',
#   'status': 'active',
#   'shortId': 'e2VZL5',
#   'companyShortId': 'zvQDlw'}]

# %%
thing = [{
  "brand": "Ford",
  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
   {'value': 'python developer', 'uniquenessScore': 0.231},
   {'value': 'test automation', 'uniquenessScore': 0.122},
   {'value': 'robot', 'uniquenessScore': 0.104},
   {'value': 'library', 'uniquenessScore': 0.031},
   {'value': 'entry level', 'uniquenessScore': 0.017},
   {'value': 'graduate', 'uniquenessScore': 0.013},
   {'value': 'experience', 'uniquenessScore': 0.001}],
  "year": 1964},{
  "brand": "Ford",
  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
   {'value': 'python developer', 'uniquenessScore': 0.231},
   {'value': 'test automation', 'uniquenessScore': 0.122},
   {'value': 'robot', 'uniquenessScore': 0.104},
   {'value': 'library', 'uniquenessScore': 0.031},
   {'value': 'entry level', 'uniquenessScore': 0.017},
   {'value': 'graduate', 'uniquenessScore': 0.013},
   {'value': 'experience', 'uniquenessScore': 0.001}],
  "year": 1964},{
  "brand": "Ford",
  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
   {'value': 'python developer', 'uniquenessScore': 0.231},
   {'value': 'test automation', 'uniquenessScore': 0.122},
   {'value': 'robot', 'uniquenessScore': 0.104},
   {'value': 'library', 'uniquenessScore': 0.031},
   {'value': 'entry level', 'uniquenessScore': 0.017},
   {'value': 'graduate', 'uniquenessScore': 0.013},
   {'value': 'experience', 'uniquenessScore': 0.001}],
  "year": 1964},{
  "brand": "Ford",
  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
   {'value': 'python developer', 'uniquenessScore': 0.231},
   {'value': 'test automation', 'uniquenessScore': 0.122},
   {'value': 'robot', 'uniquenessScore': 0.104},
   {'value': 'library', 'uniquenessScore': 0.031},
   {'value': 'entry level', 'uniquenessScore': 0.017},
   {'value': 'graduate', 'uniquenessScore': 0.013},
   {'value': 'experience', 'uniquenessScore': 0.001}],
  "year": 1964}]

# %%
thing1 = thing[0]

# %%
type(thing1)
thing1['keywords']
# Out:
# [{'value': 'opencv', 'uniquenessScore': 0.49},
#  {'value': 'python developer', 'uniquenessScore': 0.231},
#  {'value': 'test automation', 'uniquenessScore': 0.122},
#  {'value': 'robot', 'uniquenessScore': 0.104},
#  {'value': 'library', 'uniquenessScore': 0.031},
#  {'value': 'entry level', 'uniquenessScore': 0.017},
#  {'value': 'graduate', 'uniquenessScore': 0.013},
#  {'value': 'experience', 'uniquenessScore': 0.001}]

# %%
thing1['keywords'] = [n['value'] for n in thing1['keywords']]

# %%
thing1
# Out:
# {'brand': 'Ford',
#  'keywords': ['opencv',
#   'python developer',
#   'test automation',
#   'robot',
#   'library',
#   'entry level',
#   'graduate',
#   'experience'],
#  'year': 1964}

# %%
def change_to_tags(n):
    n['keywords'] == [n['value'] for n in n['keywords']]

# %%
for item in thing:
    item.update(tags = [n['value'] for n in item['keywords']])

# %%
thing
# Out:
# [{'brand': 'Ford',
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'year': 1964,
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'robot',
#    'library',
#    'entry level',
#    'graduate',
#    'experience']},
#  {'brand': 'Ford',
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'year': 1964,
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'robot',
#    'library',
#    'entry level',
#    'graduate',
#    'experience']},
#  {'brand': 'Ford',
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'year': 1964,
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'robot',
#    'library',
#    'entry level',
#    'graduate',
#    'experience']},
#  {'brand': 'Ford',
#   'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#    {'value': 'python developer', 'uniquenessScore': 0.231},
#    {'value': 'test automation', 'uniquenessScore': 0.122},
#    {'value': 'robot', 'uniquenessScore': 0.104},
#    {'value': 'library', 'uniquenessScore': 0.031},
#    {'value': 'entry level', 'uniquenessScore': 0.017},
#    {'value': 'graduate', 'uniquenessScore': 0.013},
#    {'value': 'experience', 'uniquenessScore': 0.001}],
#   'year': 1964,
#   'tags': ['opencv',
#    'python developer',
#    'test automation',
#    'robot',
#    'library',
#    'entry level',
#    'graduate',
#    'experience']}]

# %%
for dict in thing:
    for n in dict:
        n['keywords'] = [n['value'] for n in n['keywords']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-cf3d21906ea4> in <module>
#       1 for dict in thing:
#       2     for n in dict:
# ----> 3         n['keywords'] = [n['value'] for n in n['keywords']]
#
# TypeError: string indices must be integers

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tag3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-d437f00cf431> in <module>
# ----> 1 df['tag3'] = make_tags(df['keywords'])
#
# <ipython-input-135-4d9d300fae70> in make_tags(y)
#       4         for n in x:
#       5             tg.append(n['value'])
# ----> 6         df['tag3'][x] = tg
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tag3'

# %%
df
# Out:
#                                                    id                type  \
# 0   451c129852855c7fc5386e026d3fada198667042bd172f...  sponsoredToOrganic
# 1   9486dd4822788545ef9176ba609b7fd22693d232032174...  sponsoredToOrganic
# 2   19c729f4839f259829d1ccb69a00bb57bd2a5ec53b9d9d...  sponsoredToOrganic
# 3   ed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e68...  sponsoredToOrganic
# 4   af1ef1679f9469dc306867e22eba9bbb0b99c18b70815d...  sponsoredToOrganic
# ..                                                ...                 ...
# 95  60aa2ec7afaf8c7ba9d37fd12cc0accf44b99d8740edb9...  sponsoredToOrganic
# 96  42f14c89167c5fbe14ee33d9953c2c7c267e731ddbde9d...  sponsoredToOrganic
# 97  f672c247002c33cb59e1c945171a6b82635bf350662a2b...  sponsoredToOrganic
# 98  95cfe7bf1d8ac67f350ddc1e7124d0fc39715de7c4f7e9...  sponsoredToOrganic
# 99  b3e67e8cd83229661972799f123d6b5b3ddaa8e8148b40...  sponsoredToOrganic
#
#                                                 title  \
# 0                        Entry Level Python Developer
# 1                    Lead Full Stack Python Developer
# 2                                   Software Engineer
# 3                       Automation Tester with Python
# 4                            Data analyst with Python
# ..                                                ...
# 95  Software Development Engineer - AWS SDK for Py...
# 96            Senior Python/Django Engineer - URGENT!
# 97        Senior Python Engineer - Python, IOT, Agile
# 98                                   Python developer
# 99                                   Python Developer
#
#                                                   url  \
# 0   https://neuvoo.com/job.php?id=844eb003d441&oap...
# 1   https://neuvoo.com/job.php?id=3a21bce968ad&oap...
# 2   https://www.ziprecruiter.com/k/t/AAJFkPXyGCKR1...
# 3   https://neuvoo.com/job.php?id=edc1e79db0b6&oap...
# 4   https://www.ziprecruiter.com/k/t/AALecNKlE-bkJ...
# ..                                                ...
# 95  https://joblift.com/details/e8550016-f621-4e5d...
# 96  https://click.appcast.io/track/44rc7cc?cs=5vq&...
# 97  https://click.appcast.io/track/44rcaz1?cs=5vq&...
# 98  https://neuvoo.com/job.php?id=a41e7d61ed5b&oap...
# 99  https://neuvoo.com/job.php?id=87a87cb35b17&oap...
#
#                      company  location_city location_state  location_latitude  \
# 0                DiverseLynx        Houston          Texas          29.674496
# 1            PeopleNTech LLC       Chandler        Arizona          33.306009
# 2      IntelliPro Group Inc.  Mountain View             CA          37.412894
# 3                DiverseLynx        Houston          Texas          29.674496
# 4   Two95 International Inc.       New York             NY          40.741790
# ..                       ...            ...            ...                ...
# 95                    Amazon        Seattle     Washington          47.638776
# 96               CyberCoders        Madison             WI          43.072549
# 97               CyberCoders     Costa Mesa             CA          33.680139
# 98              Diverse Lynx     Winchester     California          33.625979
# 99         TalentBurst, Inc.      Merrimack  New Hampshire          42.863038
#
#     location_longitude     score  ...  \
# 0           -95.247573  0.323031  ...
# 1          -111.919280  0.385376  ...
# 2          -122.049890  0.249076  ...
# 3           -95.247573  0.351400  ...
# 4           -73.999332  0.352179  ...
# ..                 ...       ...  ...
# 95         -122.366170  0.389200  ...
# 96          -89.402181  1.304147  ...
# 97         -117.908450  0.387744  ...
# 98         -117.068530  0.348716  ...
# 99          -71.516973  0.650829  ...
#
#                                                bullet  \
# 0                    for Entry Level Python Developer
# 1          Position- Lead Full Stack Python Developer
# 2   Position DescriptionProject Overview: As Pytho...
# 3   4 yrs of experience in Test Automation using P...
# 4                     Title: Data analyst with Python
# ..                                                ...
# 95  The AWS SDK for Python team is searching for P...
# 96  If you are a Senior Python/Django Engineer wit...
# 97  If you are a Senior Python Engineer with exper...
# 98                             Role: Python developer
# 99  We are seeking a savvy Python developer to joi...
#
#                                               bullets  \
# 0   [for Entry Level Python Developer, Fresh Gradu...
# 1   [Position- Lead Full Stack Python Developer, N...
# 2   [Position DescriptionProject Overview: As Pyth...
# 3   [4 yrs of experience in Test Automation using ...
# 4   [Title: Data analyst with Python, Experience w...
# ..                                                ...
# 95  [The AWS SDK for Python team is searching for ...
# 96  [If you are a Senior Python/Django Engineer wi...
# 97  [If you are a Senior Python Engineer with expe...
# 98  [Role: Python developer, 6+ yrs of programming...
# 99  [We are seeking a savvy Python developer to jo...
#
#                                              keywords  \
# 0   [{'value': 'opencv', 'uniquenessScore': 0.49},...
# 1   [{'value': 'python developer', 'uniquenessScor...
# 2   [{'value': 'q2', 'uniquenessScore': 0.186}, {'...
# 3   [{'value': 'opencv', 'uniquenessScore': 0.49},...
# 4   [{'value': 'flask', 'uniquenessScore': 0.371},...
# ..                                                ...
# 95  [{'value': 'aws cloud', 'uniquenessScore': 0.2...
# 96  [{'value': 'vue js', 'uniquenessScore': 0.816}...
# 97  [{'value': 'right at home', 'uniquenessScore':...
# 98  [{'value': 'python developer', 'uniquenessScor...
# 99  [{'value': 'investment operations', 'uniquenes...
#
#                 validThrough  status shortId companyShortId hey tags    tagz
# 0   2020-06-01T00:57:19.331Z  active  v2Yd7a         zGxooN           opencv
# 1   2020-06-01T00:42:16.175Z  active  0VJlgp         N0XEWN           opencv
# 2   2020-06-01T18:04:01.181Z  active  j3KPab         NqnZ0y           opencv
# 3   2020-06-01T01:18:29.056Z  active  xPE9xJ         zGxooN           opencv
# 4   2020-06-01T18:04:39.697Z  active  gQQ71l         yoPqYw           opencv
# ..                       ...     ...     ...            ...  ..  ...     ...
# 95  2020-05-31T07:14:06.869Z  active  Gvd9qg         z4bL3y           opencv
# 96  2020-05-31T20:29:30.239Z  active  dLn4Zd         yKQboz           opencv
# 97  2020-05-31T20:31:48.596Z  active  X9VegV         yKQboz           opencv
# 98  2020-06-01T01:03:48.741Z  active  Z666EP         wYKRpN           opencv
# 99  2020-06-01T00:57:49.173Z  active  e2VZL5         zvQDlw           opencv
#
# [100 rows x 23 columns]

# %%
df['tags'] = ""
for x in df['keywords']:
    for n in x:
        tags = []
        tags.append([n['value']])
    df['tags'].append(tags)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-b7c7ce52df70> in <module>
#       4         tags = []
#       5         tags.append([n['value']])
# ----> 6     df['tags'].append(tags)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in append(self, to_append, ignore_index, verify_integrity)
#    2777             to_concat = [self, to_append]
#    2778         return concat(
# -> 2779             to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    2780         )
#    2781
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     330                     " only Series and DataFrame objs are valid".format(type(obj))
#     331                 )
# --> 332                 raise TypeError(msg)
#     333
#     334             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'list'>'; only Series and DataFrame objs are valid

# %%
df['hey'] = ""

# %%
df
# Out:
#                                                    id                type  \
# 0   451c129852855c7fc5386e026d3fada198667042bd172f...  sponsoredToOrganic
# 1   9486dd4822788545ef9176ba609b7fd22693d232032174...  sponsoredToOrganic
# 2   19c729f4839f259829d1ccb69a00bb57bd2a5ec53b9d9d...  sponsoredToOrganic
# 3   ed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e68...  sponsoredToOrganic
# 4   af1ef1679f9469dc306867e22eba9bbb0b99c18b70815d...  sponsoredToOrganic
# ..                                                ...                 ...
# 95  60aa2ec7afaf8c7ba9d37fd12cc0accf44b99d8740edb9...  sponsoredToOrganic
# 96  42f14c89167c5fbe14ee33d9953c2c7c267e731ddbde9d...  sponsoredToOrganic
# 97  f672c247002c33cb59e1c945171a6b82635bf350662a2b...  sponsoredToOrganic
# 98  95cfe7bf1d8ac67f350ddc1e7124d0fc39715de7c4f7e9...  sponsoredToOrganic
# 99  b3e67e8cd83229661972799f123d6b5b3ddaa8e8148b40...  sponsoredToOrganic
#
#                                                 title  \
# 0                        Entry Level Python Developer
# 1                    Lead Full Stack Python Developer
# 2                                   Software Engineer
# 3                       Automation Tester with Python
# 4                            Data analyst with Python
# ..                                                ...
# 95  Software Development Engineer - AWS SDK for Py...
# 96            Senior Python/Django Engineer - URGENT!
# 97        Senior Python Engineer - Python, IOT, Agile
# 98                                   Python developer
# 99                                   Python Developer
#
#                                                   url  \
# 0   https://neuvoo.com/job.php?id=844eb003d441&oap...
# 1   https://neuvoo.com/job.php?id=3a21bce968ad&oap...
# 2   https://www.ziprecruiter.com/k/t/AAJFkPXyGCKR1...
# 3   https://neuvoo.com/job.php?id=edc1e79db0b6&oap...
# 4   https://www.ziprecruiter.com/k/t/AALecNKlE-bkJ...
# ..                                                ...
# 95  https://joblift.com/details/e8550016-f621-4e5d...
# 96  https://click.appcast.io/track/44rc7cc?cs=5vq&...
# 97  https://click.appcast.io/track/44rcaz1?cs=5vq&...
# 98  https://neuvoo.com/job.php?id=a41e7d61ed5b&oap...
# 99  https://neuvoo.com/job.php?id=87a87cb35b17&oap...
#
#                      company  location_city location_state  location_latitude  \
# 0                DiverseLynx        Houston          Texas          29.674496
# 1            PeopleNTech LLC       Chandler        Arizona          33.306009
# 2      IntelliPro Group Inc.  Mountain View             CA          37.412894
# 3                DiverseLynx        Houston          Texas          29.674496
# 4   Two95 International Inc.       New York             NY          40.741790
# ..                       ...            ...            ...                ...
# 95                    Amazon        Seattle     Washington          47.638776
# 96               CyberCoders        Madison             WI          43.072549
# 97               CyberCoders     Costa Mesa             CA          33.680139
# 98              Diverse Lynx     Winchester     California          33.625979
# 99         TalentBurst, Inc.      Merrimack  New Hampshire          42.863038
#
#     location_longitude     score  ...            provider  \
# 0           -95.247573  0.323031  ...              neuvoo
# 1          -111.919280  0.385376  ...              neuvoo
# 2          -122.049890  0.249076  ...  ziprecruitertest10
# 3           -95.247573  0.351400  ...              neuvoo
# 4           -73.999332  0.352179  ...  ziprecruitertest10
# ..                 ...       ...  ...                 ...
# 95         -122.366170  0.389200  ...             joblift
# 96          -89.402181  1.304147  ...         careerbliss
# 97         -117.908450  0.387744  ...         careerbliss
# 98         -117.068530  0.348716  ...              neuvoo
# 99          -71.516973  0.650829  ...              neuvoo
#
#                                                bullet  \
# 0                    for Entry Level Python Developer
# 1          Position- Lead Full Stack Python Developer
# 2   Position DescriptionProject Overview: As Pytho...
# 3   4 yrs of experience in Test Automation using P...
# 4                     Title: Data analyst with Python
# ..                                                ...
# 95  The AWS SDK for Python team is searching for P...
# 96  If you are a Senior Python/Django Engineer wit...
# 97  If you are a Senior Python Engineer with exper...
# 98                             Role: Python developer
# 99  We are seeking a savvy Python developer to joi...
#
#                                               bullets  \
# 0   [for Entry Level Python Developer, Fresh Gradu...
# 1   [Position- Lead Full Stack Python Developer, N...
# 2   [Position DescriptionProject Overview: As Pyth...
# 3   [4 yrs of experience in Test Automation using ...
# 4   [Title: Data analyst with Python, Experience w...
# ..                                                ...
# 95  [The AWS SDK for Python team is searching for ...
# 96  [If you are a Senior Python/Django Engineer wi...
# 97  [If you are a Senior Python Engineer with expe...
# 98  [Role: Python developer, 6+ yrs of programming...
# 99  [We are seeking a savvy Python developer to jo...
#
#                                              keywords  \
# 0   [{'value': 'opencv', 'uniquenessScore': 0.49},...
# 1   [{'value': 'python developer', 'uniquenessScor...
# 2   [{'value': 'q2', 'uniquenessScore': 0.186}, {'...
# 3   [{'value': 'opencv', 'uniquenessScore': 0.49},...
# 4   [{'value': 'flask', 'uniquenessScore': 0.371},...
# ..                                                ...
# 95  [{'value': 'aws cloud', 'uniquenessScore': 0.2...
# 96  [{'value': 'vue js', 'uniquenessScore': 0.816}...
# 97  [{'value': 'right at home', 'uniquenessScore':...
# 98  [{'value': 'python developer', 'uniquenessScor...
# 99  [{'value': 'investment operations', 'uniquenes...
#
#                 validThrough  status shortId companyShortId hey tags
# 0   2020-06-01T00:57:19.331Z  active  v2Yd7a         zGxooN
# 1   2020-06-01T00:42:16.175Z  active  0VJlgp         N0XEWN
# 2   2020-06-01T18:04:01.181Z  active  j3KPab         NqnZ0y
# 3   2020-06-01T01:18:29.056Z  active  xPE9xJ         zGxooN
# 4   2020-06-01T18:04:39.697Z  active  gQQ71l         yoPqYw
# ..                       ...     ...     ...            ...  ..  ...
# 95  2020-05-31T07:14:06.869Z  active  Gvd9qg         z4bL3y
# 96  2020-05-31T20:29:30.239Z  active  dLn4Zd         yKQboz
# 97  2020-05-31T20:31:48.596Z  active  X9VegV         yKQboz
# 98  2020-06-01T01:03:48.741Z  active  Z666EP         wYKRpN
# 99  2020-06-01T00:57:49.173Z  active  e2VZL5         zvQDlw
#
# [100 rows x 22 columns]

# %%
# tags = [n['value'] for n in k]
tags = []
for n in k:
    tags.append(n['value'])

# %%
for x in flat:
    for n in k:

# %%
df['tags'] = [n['value'] for n in df['keywords']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-70304bdab094> in <module>
# ----> 1 df['tags'] = [n['value'] for n in df['keywords']]
#
# <ipython-input-59-70304bdab094> in <listcomp>(.0)
# ----> 1 df['tags'] = [n['value'] for n in df['keywords']]
#
# TypeError: list indices must be integers or slices, not str

# %%
df['tags'] = df['keywords'].apply(lambda x: n['value'] for n in x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-0044ab471a79> in <module>
# ----> 1 df['tags'] = df['keywords'].apply(lambda x: n['value'] for n in x)
#       2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'generator' object is not callable

# %%
tags
# Out:
# ['opencv',
#  'python developer',
#  'test automation',
#  'robot',
#  'library',
#  'entry level',
#  'graduate',
#  'experience']

# %%
type(flat)
# Out:
# dict

# %%
flat
# Out:
# {'id': '451c129852855c7fc5386e026d3fada198667042bd172fd2129274d0a9d6a560',
#  'type': 'sponsoredToOrganic',
#  'title': 'Entry Level Python Developer',
#  'url': 'https://neuvoo.com/job.php?id=844eb003d441&oapply=org_v2020-05&source=kimblegroup_bulk&utm_source=partner&utm_medium=kimblegroup_bulk&puid=gdd83decgddc3aebfade3deg3deg3dedbaacdd9c4dacfdafaea33de83ee3fbdbgbdd8cdcaed37ddf9ddbgdd7',
#  'company': 'DiverseLynx',
#  'location_city': 'Houston',
#  'location_state': 'Texas',
#  'location_latitude': 29.674496,
#  'location_longitude': -95.247573,
#  'score': 0.3230307692307693,
#  'postedDate': '2020-05-30T00:57:19.331Z',
#  'updatedDate': '2020-05-30T00:57:19.331Z',
#  'provider': 'neuvoo',
#  'bullet': 'for Entry Level Python Developer',
#  'bullets': ['for Entry Level Python Developer',
#   'Fresh Graduate or Work experience in Test Automation using Python',
#   'Knowledge of Python and Robot framework',
#   'Knowledge ofPython Library - OpenCV, Pygui',
#   'Develop Test Automation scripts using Python'],
#  'keywords': [{'value': 'opencv', 'uniquenessScore': 0.49},
#   {'value': 'python developer', 'uniquenessScore': 0.231},
#   {'value': 'test automation', 'uniquenessScore': 0.122},
#   {'value': 'robot', 'uniquenessScore': 0.104},
#   {'value': 'library', 'uniquenessScore': 0.031},
#   {'value': 'entry level', 'uniquenessScore': 0.017},
#   {'value': 'graduate', 'uniquenessScore': 0.013},
#   {'value': 'experience', 'uniquenessScore': 0.001}],
#  'validThrough': '2020-06-01T00:57:19.331Z',
#  'status': 'active',
#  'shortId': 'v2Yd7a',
#  'companyShortId': 'zGxooN'}

# %%
tags = flat['keywords']

# %%
tags
# Out:
# [{'value': 'opencv', 'uniquenessScore': 0.49},
#  {'value': 'python developer', 'uniquenessScore': 0.231},
#  {'value': 'test automation', 'uniquenessScore': 0.122},
#  {'value': 'robot', 'uniquenessScore': 0.104},
#  {'value': 'library', 'uniquenessScore': 0.031},
#  {'value': 'entry level', 'uniquenessScore': 0.017},
#  {'value': 'graduate', 'uniquenessScore': 0.013},
#  {'value': 'experience', 'uniquenessScore': 0.001}]

# %%
my_tags = [n['value'] for n in tags]

# %%
for
# Out:
# ['opencv',
#  'python developer',
#  'test automation',
#  'robot',
#  'library',
#  'entry level',
#  'graduate',
#  'experience']

# %%
type(flat['keywords'])
# Out:
# list

# %%
for n in range()

# %%
flat_results =[
        flatten(job, reducer="underscore")
        for job in 
        flat['keywords']]

# %%
flat_results
# Out:
# [{'value': 'opencv', 'uniquenessScore': 0.49},
#  {'value': 'python developer', 'uniquenessScore': 0.231},
#  {'value': 'test automation', 'uniquenessScore': 0.122},
#  {'value': 'robot', 'uniquenessScore': 0.104},
#  {'value': 'library', 'uniquenessScore': 0.031},
#  {'value': 'entry level', 'uniquenessScore': 0.017},
#  {'value': 'graduate', 'uniquenessScore': 0.013},
#  {'value': 'experience', 'uniquenessScore': 0.001}]

# %%
df = pd.DataFrame.from_dict(flat_results)

# %%
df
# Out:
#               value  uniquenessScore
# 0            opencv            0.490
# 1  python developer            0.231
# 2   test automation            0.122
# 3             robot            0.104
# 4           library            0.031
# 5       entry level            0.017
# 6          graduate            0.013
# 7        experience            0.001

# %%
pip install arrow
# Out:
# Collecting arrow
#   Downloading https://files.pythonhosted.org/packages/99/b5/1f1c5ef3156f7b514c58613fe56e5670dc56374ab744bd1eb653c95e16b5/arrow-0.15.6-py2.py3-none-any.whl (47kB)
#      |████████████████████████████████| 51kB 1.1MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (from arrow) (2.8.0)
# Requirement already satisfied: six>=1.5 in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (from python-dateutil->arrow) (1.12.0)
# Installing collected packages: arrow
# Successfully installed arrow-0.15.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/robertbuckley/anaconda3/lib/python3.7/site-packages (from BeautifulSoup4) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import arrow
from bs4 import BeautifulSoup

def keyword(text):
    """
    Formats keywords by 
    -lowercasing all letters 
    -replacing ' ' with '_'
    -replacing '-' with '_'
    """
    text = text.lower()
    text = text.replace(' ', '_')
    text = text.replace('-', '_')
    return text

def remove_html(text):
    """
    Removes HTML
    """
    return BeautifulSoup(text).get_text()

def format_date(text):
    """
    Formats Date to 'YYYY-MM-DD'
    """
    time = arrow.get(text)
    time = time.format('YYYY-MM-DD')
    return time

# TODO:
# this funciton needs to be changed so that it can check for the
# API that we have and change it based on that.. just not sure
# how that works with the apply funciton. don't want to have parameters?
# def adzuna_id(text):
#     """
#     Formats ADZUNA API IDs to A + original ID
#     """
#     return "A" + str(text)

def jobsearcher_id(text):
    """
    Formats JOBSEARCHER API IDs to JS + original ID
    """
    return "JS" + str(text)


# TODO:
# Change it so that we have a list of the columns that need 
# the specific functions applied to them so that we can just add them
# to each one

# ex: 
# col_to_remove_html = ['title', 'title_keyword', 'description']
# for col in col_to_remove_html:
#     df[col] = df[col].apply(remove_html)
def transform_df(df):
    """
    Takes in dataframe, applies functions to correct columns
    """
    # insert date column
    df['inserted_date'] = arrow.utcnow().format("YYYY-MM-DD")

    # transform ID column
    df['id'] = df['id'].apply(jobsearcher_id)

    # remove HTML from columns
    df['title'] = df['title'].apply(remove_html)
#     df['title_keyword'] = df['title_keyword'].apply(remove_html) **Not in jobsearcher
#     df['description'] = df['description'].apply(remove_html) **Not needed? No HTML in jobsearcher description

    # transforms date columns
    df['publication_date'] = df['publication_date'].apply(format_date)

    return df

# %%
df = request_to_df()
df = transform_df(df)

# %%
df
# Out:
#                                                    id  \
# 0   JS451c129852855c7fc5386e026d3fada198667042bd17...
# 1   JSfce99407d67af38e810957c5db29173f72e8fe2b8552...
# 2   JS9486dd4822788545ef9176ba609b7fd22693d2320321...
# 3   JSed63799d396dfef0b4655f38efbd1342dbf3ffee1e4e...
# 4   JSaf1ef1679f9469dc306867e22eba9bbb0b99c18b7081...
# ..                                                ...
# 95  JS74aa011a385e614bea6e0b854cf89dfb83fccab2ba90...
# 96  JS61a1500b8eba1e428573f9a276238b2054da45621384...
# 97  JS6e5451faeb35c08f9585a9b5f6dad47b55607087c2f0...
# 98  JS19ec97d35a7bc7b1d384029a00aa49e071d6312e833c...
# 99  JS77703e2744f36a84bdb7b060e597ddf9ee14b74dd14a...
#
#                                              post_url  \
# 0   https://neuvoo.com/job.php?id=85ca87d0296d&oap...
# 1   https://www.ziprecruiter.com/eclk/opqvd0nnIoM1...
# 2   https://neuvoo.com/job.php?id=3a21bce968ad&oap...
# 3   https://neuvoo.com/job.php?id=edc1e79db0b6&oap...
# 4   https://www.ziprecruiter.com/k/t/AAL3umq2NAhzf...
# ..                                                ...
# 95  https://neuvoo.com/job.php?id=c45e3b4ec47d&oap...
# 96  https://neuvoo.com/job.php?id=c6a29b17e0cf&oap...
# 97  https://neuvoo.com/job.php?id=6275a0c49a72&oap...
# 98  https://www.ziprecruiter.com/k/l/AAL6kTveWufX6...
# 99  https://neuvoo.com/job.php?id=42235ec4636e&oap...
#
#                       company                             title        city  \
# 0                 DiverseLynx      Entry Level Python Developer     Houston
# 1            Xcutives.com Inc                  Python Developer      Austin
# 2             PeopleNTech LLC  Lead Full Stack Python Developer    Chandler
# 3                 DiverseLynx     Automation Tester with Python     Houston
# 4    Two95 International Inc.          Data analyst with Python    New York
# ..                        ...                               ...         ...
# 95               Liberty Jobs                  Python Developer       Wayne
# 96    Lorven Technologies Inc                  Python Developer    New York
# 97            Tekreliance LLC                  Python Developer   San Ramon
# 98                Tek Leaders                  Python Developer        Lehi
# 99  Open Systems Technologies        Backend Developer - Python  Bloomfield
#
#            state publication_date  \
# 0          Texas       2020-05-26
# 1             TX       2020-05-18
# 2        Arizona       2020-05-26
# 3          Texas       2020-05-26
# 4             NY       2020-04-28
# ..           ...              ...
# 95  Pennsylvania       2020-05-26
# 96      New York       2020-05-26
# 97    California       2020-05-26
# 98            UT       2020-05-19
# 99   Connecticut       2020-05-26
#
#                                           description   latitude   longitude  \
# 0   [for Entry Level Python Developer, Fresh Gradu...  29.674496  -95.247573
# 1   [Job Title: Python Developer Location: Austin,...  30.170527  -97.876902
# 2   [Position- Lead Full Stack Python Developer, N...  33.306009 -111.919280
# 3   [4 yrs of experience in Test Automation using ...  29.674496  -95.247573
# 4   [Title: Data analyst with Python, Experience w...  40.741790  -73.999332
# ..                                                ...        ...         ...
# 95  [Mid Level Python Developer, A highly recogniz...  40.041159  -75.388173
# 96  [Submit candidates under their legal name and ...  40.741790  -73.999332
# 97  [Requirement for Python Developer at multiple ...  37.751779 -121.953450
# 98  [Senior Python Developer with AWS knowledge, S...  40.393610 -111.846300
# 99  [Our client is seeking a Backend Developer - P...  41.839367  -72.741195
#
#    inserted_date
# 0     2020-05-27
# 1     2020-05-27
# 2     2020-05-27
# 3     2020-05-27
# 4     2020-05-27
# ..           ...
# 95    2020-05-27
# 96    2020-05-27
# 97    2020-05-27
# 98    2020-05-27
# 99    2020-05-27
#
# [100 rows x 11 columns]

# %%
import requests
import pandas as pd
from flatten_dict import flatten

# from dotenv import load_dotenv
# import os

# load_dotenv()

# app_id = os.getenv("APP_ID")
# api_key = os.getenv("API_KEY")

# TODO:
# Change the request to cover many different types of jobs... not just data engineer

def request_to_df():
    # make API call
    request = requests.get("https://api.adzuna.com/v1/api/jobs/us/search/1?app_id=da871bdc&app_key=e01f11150c93613b88693ef53adb8109&results_per_page=20&what=data%20engineer&content-type=application/json")
    # convert result into json
    result = request.json()
    # flatten nested objects
    flattened_results =[
        flatten(job, reducer="underscore")
        for job in 
        result['results']
    ]

    # turn into dataframe
    df = pd.DataFrame.from_dict(flattened_results)

    # rename columns
#     df = df[['id', 'redirect_url', 'title', 'title', 'category_tag', 'description', 'created', 'location_area', 'latitude', 'longitude']]
#     df.columns = ['id', 'post_url', 'title', 'title_keyword', 'tags', 'description', 'publication_date', 'location', 'latitude', 'longitude']
    return df

# %%
df = request_to_df()

# %%
df
# Out:
#             id                                        description  \
# 0   1549335342  ...  for good. <strong>Data</strong> <strong>E...
# 1   1554902511  Title <strong>Data</strong> <strong>Engineer</...
# 2   1533100037  Role <strong>Data</strong> <strong>Engineer</s...
# 3   1555035138  <strong>Data</strong> <strong>Engineer</strong...
# 4   1550148404  Role FullStack <strong>Data</strong> <strong>E...
# 5   1552144521  Hi, This is Surya with DISYS, One of our direc...
# 6   1550124138  Hi, Please find the below requirements. You ca...
# 7   1521288337  Description We are seeking a highly talented <...
# 8   1551130791  Job Title <strong>Data</strong> <strong>Engine...
# 9   1544828627  Job Title <strong>Data</strong> <strong>Engine...
# 10  1556053561  Location 605 S 5th Ave, Seattle, WA Job Title ...
# 11  1548134006  Top Skills Details 1) 4 years of <strong>data<...
# 12  1548994415  <strong>Data</strong> <strong>Engineer</strong...
# 13  1542069817  <strong>Data</strong> <strong>Engineer</strong...
# 14  1539235040  No need to be in Houston or relocate Wersquore...
# 15  1552144340  Description - Title <strong>Data</strong> <str...
# 16  1533100709  U.S. Citizens and those authorized to work in ...
# 17  1509946981  <strong>Data</strong> <strong>Engineer</strong...
# 18  1552273428  Job Title <strong>Data</strong> <strong>Engine...
# 19  1556053483  Hi Folks, Good afternoon. Please find the belo...
#
#                  location_display_name               location___CLASS__  \
# 0   Illinois Medical District, Chicago  Adzuna::API::Response::Location
# 1               Atlanta, Fulton County  Adzuna::API::Response::Location
# 2        Wilmington, New Castle County  Adzuna::API::Response::Location
# 3              Las Vegas, Clark County  Adzuna::API::Response::Location
# 4                         New York, US  Adzuna::API::Response::Location
# 5            Richmond County, Virginia  Adzuna::API::Response::Location
# 6                 Redmond, King County  Adzuna::API::Response::Location
# 7                 Newark, Essex County  Adzuna::API::Response::Location
# 8           Portland, Multnomah County  Adzuna::API::Response::Location
# 9           Portland, Multnomah County  Adzuna::API::Response::Location
# 10                Seattle, King County  Adzuna::API::Response::Location
# 11                Austin County, Texas  Adzuna::API::Response::Location
# 12            Phoenix, Maricopa County  Adzuna::API::Response::Location
# 13             Mc Lean, Fairfax County  Adzuna::API::Response::Location
# 14               Houston, Texas County  Adzuna::API::Response::Location
# 15           Richmond County, Virginia  Adzuna::API::Response::Location
# 16              Vienna, Fairfax County  Adzuna::API::Response::Location
# 17           San Antonio, Bexar County  Adzuna::API::Response::Location
# 18           Richmond County, Virginia  Adzuna::API::Response::Location
# 19           Richmond County, Virginia  Adzuna::API::Response::Location
#
#                                         location_area  \
# 0   [US, Illinois, Cook County, Chicago, Illinois ...
# 1               [US, Georgia, Fulton County, Atlanta]
# 2       [US, Delaware, New Castle County, Wilmington]
# 3               [US, Nevada, Clark County, Las Vegas]
# 4                                      [US, New York]
# 5                     [US, Virginia, Richmond County]
# 6              [US, Washington, King County, Redmond]
# 7              [US, New Jersey, Essex County, Newark]
# 8            [US, Oregon, Multnomah County, Portland]
# 9            [US, Oregon, Multnomah County, Portland]
# 10             [US, Washington, King County, Seattle]
# 11                         [US, Texas, Austin County]
# 12            [US, Arizona, Maricopa County, Phoenix]
# 13            [US, Virginia, Fairfax County, Mc Lean]
# 14              [US, Missouri, Texas County, Houston]
# 15                    [US, Virginia, Richmond County]
# 16             [US, Virginia, Fairfax County, Vienna]
# 17             [US, Texas, Bexar County, San Antonio]
# 18                    [US, Virginia, Richmond County]
# 19                    [US, Virginia, Richmond County]
#
#                                                 adref   latitude  \
# 0   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  41.868494
# 1   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  33.755711
# 2   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  39.731260
# 3   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1NTAzNTEzOCIsI...  35.920884
# 4   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1MDE0ODQwNCIsI...  42.522869
# 5   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  37.959676
# 6   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  47.670119
# 7   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUyMTI4ODMzNyIsI...  40.735075
# 8   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  45.505603
# 9   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  45.505603
# 10  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  47.608492
# 11  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU0ODEzNDAwNiIsI...  29.918447
# 12  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  33.450000
# 13  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU0MjA2OTgxNyIsI...  38.970000
# 14  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzOTIzNTA0MCIsI...  37.326159
# 15  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiMWlXbFVXZWc2aEdDV...  37.959676
# 16  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzMzEwMDcwOSIsI...  38.893471
# 17  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUwOTk0Njk4MSIsI...  29.463570
# 18  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1MjI3MzQyOCIsI...  37.959676
# 19  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1NjA1MzQ4MyIsI...  37.959676
#
#                      __CLASS__  \
# 0   Adzuna::API::Response::Job
# 1   Adzuna::API::Response::Job
# 2   Adzuna::API::Response::Job
# 3   Adzuna::API::Response::Job
# 4   Adzuna::API::Response::Job
# 5   Adzuna::API::Response::Job
# 6   Adzuna::API::Response::Job
# 7   Adzuna::API::Response::Job
# 8   Adzuna::API::Response::Job
# 9   Adzuna::API::Response::Job
# 10  Adzuna::API::Response::Job
# 11  Adzuna::API::Response::Job
# 12  Adzuna::API::Response::Job
# 13  Adzuna::API::Response::Job
# 14  Adzuna::API::Response::Job
# 15  Adzuna::API::Response::Job
# 16  Adzuna::API::Response::Job
# 17  Adzuna::API::Response::Job
# 18  Adzuna::API::Response::Job
# 19  Adzuna::API::Response::Job
#
#                                                title  \
# 0    <strong>Data</strong> <strong>Engineer</strong>
# 1    <strong>Data</strong> <strong>Engineer</strong>
# 2    <strong>Data</strong> <strong>Engineer</strong>
# 3    <strong>Data</strong> <strong>Engineer</strong>
# 4    <strong>Data</strong> <strong>Engineer</strong>
# 5   <strong>Data</strong> <strong>Engineers</strong>
# 6    <strong>Data</strong> <strong>Engineer</strong>
# 7    <strong>Data</strong> <strong>Engineer</strong>
# 8    <strong>Data</strong> <strong>Engineer</strong>
# 9    <strong>Data</strong> <strong>Engineer</strong>
# 10   <strong>Data</strong> <strong>Engineer</strong>
# 11   <strong>Data</strong> <strong>Engineer</strong>
# 12   <strong>Data</strong> <strong>Engineer</strong>
# 13   <strong>DATA</strong> <strong>ENGINEER</strong>
# 14   <strong>Data</strong> <strong>Engineer</strong>
# 15  <strong>Data</strong> <strong>Engineers</strong>
# 16   <strong>Data</strong> <strong>Engineer</strong>
# 17   <strong>Data</strong> <strong>Engineer</strong>
# 18   <strong>Data</strong> <strong>Engineer</strong>
# 19   <strong>Data</strong> <strong>Engineer</strong>
#
#                                          redirect_url salary_is_predicted  \
# 0   https://www.adzuna.com/land/ad/1549335342?se=1...                   0
# 1   https://www.adzuna.com/land/ad/1554902511?se=1...                   0
# 2   https://www.adzuna.com/land/ad/1533100037?se=1...                   0
# 3   https://www.adzuna.com/land/ad/1555035138?se=1...                   0
# 4   https://www.adzuna.com/land/ad/1550148404?se=1...                   0
# 5   https://www.adzuna.com/land/ad/1552144521?se=1...                   0
# 6   https://www.adzuna.com/land/ad/1550124138?se=1...                   0
# 7   https://www.adzuna.com/land/ad/1521288337?se=1...                   0
# 8   https://www.adzuna.com/land/ad/1551130791?se=1...                   0
# 9   https://www.adzuna.com/land/ad/1544828627?se=1...                   0
# 10  https://www.adzuna.com/land/ad/1556053561?se=1...                   0
# 11  https://www.adzuna.com/land/ad/1548134006?se=1...                   0
# 12  https://www.adzuna.com/land/ad/1548994415?se=1...                   0
# 13  https://www.adzuna.com/land/ad/1542069817?se=1...                   0
# 14  https://www.adzuna.com/land/ad/1539235040?se=1...                   0
# 15  https://www.adzuna.com/land/ad/1552144340?se=1...                   0
# 16  https://www.adzuna.com/land/ad/1533100709?se=1...                   0
# 17  https://www.adzuna.com/land/ad/1509946981?se=1...                   0
# 18  https://www.adzuna.com/land/ad/1552273428?se=1...                   0
# 19  https://www.adzuna.com/land/ad/1556053483?se=1...                   0
#
#                  category___CLASS__ category_tag category_label  \
# 0   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 1   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 2   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 3   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 4   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 5   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 6   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 7   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 8   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 9   Adzuna::API::Response::Category      it-jobs        IT Jobs
# 10  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 11  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 12  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 13  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 14  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 15  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 16  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 17  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 18  Adzuna::API::Response::Category      it-jobs        IT Jobs
# 19  Adzuna::API::Response::Category      it-jobs        IT Jobs
#
#                  company_display_name               company___CLASS__  \
# 0                         Capital One  Adzuna::API::Response::Company
# 1              Elite It Professionals  Adzuna::API::Response::Company
# 2                          MOURI Tech  Adzuna::API::Response::Company
# 3                       Maxonic, Inc.  Adzuna::API::Response::Company
# 4               Empower Professionals  Adzuna::API::Response::Company
# 5   Digital Intelligence Systems, LLC  Adzuna::API::Response::Company
# 6                     PVK Corporation  Adzuna::API::Response::Company
# 7               Zar IT Solutions, Inc  Adzuna::API::Response::Company
# 8                       Sagatianz Inc  Adzuna::API::Response::Company
# 9                      Gangboard, LLC  Adzuna::API::Response::Company
# 10                            Vaktech  Adzuna::API::Response::Company
# 11         InfoSmart Technologies Inc  Adzuna::API::Response::Company
# 12                Xoriant Corporation  Adzuna::API::Response::Company
# 13                       iSolvers Inc  Adzuna::API::Response::Company
# 14                PREDICTif Solutions  Adzuna::API::Response::Company
# 15                           Hexacorp  Adzuna::API::Response::Company
# 16                V.L.S. Systems, Inc  Adzuna::API::Response::Company
# 17                        Tech Quarry  Adzuna::API::Response::Company
# 18  Digital Intelligence Systems, LLC  Adzuna::API::Response::Company
# 19                   Open IT Labs LLC  Adzuna::API::Response::Company
#
#      longitude               created contract_time
# 0   -87.673975  2020-05-19T22:16:25Z           NaN
# 1   -84.388372  2020-05-26T12:53:16Z     full_time
# 2   -75.545138  2020-04-30T17:27:52Z           NaN
# 3  -115.165201  2020-05-26T15:40:12Z           NaN
# 4   -75.574677  2020-05-20T15:30:36Z     full_time
# 5   -76.711917  2020-05-22T18:23:59Z           NaN
# 6  -122.118237  2020-05-20T15:16:35Z           NaN
# 7   -74.173906  2020-04-14T22:54:56Z           NaN
# 8  -122.688215  2020-05-21T15:29:41Z           NaN
# 9  -122.688215  2020-05-14T12:27:59Z           NaN
# 10 -122.336407  2020-05-27T15:32:38Z           NaN
# 11  -96.258873  2020-05-18T21:22:34Z           NaN
# 12 -112.070000  2020-05-19T18:55:04Z           NaN
# 13  -77.230000  2020-05-11T14:52:59Z           NaN
# 14  -91.955988  2020-05-07T14:45:16Z     full_time
# 15  -76.711917  2020-05-22T18:23:27Z           NaN
# 16  -77.220397  2020-04-30T17:28:22Z           NaN
# 17  -98.522671  2020-04-01T02:34:16Z           NaN
# 18  -76.711917  2020-05-22T21:44:42Z           NaN
# 19  -76.711917  2020-05-27T15:32:08Z           NaN

# %%
df['city'] = df['location_area'].apply(lambda x: x[-1])

# %%
df['city'] = df['city'].apply(lambda x: x.replace('County', '').rstrip())

# %%
df['city']
# Out:
# 0     Illinois Medical District
# 1                       Atlanta
# 2                    Wilmington
# 3                     Las Vegas
# 4                      New York
# 5                      Richmond
# 6                       Redmond
# 7                        Newark
# 8                      Portland
# 9                      Portland
# 10                      Seattle
# 11                       Austin
# 12                      Phoenix
# 13                      Mc Lean
# 14                      Houston
# 15                     Richmond
# 16                       Vienna
# 17                  San Antonio
# 18                     Richmond
# 19                     Richmond
# Name: city, dtype: object

# %%
df.iloc[[1],[5]]
# Out:
#                            location_area
# 1  [US, Georgia, Fulton County, Atlanta]

# %%
x = df.loc[1, "location_area"]

# %%
city = x[-1]
state = x[1]
print(city), print(state)
# Out:
# Atlanta
# Georgia
# (None, None)

# %%
for x in len(df['location_area']):
    location = df.loc[x, 'location_area']
    city.append(location[-1])
    state.append(location[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-181b3510a540> in <module>
# ----> 1 for x in len(df['location_area']):
#       2     location = df.loc[x, 'location_area']
#       3     city.append(location[-1])
#       4     state.append(location[1])
#       5
#
# TypeError: 'int' object is not iterable

# %%
location = df.loc[0, 'location_area']
city = city.append(location[-1])
state = state.append(location[1])

# %%
l = location[-1]

# %%
#To be added to Adzuna ETL -extraction
city = []
state = []
for x in range(0,(len(df['location_area']))):
    location = df.loc[x, 'location_area']
    city.append(location[-1])
    state.append(location[1])
df['city'] = city
df['state'] = state

#Then in the transformation strip the "County" from "city" values

# %%
# Out:
#                                                title  \
# 0    <strong>Data</strong> <strong>Engineer</strong>
# 1    <strong>Data</strong> <strong>Engineer</strong>
# 2    <strong>Data</strong> <strong>Engineer</strong>
# 3    <strong>Data</strong> <strong>Engineer</strong>
# 4    <strong>Data</strong> <strong>Engineer</strong>
# 5   <strong>Data</strong> <strong>Engineers</strong>
# 6    <strong>Data</strong> <strong>Engineer</strong>
# 7    <strong>Data</strong> <strong>Engineer</strong>
# 8    <strong>Data</strong> <strong>Engineer</strong>
# 9    <strong>Data</strong> <strong>Engineer</strong>
# 10   <strong>Data</strong> <strong>Engineer</strong>
# 11   <strong>Data</strong> <strong>Engineer</strong>
# 12   <strong>Data</strong> <strong>Engineer</strong>
# 13   <strong>DATA</strong> <strong>ENGINEER</strong>
# 14   <strong>Data</strong> <strong>Engineer</strong>
# 15  <strong>Data</strong> <strong>Engineers</strong>
# 16   <strong>Data</strong> <strong>Engineer</strong>
# 17   <strong>Data</strong> <strong>Engineer</strong>
# 18   <strong>Data</strong> <strong>Engineer</strong>
# 19   <strong>Data</strong> <strong>Engineer</strong>
#
#                      __CLASS__  \
# 0   Adzuna::API::Response::Job
# 1   Adzuna::API::Response::Job
# 2   Adzuna::API::Response::Job
# 3   Adzuna::API::Response::Job
# 4   Adzuna::API::Response::Job
# 5   Adzuna::API::Response::Job
# 6   Adzuna::API::Response::Job
# 7   Adzuna::API::Response::Job
# 8   Adzuna::API::Response::Job
# 9   Adzuna::API::Response::Job
# 10  Adzuna::API::Response::Job
# 11  Adzuna::API::Response::Job
# 12  Adzuna::API::Response::Job
# 13  Adzuna::API::Response::Job
# 14  Adzuna::API::Response::Job
# 15  Adzuna::API::Response::Job
# 16  Adzuna::API::Response::Job
# 17  Adzuna::API::Response::Job
# 18  Adzuna::API::Response::Job
# 19  Adzuna::API::Response::Job
#
#                                                 adref  \
# 0   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 1   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 2   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzMzEwMDAzNyIsI...
# 3   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1NTAzNTEzOCIsI...
# 4   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1MDE0ODQwNCIsI...
# 5   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 6   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1MDEyNDEzOCIsI...
# 7   eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUyMTI4ODMzNyIsI...
# 8   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 9   eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 10  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 11  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU0ODEzNDAwNiIsI...
# 12  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 13  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 14  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzOTIzNTA0MCIsI...
# 15  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 16  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzMzEwMDcwOSIsI...
# 17  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUwOTk0Njk4MSIsI...
# 18  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
# 19  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiLURrMUoxT2c2aEdrQ...
#
#                  location___CLASS__               location_display_name  \
# 0   Adzuna::API::Response::Location  Illinois Medical District, Chicago
# 1   Adzuna::API::Response::Location              Atlanta, Fulton County
# 2   Adzuna::API::Response::Location       Wilmington, New Castle County
# 3   Adzuna::API::Response::Location             Las Vegas, Clark County
# 4   Adzuna::API::Response::Location                        New York, US
# 5   Adzuna::API::Response::Location           Richmond County, Virginia
# 6   Adzuna::API::Response::Location                Redmond, King County
# 7   Adzuna::API::Response::Location                Newark, Essex County
# 8   Adzuna::API::Response::Location          Portland, Multnomah County
# 9   Adzuna::API::Response::Location          Portland, Multnomah County
# 10  Adzuna::API::Response::Location                Seattle, King County
# 11  Adzuna::API::Response::Location                Austin County, Texas
# 12  Adzuna::API::Response::Location            Phoenix, Maricopa County
# 13  Adzuna::API::Response::Location             Mc Lean, Fairfax County
# 14  Adzuna::API::Response::Location               Houston, Texas County
# 15  Adzuna::API::Response::Location           Richmond County, Virginia
# 16  Adzuna::API::Response::Location              Vienna, Fairfax County
# 17  Adzuna::API::Response::Location           San Antonio, Bexar County
# 18  Adzuna::API::Response::Location           Richmond County, Virginia
# 19  Adzuna::API::Response::Location           Richmond County, Virginia
#
#                                         location_area          id  \
# 0   [US, Illinois, Cook County, Chicago, Illinois ...  1549335342
# 1               [US, Georgia, Fulton County, Atlanta]  1554902511
# 2       [US, Delaware, New Castle County, Wilmington]  1533100037
# 3               [US, Nevada, Clark County, Las Vegas]  1555035138
# 4                                      [US, New York]  1550148404
# 5                     [US, Virginia, Richmond County]  1552144521
# 6              [US, Washington, King County, Redmond]  1550124138
# 7              [US, New Jersey, Essex County, Newark]  1521288337
# 8            [US, Oregon, Multnomah County, Portland]  1551130791
# 9            [US, Oregon, Multnomah County, Portland]  1544828627
# 10             [US, Washington, King County, Seattle]  1556053561
# 11                         [US, Texas, Austin County]  1548134006
# 12            [US, Arizona, Maricopa County, Phoenix]  1548994415
# 13            [US, Virginia, Fairfax County, Mc Lean]  1542069817
# 14              [US, Missouri, Texas County, Houston]  1539235040
# 15                    [US, Virginia, Richmond County]  1552144340
# 16             [US, Virginia, Fairfax County, Vienna]  1533100709
# 17             [US, Texas, Bexar County, San Antonio]  1509946981
# 18                    [US, Virginia, Richmond County]  1552273428
# 19                    [US, Virginia, Richmond County]  1556053483
#
#                  company___CLASS__               company_display_name  \
# 0   Adzuna::API::Response::Company                        Capital One
# 1   Adzuna::API::Response::Company             Elite It Professionals
# 2   Adzuna::API::Response::Company                         MOURI Tech
# 3   Adzuna::API::Response::Company                      Maxonic, Inc.
# 4   Adzuna::API::Response::Company              Empower Professionals
# 5   Adzuna::API::Response::Company  Digital Intelligence Systems, LLC
# 6   Adzuna::API::Response::Company                    PVK Corporation
# 7   Adzuna::API::Response::Company              Zar IT Solutions, Inc
# 8   Adzuna::API::Response::Company                      Sagatianz Inc
# 9   Adzuna::API::Response::Company                     Gangboard, LLC
# 10  Adzuna::API::Response::Company                            Vaktech
# 11  Adzuna::API::Response::Company         InfoSmart Technologies Inc
# 12  Adzuna::API::Response::Company                Xoriant Corporation
# 13  Adzuna::API::Response::Company                       iSolvers Inc
# 14  Adzuna::API::Response::Company                PREDICTif Solutions
# 15  Adzuna::API::Response::Company                           Hexacorp
# 16  Adzuna::API::Response::Company                V.L.S. Systems, Inc
# 17  Adzuna::API::Response::Company                        Tech Quarry
# 18  Adzuna::API::Response::Company  Digital Intelligence Systems, LLC
# 19  Adzuna::API::Response::Company                   Open IT Labs LLC
#
#                  category___CLASS__  ... category_tag  \
# 0   Adzuna::API::Response::Category  ...      it-jobs
# 1   Adzuna::API::Response::Category  ...      it-jobs
# 2   Adzuna::API::Response::Category  ...      it-jobs
# 3   Adzuna::API::Response::Category  ...      it-jobs
# 4   Adzuna::API::Response::Category  ...      it-jobs
# 5   Adzuna::API::Response::Category  ...      it-jobs
# 6   Adzuna::API::Response::Category  ...      it-jobs
# 7   Adzuna::API::Response::Category  ...      it-jobs
# 8   Adzuna::API::Response::Category  ...      it-jobs
# 9   Adzuna::API::Response::Category  ...      it-jobs
# 10  Adzuna::API::Response::Category  ...      it-jobs
# 11  Adzuna::API::Response::Category  ...      it-jobs
# 12  Adzuna::API::Response::Category  ...      it-jobs
# 13  Adzuna::API::Response::Category  ...      it-jobs
# 14  Adzuna::API::Response::Category  ...      it-jobs
# 15  Adzuna::API::Response::Category  ...      it-jobs
# 16  Adzuna::API::Response::Category  ...      it-jobs
# 17  Adzuna::API::Response::Category  ...      it-jobs
# 18  Adzuna::API::Response::Category  ...      it-jobs
# 19  Adzuna::API::Response::Category  ...      it-jobs
#
#                                          redirect_url salary_is_predicted  \
# 0   https://www.adzuna.com/land/ad/1549335342?se=-...                   0
# 1   https://www.adzuna.com/land/ad/1554902511?se=-...                   0
# 2   https://www.adzuna.com/land/ad/1533100037?se=-...                   0
# 3   https://www.adzuna.com/land/ad/1555035138?se=-...                   0
# 4   https://www.adzuna.com/land/ad/1550148404?se=-...                   0
# 5   https://www.adzuna.com/land/ad/1552144521?se=-...                   0
# 6   https://www.adzuna.com/land/ad/1550124138?se=-...                   0
# 7   https://www.adzuna.com/land/ad/1521288337?se=-...                   0
# 8   https://www.adzuna.com/land/ad/1551130791?se=-...                   0
# 9   https://www.adzuna.com/land/ad/1544828627?se=-...                   0
# 10  https://www.adzuna.com/land/ad/1556053561?se=-...                   0
# 11  https://www.adzuna.com/land/ad/1548134006?se=-...                   0
# 12  https://www.adzuna.com/land/ad/1548994415?se=-...                   0
# 13  https://www.adzuna.com/land/ad/1542069817?se=-...                   0
# 14  https://www.adzuna.com/land/ad/1539235040?se=-...                   0
# 15  https://www.adzuna.com/land/ad/1552144340?se=-...                   0
# 16  https://www.adzuna.com/land/ad/1533100709?se=-...                   0
# 17  https://www.adzuna.com/land/ad/1509946981?se=-...                   0
# 18  https://www.adzuna.com/land/ad/1552273428?se=-...                   0
# 19  https://www.adzuna.com/land/ad/1556053483?se=-...                   0
#
#      longitude                                        description  \
# 0   -87.673975  ...  for good. <strong>Data</strong> <strong>E...
# 1   -84.388372  Title <strong>Data</strong> <strong>Engineer</...
# 2   -75.545138  Role <strong>Data</strong> <strong>Engineer</s...
# 3  -115.165201  <strong>Data</strong> <strong>Engineer</strong...
# 4   -75.574677  Role FullStack <strong>Data</strong> <strong>E...
# 5   -76.711917  Hi, This is Surya with DISYS, One of our direc...
# 6  -122.118237  Hi, Please find the below requirements. You ca...
# 7   -74.173906  Description We are seeking a highly talented <...
# 8  -122.688215  Job Title <strong>Data</strong> <strong>Engine...
# 9  -122.688215  Job Title <strong>Data</strong> <strong>Engine...
# 10 -122.336407  Location 605 S 5th Ave, Seattle, WA Job Title ...
# 11  -96.258873  Top Skills Details 1) 4 years of <strong>data<...
# 12 -112.070000  <strong>Data</strong> <strong>Engineer</strong...
# 13  -77.230000  <strong>Data</strong> <strong>Engineer</strong...
# 14  -91.955988  No need to be in Houston or relocate Wersquore...
# 15  -76.711917  Description - Title <strong>Data</strong> <str...
# 16  -77.220397  U.S. Citizens and those authorized to work in ...
# 17  -98.522671  <strong>Data</strong> <strong>Engineer</strong...
# 18  -76.711917  Job Title <strong>Data</strong> <strong>Engine...
# 19  -76.711917  Hi Folks, Good afternoon. Please find the belo...
#
#                  created   latitude  contract_time                       city  \
# 0   2020-05-19T22:16:25Z  41.868494            NaN  Illinois Medical District
# 1   2020-05-26T12:53:16Z  33.755711      full_time                    Atlanta
# 2   2020-04-30T17:27:52Z  39.731260            NaN                 Wilmington
# 3   2020-05-26T15:40:12Z  35.920884            NaN                  Las Vegas
# 4   2020-05-20T15:30:36Z  42.522869      full_time                   New York
# 5   2020-05-22T18:23:59Z  37.959676            NaN            Richmond County
# 6   2020-05-20T15:16:35Z  47.670119            NaN                    Redmond
# 7   2020-04-14T22:54:56Z  40.735075            NaN                     Newark
# 8   2020-05-21T15:29:41Z  45.505603            NaN                   Portland
# 9   2020-05-14T12:27:59Z  45.505603            NaN                   Portland
# 10  2020-05-27T15:32:38Z  47.608492            NaN                    Seattle
# 11  2020-05-18T21:22:34Z  29.918447            NaN              Austin County
# 12  2020-05-19T18:55:04Z  33.450000            NaN                    Phoenix
# 13  2020-05-11T14:52:59Z  38.970000            NaN                    Mc Lean
# 14  2020-05-07T14:45:16Z  37.326159      full_time                    Houston
# 15  2020-05-22T18:23:27Z  37.959676            NaN            Richmond County
# 16  2020-04-30T17:28:22Z  38.893471            NaN                     Vienna
# 17  2020-04-01T02:34:16Z  29.463570            NaN                San Antonio
# 18  2020-05-22T21:44:42Z  37.959676            NaN            Richmond County
# 19  2020-05-27T15:32:08Z  37.959676            NaN            Richmond County
#
#          state
# 0     Illinois
# 1      Georgia
# 2     Delaware
# 3       Nevada
# 4     New York
# 5     Virginia
# 6   Washington
# 7   New Jersey
# 8       Oregon
# 9       Oregon
# 10  Washington
# 11       Texas
# 12     Arizona
# 13    Virginia
# 14    Missouri
# 15    Virginia
# 16    Virginia
# 17       Texas
# 18    Virginia
# 19    Virginia
#
# [20 rows x 21 columns]

# %%
jobwords = ['python', 'data scientist']
jobsearcher_titles = [item.replace(" ", "&q[must][1]=")for item in jobwords]
jobsearcher_titles = ["q[must][0]=" + item for item in jobsearcher_titles]

# %%
main_titles = ["data engineer", "data scientist"]

# %%
for title in jobsearcher_titles:
    print(title)
# Out:
# q[must][0]=data&q[must][1]=engineer
# q[must][0]=data&q[must][1]=scientist

# %%
import requests
import pandas as pd
from flatten_dict import flatten

# %%
main_titles = ["data engineer", "data scientist"]

# %%
def jobsearcher():
    """
    Function to make HTTP requests to Adzuna API
    Returns dataframe that is the same format as others
    Current format:
        df.columns = [
        "id",
        "post_url",
        "title",
        "title_keyword",
        "tags",
        "description",
        "company",
        "publication_date",
        "latitude",
        "longitude",
        "city",
        "state
    ]
    """

    jobsearcher_titles = [item.replace(" ", "&q[must][1]=") for item in main_titles]
    jobsearcher_titles = ["q[must][0]=" + item for item in jobsearcher_titles]
    appended_results = list()

    for title in jobsearcher_titles:

        # make the requests to JobSearcher API
        request = requests.get(
            f"https://api.jobsearcher.com/v1/jobs?{title}&status=active&limit=100&type=organic&offset=900&distance=25&collapse=companyNameAndState&from_age=1&sortBy[0]=postedDate&sortOrder[0]=desc"
        )

        # convert result into json
        result = request.json()
        
        # flatten nested objects
        flattened_results = [
            flatten(job, reducer="underscore") for job in result["data"]
        ]
        
        #creates a list of tags from the list of dictionaries in 'keywords'
        for item in flattened_results:
            item.update(tags = [n['value'] for n in item['keywords']])
            
        # append those flattened results to make a list of flattened results
        # with each index being a different API
        appended_results.append(flattened_results)

        # turn 2D list with different API calls into a 1D list to be put into df
        final = [job for api in appended_results for job in api]

        # turn into dataframe
    df = pd.DataFrame.from_dict(final)

    # rename columns
    df = df[
        [
            "id",
            "url",
            "title",
            "title",
            "tags",
            "bullets",
            "company",
            "postedDate",
            "location_latitude",
            "location_longitude",
            "location_city",
            "location_state",
        ]
    ]

    df.columns = [
        "id",
        "post_url",
        "title",
        "title_keyword",
        "tags",
        "description",
        "company",
        "publication_date",
        "latitude",
        "longitude",
        "city",
        "state",
    ]

    df['id'] = df['id'].apply(
        lambda x: "JS" + str(x)
    )
    
    return df

# %%
df = jobsearcher()

# %%
df.shape
# Out:
# (100, 12)
